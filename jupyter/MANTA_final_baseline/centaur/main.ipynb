# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from uedge import *
from uedge.hdf5 import *
#import plotmesh as pm
from uetools import Case
from uedge.gridue import write_gridue
from Forthon import gchange
# Out:
# UEDGE configuration file /Users/eliotfelske/.uetoolsrc read.

# %%
import os
os.getcwd()
# Out:
# '/Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur'

# %% [markdown]
# # Create Case from YAML

# %%
c = Case('centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5')
#c = Case('input_v12_zeff.yaml')
print("dif_use, kye_use, kyi_use around SOL:", bbb.dif_use[28, :, 0][1], bbb.kye_use[28, :][1], bbb.kyi_use[28, :][1])
#if bbb.dif_use[30, :, 0][1] == c_dif and bbb.kye_use[30, :][1] == c_kye and bbb.kyi_use[30, :][1] == c_kyi:
   # pass
#else:
    #print(f'Diffusivities or chi values not matching!', file=sys.stderr)
# fnorm for final=1.65e+00
# Out:
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/centaur/centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/centaur/centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/centaur/centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
# *** For isimpon=2, set afracs, not afrac ***
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 9.06e+00
#
# dif_use, kye_use, kyi_use around SOL: 0.059 0.059 0.0221

# %%
bbb.afracs
# Out:
# array([[0.011, 0.011, 0.011, ..., 0.011, 0.011, 0.011],
#        [0.011, 0.011, 0.011, ..., 0.011, 0.011, 0.011],
#        [0.011, 0.011, 0.011, ..., 0.011, 0.011, 0.011],
#        ...,
#        [0.011, 0.011, 0.011, ..., 0.011, 0.011, 0.011],
#        [0.011, 0.011, 0.011, ..., 0.011, 0.011, 0.011],
#        [0.011, 0.011, 0.011, ..., 0.011, 0.011, 0.011]])

# %%
c.populate()
print("dif_use, kye_use, kyi_use around SOL:", bbb.dif_use[30, :, 0][1], bbb.kye_use[30, :][1], bbb.kyi_use[30, :][1])
# Out:
# *** For isimpon=2, set afracs, not afrac ***
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 6.68e-01
#
# dif_use, kye_use, kyi_use around SOL: 0.059 0.059 0.0221

# %%
'''c_dif = 0.05
c_kye = 0.05
c_kyi = 0.02

prof_d = [0.06, 0.059, 0.058, 0.057, 0.056, 0.055, 0.054, 0.053, 0.052, 0.051, 
 0.05, 0.049, 0.048, 0.047, 0.046, 0.045, 0.044, 0.043, 0.042, 0.041, 
 0.04, 0.039, 0.038, 0.037, 0.036, 0.035, 0.034, 0.033, 0.032, 0.031, 
 0.03, 0.029, 0.028, 0.027, 0.026, 0.025, 0.024, 0.023, 0.022, 0.021, 
 0.02, 0.019, 0.018, 0.017, 0.016, 0.015]
prof_e = [0.06, 0.059, 0.058, 0.057, 0.056, 0.055, 0.054, 0.053, 0.052, 0.051, 
 0.05, 0.049, 0.048, 0.047, 0.046, 0.045, 0.044, 0.043, 0.042, 0.041, 
 0.04, 0.039, 0.038, 0.037, 0.036, 0.035, 0.034, 0.033, 0.032, 0.031, 
 0.03, 0.029, 0.028, 0.027, 0.026, 0.025, 0.024, 0.023, 0.022, 0.021, 
 0.02, 0.019, 0.018, 0.017, 0.016, 0.015]
prof_i = [0.0226, 0.0221, 0.0216, 0.0211, 0.0206, 0.0201, 0.0196, 0.0191, 0.0186, 0.0181, 
 0.0176, 0.0171, 0.0166, 0.0161, 0.0156, 0.0151, 0.0146, 0.0141, 0.0136, 0.0131, 
 0.0126, 0.0121, 0.0116, 0.0111, 0.0106, 0.0101, 0.0096, 0.0091, 0.0086, 0.0081, 
 0.0076, 0.0071, 0.0066, 0.0061, 0.0056, 0.0051, 0.0046, 0.0041, 0.0036, 0.0031, 
 0.0026, 0.0021, 0.0016, 0.0011, 0.0006, 0.0001]

#divertor region temporary for plotting, reset to 0.5 at the end of cell
bbb.dif_use[1:17, :, 0] = c_dif
bbb.dif_use[41:65, :, 0] = c_dif
bbb.kye_use[1:17, :] = c_kye
bbb.kye_use[41:65, :] = c_kye
bbb.kyi_use[1:17, :] = c_kyi
bbb.kyi_use[41:65, :] = c_kyi

bbb.dif_use[30,:,0] = prof_d
bbb.dif_use[29,:,0] = prof_d
bbb.dif_use[28,:,0] = prof_d
bbb.dif_use[27,:,0] = prof_d
bbb.dif_use[26,:,0] = prof_d
bbb.dif_use[25,:,0] = prof_d
bbb.dif_use[24,:,0] = prof_d
bbb.dif_use[23,:,0] = prof_d
bbb.dif_use[22,:,0] = prof_d
bbb.dif_use[21,:,0] = prof_d
bbb.dif_use[20,:,0] = prof_d
bbb.dif_use[19,:,0] = prof_d
bbb.dif_use[18,:,0] = prof_d
bbb.dif_use[17,:,0] = prof_d
bbb.dif_use[31,:,0] = prof_d
bbb.dif_use[32,:,0] = prof_d
bbb.dif_use[33,:,0] = prof_d
bbb.dif_use[34,:,0] = prof_d
bbb.dif_use[35,:,0] = prof_d
bbb.dif_use[36,:,0] = prof_d
bbb.dif_use[37,:,0] = prof_d
bbb.dif_use[38,:,0] = prof_d
bbb.dif_use[39,:,0] = prof_d
bbb.dif_use[40,:,0] = prof_d

bbb.kye_use[30,:] = prof_e
bbb.kye_use[29,:] = prof_e
bbb.kye_use[28,:] = prof_e
bbb.kye_use[27,:] = prof_e
bbb.kye_use[26,:] = prof_e
bbb.kye_use[25,:] = prof_e
bbb.kye_use[24,:] = prof_e
bbb.kye_use[23,:] = prof_e
bbb.kye_use[22,:] = prof_e
bbb.kye_use[21,:] = prof_e
bbb.kye_use[20,:] = prof_e
bbb.kye_use[19,:] = prof_e
bbb.kye_use[18,:] = prof_e
bbb.kye_use[17,:] = prof_e
bbb.kye_use[31,:] = prof_e
bbb.kye_use[32,:] = prof_e
bbb.kye_use[33,:] = prof_e
bbb.kye_use[34,:] = prof_e
bbb.kye_use[35,:] = prof_e
bbb.kye_use[36,:] = prof_e
bbb.kye_use[37,:] = prof_e
bbb.kye_use[38,:] = prof_e
bbb.kye_use[39,:] = prof_e
bbb.kye_use[40,:] = prof_e

bbb.kyi_use[30,:] = prof_i
bbb.kyi_use[29,:] = prof_i
bbb.kyi_use[28,:] = prof_i
bbb.kyi_use[27,:] = prof_i
bbb.kyi_use[26,:] = prof_i
bbb.kyi_use[25,:] = prof_i
bbb.kyi_use[24,:] = prof_i
bbb.kyi_use[23,:] = prof_i
bbb.kyi_use[22,:] = prof_i
bbb.kyi_use[21,:] = prof_i
bbb.kyi_use[20,:] = prof_i
bbb.kyi_use[19,:] = prof_i
bbb.kyi_use[18,:] = prof_i
bbb.kyi_use[17,:] = prof_i
bbb.kyi_use[31,:] = prof_i
bbb.kyi_use[32,:] = prof_i
bbb.kyi_use[33,:] = prof_i
bbb.kyi_use[34,:] = prof_i
bbb.kyi_use[35,:] = prof_i
bbb.kyi_use[36,:] = prof_i
bbb.kyi_use[37,:] = prof_i
bbb.kyi_use[38,:] = prof_i
bbb.kyi_use[39,:] = prof_i
bbb.kyi_use[40,:] = prof_i
#bbb.kye_use[com.ixpt1[0]+1:com.ixpt2[0],com.iysptrx-10:com.iysptrx] = 15 what does this do?
'''
plt.figure()
c.plot.mesh(bbb.dif_use[:,:,0])
plt.title('dif_use')

c.plot.mesh(bbb.kye_use[:,:])
plt.title('kye_use')

c.plot.mesh(bbb.kyi_use[:,:])
plt.title('kyi_use')

plt.show()
'''
bbb.dif_use[1:17, :, 0] = c_dif
bbb.dif_use[41:65, :, 0] = c_dif
bbb.kye_use[1:17, :] = c_kye
bbb.kye_use[41:65, :] = c_kye
bbb.kyi_use[1:17, :] = c_kyi
bbb.kyi_use[41:65, :] = c_kyi

#indexing first index from 1 starts at the inner plate moving upward with index number, starting at
#Core boundary indicies: HFS: 17-30, LFS: 31-40
#kye biases heat outer plate, dif is more inner plate and has more of an effecto on midplane temps

#for ix in range(com.ixpt1[0]+1,com.ixpt2[0]: bbb.dif_use[ix,:,0]= [0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5]
#len bbb.dif_use[#,:,0] = 46

#for ix in range(com.ixpt1[0] + 1, com.ixpt2[0]):
    #print(bbb.dif_use[ix,:,0])
#kye,i decrease makes wall heat go down and decreases lambda, dif decrease increases wall heat again
'''
# Out:
# '\nbbb.dif_use[1:17, :, 0] = c_dif\nbbb.dif_use[41:65, :, 0] = c_dif\nbbb.kye_use[1:17, :] = c_kye\nbbb.kye_use[41:65, :] = c_kye\nbbb.kyi_use[1:17, :] = c_kyi\nbbb.kyi_use[41:65, :] = c_kyi\n\n#indexing first index from 1 starts at the inner plate moving upward with index number, starting at\n#Core boundary indicies: HFS: 17-30, LFS: 31-40\n#kye biases heat outer plate, dif is more inner plate and has more of an effecto on midplane temps\n\n#for ix in range(com.ixpt1[0]+1,com.ixpt2[0]: bbb.dif_use[ix,:,0]= [0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5]\n#len bbb.dif_use[#,:,0] = 46\n\n#for ix in range(com.ixpt1[0] + 1, com.ixpt2[0]):\n    #print(bbb.dif_use[ix,:,0])\n#kye,i decrease makes wall heat go down and decreases lambda, dif decrease increases wall heat again\n'

# %%
from plot_sinksource import plot_sinksource
plot_sinksource(c)

# %% [markdown]
# # Converge

# %%
bbb.ncore
# Out:
# array([2.38e+20, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19,
#        7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19,
#        7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19,
#        7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19,
#        7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19,
#        7.00e+19])

# %%
#bbb.afracs = 1.e-4
bbb.afracs
# Out:
# array([[0.011, 0.011, 0.011, ..., 0.011, 0.011, 0.011],
#        [0.011, 0.011, 0.011, ..., 0.011, 0.011, 0.011],
#        [0.011, 0.011, 0.011, ..., 0.011, 0.011, 0.011],
#        ...,
#        [0.011, 0.011, 0.011, ..., 0.011, 0.011, 0.011],
#        [0.011, 0.011, 0.011, ..., 0.011, 0.011, 0.011],
#        [0.011, 0.011, 0.011, ..., 0.011, 0.011, 0.011]])

# %%
# bbb.pcoree = 5.e6
# bbb.pcorei = 5.e6
bbb.pcoree,bbb.pcorei
# Out:
# (5000000.0, 5000000.0)

# %%
#bbb.isimpon = 6
bbb.isimpon
# Out:
# 2

# %%
c.populate()
# Out:
# *** For isimpon=2, set afracs, not afrac ***
#
# *** UEDGE arrays populated: WARNING, case NOT converged ***
# fnrm without preconditioning: 2.38e+05

# %%
import subprocess
bbb.isbcwdt=0
proc = subprocess.Popen(['caffeinate', "-d", "-u", "-i", "-s"])

try:
    c.converge(savefname='centaur_v12_p13.5MW_n2.187e20_Zeff3.85', dtreal=1e-10)
    os.system("printf '\7'") #macos plays sound after converging
finally:
    # Terminate caffeinate
    proc.terminate()
# Out:
# Requested save-path ../solutions not found, writing to cwd!
# *----------------------------------------------------------*
#  Need to take initial step with Jacobian; trying to do here
# *----------------------------------------------------------*
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1610455899374722E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.2750016765504545E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ---------------------------------------------------------------
# *** Number of time-step changes = 1 New time-step: 1.00E-10 ***
# ---------------------------------------------------------------
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610448436789455E-01 nfe=      1
#  iter=    1 fnrm=     0.2748197169601087E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Inner iteration #1
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610440975438441E-01 nfe=      1
#  iter=    1 fnrm=     0.2746405054690651E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 1.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #2
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610433515319612E-01 nfe=      1
#  iter=    1 fnrm=     0.2744835526689682E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 2.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #3
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610426056432247E-01 nfe=      1
#  iter=    1 fnrm=     0.2743258293821088E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 3.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #4
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610418598773691E-01 nfe=      1
#  iter=    1 fnrm=     0.2741685843278335E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 4.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #5
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610411142342616E-01 nfe=      1
#  iter=    1 fnrm=     0.2740165407041940E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 5.0000E-10; Timestep = 1.0000E-10
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 2 New time-step: 3.40E-10 ***
# ---------------------------------------------------------------
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1610406360090966E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.2556142660306313E-09 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Inner iteration #1
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610381023491693E-01 nfe=      1
#  iter=    1 fnrm=     0.2381544152634322E-09 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 9.4000E-10; Timestep = 3.4000E-10
#
#  Inner iteration #2
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610355700962067E-01 nfe=      1
#  iter=    1 fnrm=     0.2350086963253191E-09 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 1.2800E-09; Timestep = 3.4000E-10
#
#  Inner iteration #3
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610330392441221E-01 nfe=      1
#  iter=    1 fnrm=     0.2177291333231270E-09 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 1.6200E-09; Timestep = 3.4000E-10
#
#  Inner iteration #4
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610305097869727E-01 nfe=      1
#  iter=    1 fnrm=     0.2251583716401475E-09 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 1.9600E-09; Timestep = 3.4000E-10
#
#  Inner iteration #5
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610279817189025E-01 nfe=      1
#  iter=    1 fnrm=     0.2535099294535272E-09 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 2.3000E-09; Timestep = 3.4000E-10
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 3 New time-step: 1.16E-09 ***
# ---------------------------------------------------------------
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610254550340441E-01 nfe=      1
#  iter=    1 fnrm=     0.1671011815450915E-07 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Inner iteration #1
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610168768744034E-01 nfe=      1
#  iter=    1 fnrm=     0.1592147562714292E-07 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 3.7960E-09; Timestep = 1.1560E-09
#
#  Inner iteration #2
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1610083143171305E-01 nfe=      1
#  iter=    1 fnrm=     0.2188264044569266E-07 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 4.9520E-09; Timestep = 1.1560E-09
#
#  Inner iteration #3
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1609997671744842E-01 nfe=      1
#  iter=    1 fnrm=     0.9362456772716868E-07 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 6.1080E-09; Timestep = 1.1560E-09
#
#  Inner iteration #4
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1609912353589633E-01 nfe=      1
#  iter=    1 fnrm=     0.9625676670020055E-08 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 7.2640E-09; Timestep = 1.1560E-09
#
#  Inner iteration #5
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1609827181532526E-01 nfe=      1
#  iter=    1 fnrm=     0.1461518967770957E-07 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 8.4200E-09; Timestep = 1.1560E-09
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 4 New time-step: 3.93E-09 ***
# ---------------------------------------------------------------
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1609776624222279E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.7200644655679946E-09 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Inner iteration #1
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1609488836098244E-01 nfe=      1
#  iter=    1 fnrm=     0.9901656592127476E-09 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 1.3506E-08; Timestep = 3.9304E-09
#
#  Inner iteration #2
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1609202643311087E-01 nfe=      1
#  iter=    1 fnrm=     0.1319458840710657E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 1.7437E-08; Timestep = 3.9304E-09
#
#  Inner iteration #3
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1608917988136423E-01 nfe=      1
#  iter=    1 fnrm=     0.1716537739942529E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 2.1367E-08; Timestep = 3.9304E-09
#
#  Inner iteration #4
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1608634817568303E-01 nfe=      1
#  iter=    1 fnrm=     0.2155506642618872E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 2.5298E-08; Timestep = 3.9304E-09
#
#  Inner iteration #5
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1608353082744731E-01 nfe=      1
#  iter=    1 fnrm=     0.2628566766211715E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 2.9228E-08; Timestep = 3.9304E-09
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 5 New time-step: 1.34E-08 ***
# ---------------------------------------------------------------
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1608072738481283E-01 nfe=      1
#  iter=    1 fnrm=     0.1440031954133685E-06 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Inner iteration #1
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1607130669845034E-01 nfe=      1
#  iter=    1 fnrm=     0.2628819903735857E-06 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 4.6522E-08; Timestep = 1.3363E-08
#
#  Inner iteration #2
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1606202354615915E-01 nfe=      1
#  iter=    1 fnrm=     0.3622144930056545E-06 nfe=      6
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 5.9885E-08; Timestep = 1.3363E-08
#
#  Inner iteration #3
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1605286729156313E-01 nfe=      1
#  iter=    1 fnrm=     0.2709767794694119E-06 nfe=      6
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 7.3248E-08; Timestep = 1.3363E-08
#
#  Inner iteration #4
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1604382976263320E-01 nfe=      1
#  iter=    1 fnrm=     0.4343650167381922E-06 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 8.6612E-08; Timestep = 1.3363E-08
#
#  Inner iteration #5
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1603490411972839E-01 nfe=      1
#  iter=    1 fnrm=     0.4585473195325699E-06 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 9.9975E-08; Timestep = 1.3363E-08
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 6 New time-step: 4.54E-08 ***
# ---------------------------------------------------------------
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1603004071580590E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1993928146099848E-06 nfe=      6
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Inner iteration #1
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1600076280214233E-01 nfe=      1
#  iter=    1 fnrm=     0.4725158368489809E-06 nfe=      6
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 1.5877E-07; Timestep = 4.5435E-08
#
#  Inner iteration #2
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1597245617923501E-01 nfe=      1
#  iter=    1 fnrm=     0.4157065673356382E-06 nfe=      7
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 2.0421E-07; Timestep = 4.5435E-08
#
#  Inner iteration #3
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1594502850369799E-01 nfe=      1
#  iter=    1 fnrm=     0.2237490629258000E-06 nfe=      8
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 2.4964E-07; Timestep = 4.5435E-08
#
#  Inner iteration #4
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1591840872355938E-01 nfe=      1
#  iter=    1 fnrm=     0.2160628860914281E-06 nfe=      8
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 2.9508E-07; Timestep = 4.5435E-08
#
#  Inner iteration #5
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1589253845771219E-01 nfe=      1
#  iter=    1 fnrm=     0.4135063915039771E-06 nfe=      7
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 3.4052E-07; Timestep = 4.5435E-08
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 7 New time-step: 1.54E-07 ***
# ---------------------------------------------------------------
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1586736933361030E-01 nfe=      1
#  iter=    1 fnrm=     0.4501700360807014E-06 nfe=     19
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Inner iteration #1
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1578563267659588E-01 nfe=      1
#  iter=    1 fnrm=     0.4243305491887751E-06 nfe=     19
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 5.4043E-07; Timestep = 1.5448E-07
#
#  Inner iteration #2
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1571021613716869E-01 nfe=      1
#  iter=    1 fnrm=     0.6153068570888898E-06 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 6.9491E-07; Timestep = 1.5448E-07
#
#  Inner iteration #3
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1564036553414506E-01 nfe=      1
#  iter=    1 fnrm=     0.6103787975096989E-06 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 8.4939E-07; Timestep = 1.5448E-07
#
#  Inner iteration #4
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1557549828806153E-01 nfe=      1
#  iter=    1 fnrm=     0.5576303583726372E-06 nfe=     17
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 1.0039E-06; Timestep = 1.5448E-07
#
#  Inner iteration #5
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1551514158975394E-01 nfe=      1
#  iter=    1 fnrm=     0.4148894031159313E-06 nfe=     19
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 1.1584E-06; Timestep = 1.5448E-07
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 8 New time-step: 5.25E-07 ***
# ---------------------------------------------------------------
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1550125670808059E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.3463950558366200E-05 nfe=     33
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Inner iteration #1
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1532601866646355E-01 nfe=      1
#  iter=    1 fnrm=     0.3425154242461154E-05 nfe=     33
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 1.8381E-06; Timestep = 5.2523E-07
#
#  Inner iteration #2
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1518401888236951E-01 nfe=      1
#  iter=    1 fnrm=     0.3104733798393339E-05 nfe=     34
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 2.3633E-06; Timestep = 5.2523E-07
#
#  Inner iteration #3
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1506709087448264E-01 nfe=      1
#  iter=    1 fnrm=     0.2944663858480554E-05 nfe=     36
#
#
#  nksol ---  iterm = 1.
# ...
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.6515527566052355E-03 nfe=      1
#  iter=    1 fnrm=     0.7521825127873016E-05 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 6.0854E-03; Timestep = 8.1138E-04
#
# ----------------------------------------------------------------
# *** Number of time-step changes = 15 New time-step: 2.76E-03 ***
# ----------------------------------------------------------------
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.5085858209199443E-03 nfe=      1
#  iter=    1 fnrm=     0.3241585994323236E-04 nfe=    136
#  iter=    2 fnrm=     0.9695654083050829E-06 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Inner iteration #1
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2641196805823607E-03 nfe=      1
#  iter=    1 fnrm=     0.3746245311313859E-05 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 9.6555E-03; Timestep = 2.7587E-03
#
#  Inner iteration #2
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1372544314572336E-03 nfe=      1
#  iter=    1 fnrm=     0.3364619918135766E-05 nfe=    136
#  iter=    2 fnrm=     0.5403622361994798E-06 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 1.2414E-02; Timestep = 2.7587E-03
#
#  Inner iteration #3
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8046369243862728E-04 nfe=      1
#  iter=    1 fnrm=     0.9468124568476345E-06 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 1.5173E-02; Timestep = 2.7587E-03
#
#  Inner iteration #4
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.4303765609520296E-04 nfe=      1
#  iter=    1 fnrm=     0.4828937940017965E-06 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 1.7932E-02; Timestep = 2.7587E-03
#
#  Inner iteration #5
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2330954872063240E-04 nfe=      1
#  iter=    1 fnrm=     0.4932141458824089E-06 nfe=    136
#  iter=    2 fnrm=     0.1713988465510616E-06 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 2.0690E-02; Timestep = 2.7587E-03
#
# ----------------------------------------------------------------
# *** Number of time-step changes = 16 New time-step: 9.38E-03 ***
# ----------------------------------------------------------------
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1412395148981251E-04 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1795836460155312E-05 nfe=    136
#  iter=    2 fnrm=     0.1199201064257875E-05 nfe=    271
#  iter=    3 fnrm=     0.1608221671623406E-06 nfe=    406
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Inner iteration #1
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.5728019028084846E-05 nfe=      1
#  iter=    1 fnrm=     0.2006040309329401E-06 nfe=    136
#  iter=    2 fnrm=     0.3430327217307913E-06 nfe=    271
#  iter=    3 fnrm=     0.2772209376922595E-06 nfe=    406
#  iter=    4 fnrm=     0.6548939368359019E-07 nfe=    541
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 3.2829E-02; Timestep = 9.3796E-03
#
#  Inner iteration #2
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1740938025712498E-05 nfe=      1
#  iter=    1 fnrm=     0.5401057315705466E-07 nfe=    136
#  iter=    2 fnrm=     0.2609584584443685E-07 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 4.2208E-02; Timestep = 9.3796E-03
#
#  Inner iteration #3
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.5910868124598987E-06 nfe=      1
#  iter=    1 fnrm=     0.2232138538924399E-07 nfe=    136
#  iter=    2 fnrm=     0.1084215714044326E-07 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 5.1588E-02; Timestep = 9.3796E-03
#
#  Inner iteration #4
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1578777180717008E-06 nfe=      1
#  iter=    1 fnrm=     0.5632849932319995E-08 nfe=    136
#  iter=    2 fnrm=     0.1778843240419005E-07 nfe=    271
#  iter=    3 fnrm=     0.1222054279708291E-07 nfe=    406
#  iter=    4 fnrm=     0.4856899211693915E-07 nfe=    541
#  iter=    5 fnrm=     0.1094079532477724E-06 nfe=    676
#  iter=    6 fnrm=     0.7020083647157287E-07 nfe=    811
#  iter=    7 fnrm=     0.2431619764308052E-08 nfe=    946
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 6.0967E-02; Timestep = 9.3796E-03
#
#  Inner iteration #5
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1049999652381562E-06 nfe=      1
#  iter=    1 fnrm=     0.3039381827023595E-08 nfe=    136
#  iter=    2 fnrm=     0.8659798976059990E-09 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Total time = 7.0347E-02; Timestep = 9.3796E-03
#
# ----------------------------------------------------------------
# *** Number of time-step changes = 17 New time-step: 3.19E-02 ***
# ----------------------------------------------------------------
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2708997680398224E-07 nfe=      1
#  iter=    1 fnrm=     0.9334377326970063E-09 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#  Inner iteration #1
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/centaur/centaur_v12_p5.00_n2.38_imp1.1e2_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2733697564034425E-08 nfe=      1
#  iter=    1 fnrm=     0.4424154509873494E-09 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./centaur_v12_p13.5MW_n2.187e20_Zeff3.85_last_ii2.hdf5
#
# ******************************
# ** SUCCESS: fnrm < bbb.ftol **
# ******************************
# Total runtime: 0:04:07

# %%
import subprocess
proc = subprocess.Popen(['caffeinate', "-d", "-u", "-i", "-s"])

try:
    c.continuation_solve('afracs', 1e-2, savedir='impu_up', dtreal=1e-10, ftol=1e-2)
    os.system("printf '\7'") #macos plays sound after converging
finally:
    # Terminate caffeinate
    proc.terminate()

# %%
c.solver.convergenceanalysis('centaur_v12_p4.50_n2.38_imp3.25e2_last_ii2.hdf5');

# %% [markdown]
# # Inner plate

# %%
# %matplotlib widget
bbb.fqp=0
bbb.plateflux(); #internally calculated fluxes (postprocessing)

fig, axs = plt.subplot_mosaic(
    [['TopLeft', 'TopRight'],
     ['Bottom', 'Bottom']],
    layout='constrained',  # Automatically adjust layout
    width_ratios=[1, 1],   # Equal width for the top plots
)
fig.suptitle('Inner heat fluxes')
fig.supxlabel('Distance along inner plate (m)')
fig.supylabel('Heat flux (MW/m**2)')
# axs['TopRight'].set_xlabel("Distance along inner plate (m)")
#axs['TopRight'].set_ylabel("feex (W)")
axs['TopRight'].set_title("Electrons")
axs['TopRight'].plot(com.yylb[1:-1],bbb.sdelb[1:-1,0]*1e-6)

# axs['TopLeft'].set_xlabel("Distance along inner plate (m)")
# axs['TopLeft'].set_ylabel("Heat flux (MW/m**2)")
axs['TopLeft'].set_title("Ions/Atoms")
axs['TopLeft'].plot(com.yylb[1:-1],bbb.sdilb[1:-1]*1e-6) #polodal east field area

# axs['Bottom'].set_xlabel("Distance along inner plate (m)")
# axs['Bottom'].set_ylabel("Heat flux [MW/m**2]")
axs['Bottom'].set_title("Particle+radiation heat flux")
axs['Bottom'].plot(com.yylb,1.e-6*(bbb.sdtlb+bbb.sdrlb))
plt.show()

import numpy as np

# Save particle + radiation heat flux data
x = com.yylb  # distance along inner plate
q = 1.e-6 * (bbb.sdtlb + bbb.sdrlb)  # convert to MW/m^2

data = np.column_stack((x, q))
np.savetxt("inner_plate_heat_flux.txt", data, header="Distance_along_plate(m) Heat_flux(MW/m^2)", fmt="%.6e")

# %% [markdown]
# # Length Scale Calculations

# %%
#lambda_q from Eich = 1.06mm (we are probably a bit wider, so I am targeting 1.1mm, lambda_t = 3
from scipy.optimize import curve_fit
from scipy.interpolate import UnivariateSpline
# NEED: ION HEAT, ELECTRON HEAT, ION DENSITY
poloidal_index = 28 # CHANGE TO 28 for in board, 32 out board
# exponential fit

#ELECTRONS HEAT 
eheat = -np.array(bbb.feex[poloidal_index,1:-1]) #add a minus sign for inboard
dist = np.array([val[0] for val in com.yylb[1:-1]])
mask = dist >= 0
eheat = eheat[mask]
dist = dist[mask]
# Params[0]=a, params[1]=b
# b=-1/lambda_q
params, pcov = curve_fit(lambda t,a,b: a*np.exp(b*t),  dist,  eheat,  p0=(0.5, 1/4))

y_fit = params[0]*np.exp(params[1]*dist)

plt.plot(dist, eheat, label="Data")

plt.title("e Heat (W)")
plt.plot(dist, y_fit, 'r-', label="Fit")
plt.gca().set_xlim(left=0)
# plt.axhline(y=0.0, color='r', linestyle='-')
plt.legend()
# plt.yscale('log')
plt.show()
print(f"Lambda_q estimate: {-1/params[1]*1000} mm")

# calc 99% heat flux
# electron TEMP REGION
from scipy.integrate import simpson
totalheat = simpson(eheat, x=dist)
from scipy.integrate import cumulative_trapezoid
cumulative_integral = cumulative_trapezoid(eheat, dist, initial=0)
target_scale = 0.999
target_value = target_scale * cumulative_integral[-1]

index = np.searchsorted(cumulative_integral, target_value)

decaylen = dist[index]
poloidal_index = 28
etemp= np.array(bbb.te[poloidal_index,1:-1]/bbb.ev)
etemp = etemp[mask]

# Interpolating to get exact temp at wall
interp_func = UnivariateSpline(dist[10:17], etemp[10:17])
x = np.arange(0.015, 0.025, 0.001)

y = interp_func(x)

wallIndex = np.where(abs(x - 0.02) < 0.0000001)[0][0]


# print(np.shape(dist),np.shape(eheat), np.shape(etemp))
print(f"{target_scale*100}% of heat flux at x = {(decaylen*100):.3f}cm, e temp = {etemp[index]:.3f} eV")
print(f"*** at x = 2cm (Index = {wallIndex}), interpolated Elc temp = {y[wallIndex]:.3f} eV ***")
print(f"at x = {(dist[13]*100):.3f}cm, Elc temp = {etemp[13]:.3f} eV")
print(f"at x = {(dist[16]*100):.3f}cm, Elc temp = {etemp[16]:.3f} eV")
print(f"at x = {(dist[21]*100):.3f}cm, Elc temp = {etemp[21]:.3f} eV")
plt.plot(x, y)
plt.plot(dist, etemp)
plt.title('Interpolation region check')
plt.xlim([0.015,0.025])
plt.ylim([7.5,17])
plt.show()
# tparams, tpcov = curve_fit(lambda t,a,b: a*np.exp(b*t),  dist,  etemp,  p0=(0.5, -1))
plt.plot(dist, etemp)
plt.title("e Temp (eV)")
plt.show()
targeteV = 5
eev = np.searchsorted(etemp[::-1], targeteV, side = "right")*-1

print(f"{targeteV}ev at x = {dist[eev]*100}cm")
# Out:
# Lambda_q estimate: 1.0720045045050453 mm
# 99.9% of heat flux at x = 4.211cm, e temp = 3.659 eV
# *** at x = 2cm (Index = 5), interpolated Elc temp = 8.219 eV ***
# at x = 2.092cm, Elc temp = 7.882 eV
# at x = 2.978cm, Elc temp = 5.472 eV
# at x = 5.326cm, Elc temp = 2.739 eV
# 5ev at x = 3.346067022343157cm

# %%
#lambda_q from Eich = 1.06mm (we are probably a bit wider, so I am targeting 1.1mm, lambda_t = 3
from scipy.optimize import curve_fit
from scipy.interpolate import UnivariateSpline
# NEED: ION HEAT, ELECTRON HEAT, ION DENSITY
poloidal_index = 28 # CHANGE TO 28 for in board, 32 out board
# exponential fit

# IONS HEAT
ionheat = -np.array(bbb.feix[poloidal_index,1:-1]) #add a minus sign for inboard
dist = np.array([val[0] for val in com.yylb[1:-1]])
mask = dist >= 0
ionheat = ionheat[mask]
dist = dist[mask]
# Params[0]=a, params[1]=b
# b=-1/lambda_q
params, pcov = curve_fit(lambda t,a,b: a*np.exp(b*t),  dist,  ionheat,  p0=(0.5, -1))
#print(pcov)
#print(params)
y_fit = params[0]*np.exp(params[1]*dist)
# print(y_fit)
# Plot the results
plt.plot(dist, ionheat, label="Data")
plt.title("Ion Heat (W)")
plt.plot(dist, y_fit, 'r-', label="Fit")
plt.gca().set_xlim(left=0)
# plt.axhline(y=0.0, color='r', linestyle='-')
plt.legend()
plt.show()
print(f"Lambda_q estimate: {-1/params[1]*1000} mm")

# ION TEMP REGION
from scipy.integrate import simpson
totalheat = simpson(ionheat, x=dist)
from scipy.integrate import cumulative_trapezoid
cumulative_integral = cumulative_trapezoid(ionheat, dist, initial=0)
target_scale = 0.999
target_value = target_scale * totalheat
iontemp= np.array(bbb.ti[poloidal_index,1:-1]/bbb.ev)
iontemp = iontemp[mask]


# Interpolation check
interp_func = UnivariateSpline(dist[10:17], iontemp[10:17])
x = np.arange(0.015, 0.025, 0.001)
# print(x)
y = interp_func(x)

wallIndex = np.where(abs(x - 0.02) < 0.0000001)[0][0]


index = np.searchsorted(cumulative_integral, target_value)
# print("HI",dist[13])
decaylen = dist[index]
poloidal_index = 29
iontemp= np.array(bbb.ti[poloidal_index,1:-1]/bbb.ev)
iontemp = iontemp[mask]
print(f"{target_scale*100}% of heat flux at x = {(decaylen*100):.3f}cm, Ion temp = {iontemp[index]:.3f} eV")
print(f"*** at x = 2cm (Index = {wallIndex}), interpolated Ion temp = {y[wallIndex]:.3f} eV ***")
print(f"at x = {(dist[13]*100):.3f}cm, Ion temp = {iontemp[13]:.3f} eV")
print(f"at x = {(dist[16]*100):.3f}cm, Ion temp = {iontemp[16]:.3f} eV")
print(f"at x = {(dist[21]*100):.3f}cm, Ion temp = {iontemp[21]:.3f} eV")
# tparams, tpcov = curve_fit(lambda t,a,b: a*np.exp(b*t),  dist,  iontemp,  p0=(0.5, -1))
plt.plot(x, y)
plt.plot(dist, etemp)
plt.title('Interpolation region check')
plt.xlim([0.015,0.025])
plt.ylim([7.5,17])
plt.show()
targeteV = 10
iev = np.searchsorted(iontemp[::-1], targeteV, side = "right")*-1

print(f"{targeteV}ev at x = {dist[iev]*100}cm")
plt.xlabel("Distance from separatrix (m)")
plt.ylabel("eV")
plt.title("Ion temp")
plt.plot(com.yylb[1:-1],bbb.ti[34,1:-1]/bbb.ev)
plt.axhline(y=5, color='r', linestyle='-')
plt.gca().set_xlim(left=0)
plt.yscale('log') 
plt.show()
# Out:
# Lambda_q estimate: 2.9606340551799333 mm
# 99.9% of heat flux at x = 2.651cm, Ion temp = 8.100 eV
# *** at x = 2cm (Index = 5), interpolated Ion temp = 11.058 eV ***
# at x = 2.092cm, Ion temp = 10.428 eV
# at x = 2.978cm, Ion temp = 7.702 eV
# at x = 5.326cm, Ion temp = 7.814 eV
# 10ev at x = 2.3584341343696336cm

# %% [markdown]
# # Midplane

# %%
# %matplotlib widget
plt.xlabel("Distance from separatrix (m)")
plt.ylabel("ions/m^3")
plt.title("Ion density")
plt.plot(com.yylb[1:-1],bbb.ni[28,1:-1,0])
plt.show()
plt.xlabel("Distance from separatrix (m)")
plt.ylabel("eV")
plt.title("Ion temp")
plt.plot(com.yylb[1:-1],bbb.ti[28,1:-1]/bbb.ev)
plt.show()
plt.xlabel("Distance from separatrix (m)")
plt.ylabel("eV")
plt.title("T_e (Inboard Midplane)")
plt.plot(com.yylb[1:-1],bbb.te[28,1:-1]/bbb.ev)
#plt.plot(com.yylb[1:-1],bbb.te[31,1:-1]/bbb.ev)
plt.show()

plt.plot(com.yylb[1:-1], bbb.ne[30,1:-1])
plt.xlabel('Distance from Separatrix (m)')
plt.title('Elc density Inner Midplane')
plt.show()
plt.plot(com.yylb[1:-1], bbb.ne[31,1:-1])
plt.xlabel('Distance from Separatrix (m)')
plt.title('Elc density Outer Midplane')
#inner limit of dist. from separatrix should correspond with the rho coord of temp and n BC so rho * minor rad. (0.72m)
#rho=0.92
bbb.ni[28,1:-1,0].size

import numpy as np

# Coordinates (distance from separatrix)
x = com.yylb[1:-1]

# Electron temperature (in eV) at outer midplane (index 31)
te_outer = bbb.te[31, 1:-1] / bbb.ev

# Electron density (in ions/m^3) at outer midplane (index 31)
ne_outer = bbb.ne[31, 1:-1]

# Stack data for saving: columns = [x, value]
te_data = np.column_stack((x, te_outer))
ne_data = np.column_stack((x, ne_outer))

# Save to text files
np.savetxt("electron_temp_outer_midplane.txt", te_data, header="Distance_from_separatrix(m) Electron_Temperature(eV)", fmt="%.6e")
np.savetxt("electron_density_outer_midplane.txt", ne_data, header="Distance_from_separatrix(m) Electron_Density(ions/m^3)", fmt="%.6e")

# %%
rho = (com.yylb[1:-1] / 0.72) + 1
n_e = bbb.ne[31,1:-1].reshape(44)
rho = rho.reshape(44)
np.savetxt('midplane_ne.csv', np.vstack((rho,n_e)).T, delimiter=', ')
t_i = bbb.ti[31,1:-1].reshape(44)
t_e = bbb.te[31,1:-1].reshape(44)
n_i = bbb.ni[31,1:-1,0].reshape(44)
np.savetxt('midplane_ti.csv', np.vstack((rho,t_i)).T, delimiter=', ')
np.savetxt('midplane_te.csv', np.vstack((rho,t_e)).T, delimiter=', ')
np.savetxt('outmidplane_ni.csv', np.vstack((rho,n_i)).T, delimiter=', ')
plt.plot(rho, n_i)

# %% [markdown]
# # Outer plate

# %%
# total convective and conductive heat flux
# 2nd char: e for energy n for particle
bbb.fqp=0
bbb.plateflux(); #internally calculated fluxes (postprocessing)

plt.figure()
fig, axs = plt.subplot_mosaic(
    [['TopLeft', 'TopRight'],
     ['Bottom', 'Bottom']],
    layout='constrained',  # Automatically adjust layout
    width_ratios=[1, 1],   # Equal width for the top plots
)
fig.suptitle('Outer heat fluxes')
fig.supxlabel('Distance along outer plate (m)')
fig.supylabel('Heat flux (MW/m**2)')
# axs['TopRight'].set_xlabel("Distance along inner plate (m)")
#axs['TopRight'].set_ylabel("feex (W)")
axs['TopRight'].set_title("Electrons")
axs['TopRight'].plot(com.yyrb[1:-1],bbb.sderb[1:-1,0]*1e-6)

# axs['TopLeft'].set_xlabel("Distance along inner plate (m)")
# axs['TopLeft'].set_ylabel("Heat flux (MW/m**2)")
axs['TopLeft'].set_title("Ions/Atoms")
axs['TopLeft'].plot(com.yyrb[1:-1],bbb.sdirb[1:-1,0]*1e-6) #polodal east field area


# axs['Bottom'].set_xlabel("Distance along inner plate (m)")
# axs['Bottom'].set_ylabel("Heat flux [MW/m**2]")
axs['Bottom'].set_title("Particle+radiation heat flux")
axs['Bottom'].plot(com.yyrb,1.e-6*(bbb.sdtrb+bbb.sdrrb))
plt.show()
max(1.e-6*(bbb.sdtrb+bbb.sdrrb))

import numpy as np

# Save particle + radiation heat flux data
x = com.yyrb  # distance along inner plate
q = 1.e-6 * (bbb.sdtrb + bbb.sdrrb)  # convert to MW/m^2

data = np.column_stack((x, q))
np.savetxt("outer_plate_heat_flux.txt", data, header="Distance_along_plate(m) Heat_flux(MW/m^2)", fmt="%.6e")

# %%
np.sum( (bbb.sdtrb+bbb.sdrrb)) / 1e6
# Out:
# np.float64(25.673051490542424)

# %% [markdown]
# # 2D Plots

# %%
plt.figure()

c.plot.grid(linewidth=0.1, #grid plot
   vessel=True, 
   plates=True, 
   platecolor=['gold','teal'], 
   lcfs=True, 
   xlim=(1.8, 2.8), 
   ylim=(0.1,0.85),
   lcfscolor='r', 
   linecolor='b',
   title='Mesh grid'
  );

c.plot.mesh(
    bbb.ne, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85),
    figsize=(7,5), 
    zrange=(1e8,1e21), 
    cmap='gist_heat',
    title='Electron density'
);


c.plot.mesh(
    abs(bbb.feex), 
    log=True,
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    zrange=(1,1e6),
    cmap='inferno',
    title='Electron heat (W)'
);
c.plot.mesh(
    bbb.te/bbb.ev, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    # zrange=(-5e5,5e5),
    cmap='seismic',
    title='Electron temperature (eV)'
);

c.plot.mesh(
    bbb.ne, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85),
    figsize=(7,5), 
    zrange=(1e10,1e22), 
    cmap='gist_heat',
    title='Ion density'
);
c.plot.mesh(
    bbb.feix, 
    # xlim=(1.8, 2.8), 
    # ylim=(0.1,0.85),
    figsize=(7,5), 
    # zrange=(-8e5,8e5),
    cmap='seismic',
    title='Ion heat (W)'
);
c.plot.mesh(
    bbb.te/bbb.ev, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    # zrange=(-5e5,5e5),
    cmap='seismic',
    title='Ion temperature (eV)'
);
c.plot.mesh(
    bbb.na, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    # zrange=(-5e5,5e5),
    cmap='seismic',
    title='Impurity concentration (m^-3)'
);
c.plot.mesh(
    bbb.prad, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    # zrange=(-5e5,5e5),
    cmap='seismic',
    title='Power Radiation'
);
plt.show()

# %%
c.dashboard() # a GUI with all the most common variable
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 c.dashboard()
#
# File /opt/anaconda3/lib/python3.12/site-packages/uetools/UeCase/Case.py:757, in Case.dashboard(self)
#     754 import sys
#     756 app = QApplication([])
# --> 757 win = StandaloneDashboard(self)
#     758 win.show()
#     759 app.exec_()
#
# File /opt/anaconda3/lib/python3.12/site-packages/uetools/UeDashboard/Dashboard.py:1610, in StandaloneDashboard.__init__(self, case, parent)
#    1607 self.resize(1250, 850)
#    1609 self.statusbar = self.statusBar()
# -> 1610 self.centralWidget =  CaseDashboard(self.case)
#    1611 self.centralWidget.setMinimumWidth(1250)
#    1612 self.centralWidget.setMinimumHeight(850)
#
# File /opt/anaconda3/lib/python3.12/site-packages/uetools/UeDashboard/Dashboard.py:458, in CaseDashboard.__init__(self, case, parent)
#     455 self.file = case.info['filename']
#     457 self.centralWidget = QWidget(self)
# --> 458 self.caseplot = HeatmapInteractiveFigure(case)
#     459 # Cannibalize Case functions
#     460 self.inplace = case.info['inplace']
#
# File /opt/anaconda3/lib/python3.12/site-packages/uetools/UeDashboard/Dashboard.py:1164, in HeatmapInteractiveFigure.__init__(self, case, parent)
#    1162 self.case = case
#    1163 self.case.plot.te2D(ax=self.canvas.axes)
# -> 1164 self.case.about.set_speciesarrays()
#    1165 self.verts = self.case.plot.Qvertices
#    1167 self._createSlider()
#
# File /opt/anaconda3/lib/python3.12/site-packages/uetools/UeUtils/AboutSetup.py:117, in AboutSetup.set_speciesarrays(self)
#     112 for i in range(nisp):
#     113     charge = "{}".format(
#     114         ("+" + str(int(zi[i]))) * (zi[i] > 0) + "0" * (zi[i] == 0)
#     115     )
#     116     sign = "".join(
# --> 117         (x for x in elements[znuclin[i]][minu[i]] if not x.isdigit())
#     118     )
#     119     ionarray.append("{}{}".format(sign, charge))  # .center(5))
#     120 for i in range(nhsp - 1):
#
# KeyError: 2.5

# %% [markdown]
# # Zeff

# %%
# Zeff=Sum(n_i*Z_i^2)/ne.  
# For n_i use your main ion and n_Ne. 
# Calculate them using quasi neutrality and your impurity fraction 
nD = bbb.ni.transpose()
nT = nD[1] # deut density - atomic density
nD = nD[0] # deut density - ion density
nT = nT.transpose()
nD = nD.transpose()
zeff = (nT+nD+(bbb.na*100))/bbb.ne
c.plot.mesh(
    zeff, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    zrange=(1,10),
    cmap='seismic',
    title='Impurity concentration (m^-3)'
);
y = zeff[17:41,2]

print(f'Zeff computational val: {y[0]}, basic calc at core-edge from Andreas: {1+bbb.afracs[0][0]*100}')
# Out:
# Zeff computational val: 3.1000000413351194, basic calc at core-edge from Andreas: 3.1

# %% [markdown]
# # Power Calculations

# %%
c = Case('reconverged_v12_p3.93_n2.38_imp5e3_dp0.06_kep0.06_kip0.06_last_ii2.hdf5')
# Out:
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../jupyter/MANTA_final_baseline/reconverged_v12_p3.93_n2.38_imp5e3_dp0.06_kep0.06_kip0.06_last_ii2.hdf5
#   User-specified diffusivities read from HDF5 file ".../jupyter/MANTA_final_baseline/reconverged_v12_p3.93_n2.38_imp5e3_dp0.06_kep0.06_kip0.06_last_ii2.hdf5"
# UETOOLS-style save successfully restored from .../jupyter/MANTA_final_baseline/reconverged_v12_p3.93_n2.38_imp5e3_dp0.06_kep0.06_kip0.06_last_ii2.hdf5
# *** For isimpon=2, set afracs, not afrac ***
#
# *** UEDGE arrays populated: Warning, case may noy be fully converged ***
# fnrm without preconditioning: 94.4

# %%
from scipy.integrate import simpson
bbb.fqp=0
bbb.plateflux();

pcore = simpson( (bbb.feiy+bbb.feey)[com.ixpt1[0]+1:com.ixpt2[0]+1,0]) / 1e6
psep = simpson( (bbb.feiy+bbb.feey)[com.ixpt1[0]+1:com.ixpt2[0]+1,com.iysptrx]) / 1e6

print(f' Power from core boundary (surface closest to magnetic axis) = {pcore:.3f} MW  \n \
Power at Separatrix = {psep:.3f} MW  \n \
Power radiated in core region = {(pcore-psep):.3f} MW = {((abs(pcore-psep)/pcore)*100):3f}%')
particlecore = simpson( (bbb.fniy)[com.ixpt1[0]+1:com.ixpt2[0],0])

pleft = simpson( (bbb.feiy+bbb.feey)[com.ixpt1[0]+1:32,com.iysptrx]) / 1e6
pright = simpson( (bbb.feiy+bbb.feey)[32:com.ixpt2[0]+1,com.iysptrx]) / 1e6
print(f'From LCFS, {(pright/pleft):.3f} times more power going out into high field side than low field side\n Left:{pleft} MW | Right: {pright} MW')
# Out:
#  Power from core boundary (surface closest to magnetic axis) = 6.845 MW
#  Power at Separatrix = 4.122 MW
#  Power radiated in core region = 2.723 MW = 39.782568%
# From LCFS, 1.397 times more power going out into high field side than low field side
#  Left:1.5897706945960914 MW | Right: 2.220426368865259 MW

# %%
impFracs = [1e-4, 3e-3, 3e-2]
pRads = [33.11, 33.9, 42.5]

# %%
c.search.var("ne")
# bbb.turb_chi()
bbb.up
# Out:
# Package:    bbb
# Group:      Compla
# Attributes: Compla
# Dimension:  (0:nx+1,0:ny+1)
#             (66, 46)
# Type:       double
# Address:    5118312960
# Pyaddress:  4676056336
# Unit:       m^-3
# Comment:
# electron dens in primary cell (ix,iy)
# array([[[-10855.51639259, -11431.43962379],
#         [-11971.11898326, -11372.56303412],
#         [-12063.32995936, -11460.16346141],
#         ...,
#         [-16742.86949573, -15905.72602096],
#         [-16736.78214279, -15899.94303563],
#         [-17113.88306861, -15894.80316941]],
#
#        [[ -9739.91380191, -11490.31621345],
#         [-11658.821658  , -11478.05857042],
#         [-11487.48532541, -11705.64496157],
#         ...,
#         [-16740.40383117, -15901.76312305],
#         [-16736.45900437, -15893.95033633],
#         [-17490.98399448, -15889.66330317]],
#
#        [[ -9775.39927487, -11943.00668698],
#         [-11473.56998083, -12050.62901481],
#         [-11237.46029189, -12474.12169535],
#         ...,
#         [-16733.06424669, -15895.77674864],
#         [-16735.26961347, -15887.54006081],
#         [-17451.30107602, -15883.59246353]],
#
#        ...,
#
#        [[  7885.9473896 ,   9847.58153258],
#         [  9934.65902927,   9784.36208432],
#         [  9136.08665206,   9007.2762516 ],
#         ...,
#         [ 11879.35905299,  11355.01421358],
#         [ 11918.64525057,  11336.19924488],
#         [ 12358.25720117,  11322.07147967]],
#
#        [[  9168.04253666,   9887.60616604],
#         [ 10450.13768373,   9927.63079954],
#         [  9533.61263481,   9056.93200307],
#         ...,
#         [ 11972.17008938,  11373.56158492],
#         [ 11954.03353185,  11356.33185525],
#         [ 12156.14536652,  11339.2016675 ]],
#
#        [[  9168.04253666,   9887.60616604],
#         [ 10450.13768373,   9927.63079953],
#         [  9533.61263481,   9056.93200306],
#         ...,
#         [ 11972.17008938,  11373.56158492],
#         [ 11954.03353185,  11356.33185525],
#         [ 12156.14536652,  11339.2016675 ]]])

# %%
len(bbb.te[28])
# Out:
# 46
