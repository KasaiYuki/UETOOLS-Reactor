# %%
import plot_sinksource
import importlib
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from uedge import *
from uedge.hdf5 import *
#import plotmesh as pm
from uetools import Case
from uedge.gridue import write_gridue
from Forthon import gchange
c = Case('input.yaml')
importlib.reload(plot_sinksource)
c.populate()
plot_sinksource.plot_sinksource(c)
# Out:
# No diffusivity-file supplied: reading from save-file ".../MANTA_final_baseline/neon_lowseed/neon.hdf5"
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/neon_lowseed/neon.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/neon_lowseed/neon.hdf5
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 1.09e-01
#
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 1.09e-01
#
# 8.082800543002101e+20 0.0
