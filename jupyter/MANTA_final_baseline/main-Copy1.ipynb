# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from uedge import *
from uedge.hdf5 import *
#import plotmesh as pm
from uetools import Case
from uedge.gridue import write_gridue
from Forthon import gchange
# Out:
# UEDGE configuration file /Users/eliotfelske/.uetoolsrc read.

# %% [markdown]
# # Create Case from YAML

# %%
#c = Case('v9_te1000_pi900_n2e20_imp0_last_ii2.hdf5') IGNORE
#c = Case('reconverged_v12_vert_dif1_last_ii2.hdf5')
c = Case('input_v12_dif.yaml')
print("dif_use, kye_use, kyi_use around SOL:", bbb.dif_use[30, :, 0][1], bbb.kye_use[30, :][1], bbb.kyi_use[30, :][1])
# Out:
# No diffusivity-file supplied: reading from save-file ".../jupyter/MANTA_final_baseline/reconverged_v12_p_last_ii2.hdf5"
#   User-specified diffusivities read from HDF5 file ".../jupyter/MANTA_final_baseline/reconverged_v12_p_last_ii2.hdf5"
# UETOOLS-style save successfully restored from .../jupyter/MANTA_final_baseline/reconverged_v12_p_last_ii2.hdf5
#
# *** UEDGE arrays populated: WARNING, case NOT converged ***
# fnrm without preconditioning: 1.90e+04
#
# dif_use, kye_use, kyi_use around SOL: 0.051 0.06 0.1

# %%
bbb.GridFileName = 'gridmorph2/SUCCESS.hdf5'

# %%
c.populate()
# Out:
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#
# *** UEDGE arrays populated: WARNING, case NOT converged ***
# fnrm without preconditioning: 7.19e+08

# %%
c_dif = 0.05
c_kye = 0.06
c_kyi = 0.1

bbb.dif_use[30,:,0] = [c_dif] * 46
bbb.dif_use[29,:,0] = [c_dif] * 46
bbb.dif_use[28,:,0] = [c_dif] * 46
bbb.dif_use[27,:,0] = [c_dif] * 46
bbb.dif_use[26,:,0] = [c_dif] * 46
bbb.dif_use[25,:,0] = [c_dif] * 46
bbb.dif_use[24,:,0] = [c_dif] * 46
bbb.dif_use[23,:,0] = [c_dif] * 46
bbb.dif_use[22,:,0] = [c_dif] * 46
bbb.dif_use[21,:,0] = [c_dif] * 46
bbb.dif_use[20,:,0] = [c_kye] * 46
bbb.dif_use[19,:,0] = [c_dif] * 46
bbb.dif_use[18,:,0] = [c_dif] * 46
bbb.dif_use[17,:,0] = [c_dif] * 46
bbb.dif_use[31,:,0] = [c_dif] * 46
bbb.dif_use[32,:,0] = [c_dif] * 46
bbb.dif_use[33,:,0] = [c_dif] * 46
bbb.dif_use[34,:,0] = [c_dif] * 46
bbb.dif_use[35,:,0] = [c_dif] * 46
bbb.dif_use[36,:,0] = [c_dif] * 46

bbb.kye_use[30,:] = [c_kye] * 46
bbb.kye_use[29,:] = [c_kye] * 46
bbb.kye_use[28,:] = [c_kye] * 46
bbb.kye_use[27,:] = [c_kye] * 46
bbb.kye_use[26,:] = [c_kye] * 46
bbb.kye_use[25,:] = [c_kye] * 46
bbb.kye_use[24,:] = [c_kye] * 46
bbb.kye_use[23,:] = [c_kye] * 46
bbb.kye_use[22,:] = [c_kye] * 46
bbb.kye_use[21,:] = [c_kye] * 46
bbb.kye_use[20,:] = [c_kye] * 46
bbb.kye_use[19,:] = [c_kye] * 46
bbb.kye_use[18,:] = [c_kye] * 46
bbb.kye_use[17,:] = [c_kye] * 46
bbb.kye_use[31,:] = [c_kye] * 46
bbb.kye_use[32,:] = [c_kye] * 46
bbb.kye_use[33,:] = [c_kye] * 46
bbb.kye_use[34,:] = [c_kye] * 46
bbb.kye_use[35,:] = [c_kye] * 46
bbb.kye_use[36,:] = [c_kye] * 46

bbb.kyi_use[30,:] = [c_kyi] * 46
bbb.kyi_use[29,:] = [c_kyi] * 46
bbb.kyi_use[28,:] = [c_kyi] * 46
bbb.kyi_use[27,:] = [c_kyi] * 46
bbb.kyi_use[26,:] = [c_kyi] * 46
bbb.kyi_use[25,:] = [c_kyi] * 46
bbb.kyi_use[24,:] = [c_kyi] * 46
bbb.kyi_use[23,:] = [c_kyi] * 46
bbb.kyi_use[22,:] = [c_kyi] * 46
bbb.kyi_use[21,:] = [c_kyi] * 46
bbb.kyi_use[20,:] = [c_kyi] * 46
bbb.kyi_use[19,:] = [c_kyi] * 46
bbb.kyi_use[18,:] = [c_kyi] * 46
bbb.kyi_use[17,:] = [c_kyi] * 46
bbb.kyi_use[31,:] = [c_kyi] * 46
bbb.kyi_use[32,:] = [c_kyi] * 46
bbb.kyi_use[33,:] = [c_kyi] * 46
bbb.kyi_use[34,:] = [c_kyi] * 46
bbb.kyi_use[35,:] = [c_kyi] * 46
bbb.kyi_use[36,:] = [c_kyi] * 46

c.plot.mesh(bbb.dif_use[:,:,0])
c.plot.mesh(bbb.kye_use[:,:])
c.plot.mesh(bbb.kyi_use[:,:])

#indexing first index from 1 starts at the inner plate moving upward with index number, starting at
#Core boundary indicies: HFS: 17-30, LFS: 31-40
#kye biases heat outer plate, dif is more inner plate and has more of an effecto on midplane temps

#for ix in range(com.ixpt1[0]+1,com.ixpt2[0]: bbb.dif_use[ix,:,0]= [0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5]
#len bbb.dif_use[#,:,0] = 46

#for ix in range(com.ixpt1[0] + 1, com.ixpt2[0]):
    #print(bbb.dif_use[ix,:,0])

# %%
from plot_sinksource import plot_sinksource
plot_sinksource(c)

# %% [markdown]
# # Converge

# %%
import subprocess
bbb.isbcwdt=0
proc = subprocess.Popen(['caffeinate'])

try:
    c.converge(savefname='reconverged_v12_p398', dtreal=1e-10)
    os.system("printf '\7'") #macos plays sound after converging
finally:
    # Terminate caffeinate
    proc.terminate()
# Out:
# Requested save-path ../solutions not found, writing to cwd!
# *----------------------------------------------------------*
#  Need to take initial step with Jacobian; trying to do here
# *----------------------------------------------------------*
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.9861287459456329E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1488921979863372E-05 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ---------------------------------------------------------------
# *** Number of time-step changes = 1 New time-step: 1.00E-10 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837596985941080E-02 nfe=      1
#  iter=    1 fnrm=     0.5495841518514756E-07 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837594814194862E-02 nfe=      1
#  iter=    1 fnrm=     0.5467699103210743E-07 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 1.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #2
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837592317239228E-02 nfe=      1
#  iter=    1 fnrm=     0.5468341114156433E-07 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 2.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #3
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837589828050475E-02 nfe=      1
#  iter=    1 fnrm=     0.5468054396127017E-07 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 3.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #4
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837587345999685E-02 nfe=      1
#  iter=    1 fnrm=     0.5468679246691742E-07 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 4.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #5
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837584870537474E-02 nfe=      1
#  iter=    1 fnrm=     0.5468689535461749E-07 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 5.0000E-10; Timestep = 1.0000E-10
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 2 New time-step: 3.40E-10 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.8837582678277296E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1574499875177528E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837575302747957E-02 nfe=      1
#  iter=    1 fnrm=     0.1567078065671414E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 9.4000E-10; Timestep = 3.4000E-10
#
#  Inner iteration #2
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837567008718093E-02 nfe=      1
#  iter=    1 fnrm=     0.1567095121769447E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 1.2800E-09; Timestep = 3.4000E-10
#
#  Inner iteration #3
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837558755104237E-02 nfe=      1
#  iter=    1 fnrm=     0.1567071175489062E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 1.6200E-09; Timestep = 3.4000E-10
#
#  Inner iteration #4
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837550535891131E-02 nfe=      1
#  iter=    1 fnrm=     0.1567052190330640E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 1.9600E-09; Timestep = 3.4000E-10
#
#  Inner iteration #5
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837542346387358E-02 nfe=      1
#  iter=    1 fnrm=     0.1567026964726490E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 2.3000E-09; Timestep = 3.4000E-10
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 3 New time-step: 1.16E-09 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837534182877620E-02 nfe=      1
#  iter=    1 fnrm=     0.1676366913051029E-06 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837502596403606E-02 nfe=      1
#  iter=    1 fnrm=     0.2548928935643192E-07 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 3.7960E-09; Timestep = 1.1560E-09
#
#  Inner iteration #2
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837477867234182E-02 nfe=      1
#  iter=    1 fnrm=     0.1921253373023591E-07 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 4.9520E-09; Timestep = 1.1560E-09
#
#  Inner iteration #3
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837450611480164E-02 nfe=      1
#  iter=    1 fnrm=     0.1511838428213485E-07 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 6.1080E-09; Timestep = 1.1560E-09
#
#  Inner iteration #4
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837423468012074E-02 nfe=      1
#  iter=    1 fnrm=     0.1236809089826369E-07 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 7.2640E-09; Timestep = 1.1560E-09
#
#  Inner iteration #5
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837396427771866E-02 nfe=      1
#  iter=    1 fnrm=     0.1044543045779341E-07 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 8.4200E-09; Timestep = 1.1560E-09
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 4 New time-step: 3.93E-09 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.8837372806599362E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.7072642273238850E-07 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837282036109168E-02 nfe=      1
#  iter=    1 fnrm=     0.7073657304837338E-07 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 1.3506E-08; Timestep = 3.9304E-09
#
#  Inner iteration #2
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837191809704622E-02 nfe=      1
#  iter=    1 fnrm=     0.7074590972026583E-07 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 1.7437E-08; Timestep = 3.9304E-09
#
#  Inner iteration #3
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837102228223381E-02 nfe=      1
#  iter=    1 fnrm=     0.7092653157147126E-07 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 2.1367E-08; Timestep = 3.9304E-09
#
#  Inner iteration #4
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8837013221421303E-02 nfe=      1
#  iter=    1 fnrm=     0.7439281427328192E-07 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 2.5298E-08; Timestep = 3.9304E-09
#
#  Inner iteration #5
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8836924742309300E-02 nfe=      1
#  iter=    1 fnrm=     0.1363227478806371E-06 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 2.9228E-08; Timestep = 3.9304E-09
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 5 New time-step: 1.34E-08 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8836836921845632E-02 nfe=      1
#  iter=    1 fnrm=     0.8403761848217020E-07 nfe=      7
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8836540734494970E-02 nfe=      1
#  iter=    1 fnrm=     0.1666183062914755E-06 nfe=      7
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 4.6522E-08; Timestep = 1.3363E-08
#
#  Inner iteration #2
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8836249003668575E-02 nfe=      1
#  iter=    1 fnrm=     0.2140221616561327E-06 nfe=      7
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 5.9885E-08; Timestep = 1.3363E-08
#
#  Inner iteration #3
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8835960555990726E-02 nfe=      1
#  iter=    1 fnrm=     0.1740371093116780E-06 nfe=      9
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 7.3248E-08; Timestep = 1.3363E-08
#
#  Inner iteration #4
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8835674856023126E-02 nfe=      1
#  iter=    1 fnrm=     0.1228443335107076E-06 nfe=      9
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 8.6612E-08; Timestep = 1.3363E-08
#
#  Inner iteration #5
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8835391755311924E-02 nfe=      1
#  iter=    1 fnrm=     0.2102360388080576E-06 nfe=      7
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 9.9975E-08; Timestep = 1.3363E-08
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 6 New time-step: 4.54E-08 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.8835150159319271E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1320082831309969E-06 nfe=      9
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8834209442764147E-02 nfe=      1
#  iter=    1 fnrm=     0.2099001033109200E-06 nfe=     10
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 1.5877E-07; Timestep = 4.5435E-08
#
#  Inner iteration #2
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8833284706361352E-02 nfe=      1
#  iter=    1 fnrm=     0.1507303755848735E-06 nfe=     10
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 2.0421E-07; Timestep = 4.5435E-08
#
#  Inner iteration #3
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8832372272331052E-02 nfe=      1
#  iter=    1 fnrm=     0.2100145570070567E-06 nfe=     10
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 2.4964E-07; Timestep = 4.5435E-08
#
#  Inner iteration #4
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8831469782613576E-02 nfe=      1
#  iter=    1 fnrm=     0.1070481163382769E-06 nfe=     11
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 2.9508E-07; Timestep = 4.5435E-08
#
#  Inner iteration #5
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8830575050932097E-02 nfe=      1
#  iter=    1 fnrm=     0.1924592722858594E-06 nfe=      8
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 3.4052E-07; Timestep = 4.5435E-08
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 7 New time-step: 1.54E-07 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8829686948191072E-02 nfe=      1
#  iter=    1 fnrm=     0.1917332021691258E-06 nfe=     19
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8826683125432319E-02 nfe=      1
#  iter=    1 fnrm=     0.2614227796634414E-06 nfe=     17
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 5.4043E-07; Timestep = 1.5448E-07
#
#  Inner iteration #2
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8823718245476113E-02 nfe=      1
#  iter=    1 fnrm=     0.2341882616011185E-06 nfe=     19
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 6.9491E-07; Timestep = 1.5448E-07
#
#  Inner iteration #3
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8820781924593062E-02 nfe=      1
#  iter=    1 fnrm=     0.2477859045574243E-06 nfe=     22
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 8.4939E-07; Timestep = 1.5448E-07
#
#  Inner iteration #4
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8817868923218303E-02 nfe=      1
#  iter=    1 fnrm=     0.2443250359080949E-06 nfe=     23
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 1.0039E-06; Timestep = 1.5448E-07
#
#  Inner iteration #5
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8814976381795956E-02 nfe=      1
#  iter=    1 fnrm=     0.2068840598156506E-06 nfe=     23
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 1.1584E-06; Timestep = 1.5448E-07
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 8 New time-step: 5.25E-07 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.8812552602123670E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.2232324654850306E-06 nfe=     35
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8802794665256483E-02 nfe=      1
#  iter=    1 fnrm=     0.2087297183306092E-06 nfe=     40
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 1.8381E-06; Timestep = 5.2523E-07
#
#  Inner iteration #2
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8793275405844642E-02 nfe=      1
#  iter=    1 fnrm=     0.2153192736917164E-06 nfe=     41
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 2.3633E-06; Timestep = 5.2523E-07
#
#  Inner iteration #3
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8783982188775715E-02 nfe=      1
#  iter=    1 fnrm=     0.2163938887970275E-06 nfe=     41
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 2.8885E-06; Timestep = 5.2523E-07
#
#  Inner iteration #4
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8774934760648301E-02 nfe=      1
#  iter=    1 fnrm=     0.2358964004162431E-06 nfe=     43
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 3.4138E-06; Timestep = 5.2523E-07
#
#  Inner iteration #5
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8766124352631575E-02 nfe=      1
#  iter=    1 fnrm=     0.4308757256511934E-06 nfe=     42
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 3.9390E-06; Timestep = 5.2523E-07
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 9 New time-step: 1.79E-06 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8757567039477580E-02 nfe=      1
#  iter=    1 fnrm=     0.5365472990931490E-04 nfe=     71
#  iter=    2 fnrm=     0.1026747782402100E-05 nfe=    195
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8730525064026422E-02 nfe=      1
#  iter=    1 fnrm=     0.9781214193436200E-04 nfe=     71
#  iter=    2 fnrm=     0.7579295891760645E-05 nfe=    187
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 6.2500E-06; Timestep = 1.7858E-06
#
#  Inner iteration #2
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8707152827324418E-02 nfe=      1
#  iter=    1 fnrm=     0.4351825725809323E-02 nfe=     74
#  iter=    2 fnrm=     0.2510467080724547E-02 nfe=    155
#  iter=    3 fnrm=     0.7403349701327878E-03 nfe=    233
#  iter=    4 fnrm=     0.1472824951639104E-03 nfe=    320
#  iter=    5 fnrm=     0.1389491389970185E-05 nfe=    422
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 8.0358E-06; Timestep = 1.7858E-06
#
#  Inner iteration #3
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8697531484836377E-02 nfe=      1
#  Total time = 8.0358E-06; Timestep = 1.7858E-06
#
#  iter=    1 fnrm=     0.1437047007861270E-02 nfe=     73
#  iter=    2 fnrm=     0.1191308127215486E-02 nfe=    165
#  iter=    3 fnrm=     0.1023084646289473E-02 nfe=    254
#  iter=    4 fnrm=     0.5142735424251766E-03 nfe=    335
#  iter=    5 fnrm=     0.5427021251167866E-03 nfe=    440
#  iter=    6 fnrm=     0.4407115665644521E-03 nfe=    527
#  iter=    7 fnrm=     0.4692385691295587E-03 nfe=    634
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
# ** Fortran index of trouble making equation is:
# 18170
# ** Number of equations solved per cell:
#     numvar = 6
#
# ** Troublemaker equation is:
# Ion density equation of species 2: iv_t=2
#
# ** Troublemaker cell (ix,iy) is:
# [58 45]
#
# ** Timestep for troublemaker equation:
# 1.7858e-06
#
# ** yl for troublemaker equation:
# 4.1920e-02
#
# ** yldot*sfscal for troublemaker equation:
# 1.9835e-04
#
# *** Converg. fails for bbb.dtreal; reduce time-step by 3, try again ***
# -----------------------------------------------------------------------
# ----------------------------------------------------------------
# *** Number of time-step changes = 10 New time-step: 5.95E-07 ***
# ----------------------------------------------------------------
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8697531484836377E-02 nfe=      1
#  iter=    1 fnrm=     0.5353021805528674E-03 nfe=     54
#  iter=    2 fnrm=     0.3878968550523660E-04 nfe=    141
#  iter=    3 fnrm=     0.1458830933879561E-06 nfe=    240
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8790135423931965E-02 nfe=      1
#  iter=    1 fnrm=     0.5388663347921625E-02 nfe=     58
#  iter=    2 fnrm=     0.5573281838764166E-02 nfe=    127
#  iter=    3 fnrm=     0.6702678257104600E-03 nfe=    187
#  iter=    4 fnrm=     0.1519998157041138E-03 nfe=    280
#  iter=    5 fnrm=     0.5629490667938957E-06 nfe=    374
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 1.0417E-05; Timestep = 5.9526E-07
#
#  Inner iteration #2
#
# ...
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2802109712936843E-01 nfe=      1
#  Total time = 9.7255E-04; Timestep = 1.7614E-06
#
#  iter=    1 fnrm=     0.6153283223449603E-02 nfe=    136
#  iter=    2 fnrm=     0.3241505056227186E-02 nfe=    271
#  iter=    3 fnrm=     0.2823326864034221E-02 nfe=    406
#  iter=    4 fnrm=     0.8889740639123096E-03 nfe=    541
#  iter=    5 fnrm=     0.7794080453602427E-03 nfe=    679
#  iter=    6 fnrm=     0.7451486915428977E-03 nfe=    818
#  iter=    7 fnrm=     0.7055992823134468E-03 nfe=    957
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
# ** Fortran index of trouble making equation is:
# 17748
# ** Number of equations solved per cell:
#     numvar = 6
#
# ** Troublemaker equation is:
# Ion energy equation: iv_t=6
#
# ** Troublemaker cell (ix,iy) is:
# [53 44]
#
# ** Timestep for troublemaker equation:
# 1.7614e-06
#
# ** yl for troublemaker equation:
# 1.0930e-01
#
# ** yldot*sfscal for troublemaker equation:
# -2.6323e-04
#
# *** Converg. fails for bbb.dtreal; reduce time-step by 3, try again ***
# -----------------------------------------------------------------------
# -----------------------------------------------------------------
# *** Number of time-step changes = 170 New time-step: 5.87E-07 ***
# -----------------------------------------------------------------
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.2723067301116682E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1386794063461655E-02 nfe=     62
#  iter=    2 fnrm=     0.2427312828413006E-04 nfe=    146
#  iter=    3 fnrm=     0.2757948803005283E-06 nfe=    262
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2772836921052850E-01 nfe=      1
#  iter=    1 fnrm=     0.1363307198705705E-02 nfe=     62
#  iter=    2 fnrm=     0.6486565189373465E-03 nfe=    140
#  iter=    3 fnrm=     0.8987298645434782E-04 nfe=    233
#  iter=    4 fnrm=     0.5822245128465679E-05 nfe=    342
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 9.7490E-04; Timestep = 5.8714E-07
#
#  Inner iteration #2
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2832409889549026E-01 nfe=      1
#  iter=    1 fnrm=     0.1797195775165028E-02 nfe=     65
#  iter=    2 fnrm=     0.9930273755040639E-04 nfe=    149
#  iter=    3 fnrm=     0.8564987249516592E-06 nfe=    272
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 9.7549E-04; Timestep = 5.8714E-07
#
#  Inner iteration #3
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2858652884163110E-01 nfe=      1
#  iter=    1 fnrm=     0.3171363315757607E-02 nfe=     71
#  iter=    2 fnrm=     0.2893938287904541E-03 nfe=    163
#  iter=    3 fnrm=     0.7692687153149580E-05 nfe=    279
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 9.7607E-04; Timestep = 5.8714E-07
#
#  Inner iteration #4
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2853051672505504E-01 nfe=      1
#  iter=    1 fnrm=     0.8953930207433763E-02 nfe=     86
#  iter=    2 fnrm=     0.6023289351168236E-03 nfe=    170
#  iter=    3 fnrm=     0.1505480847138490E-04 nfe=    274
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 9.7666E-04; Timestep = 5.8714E-07
#
#  Inner iteration #5
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2813549270999736E-01 nfe=      1
#  iter=    1 fnrm=     0.8533844402101993E-02 nfe=     76
#  iter=    2 fnrm=     0.1400781004398069E-03 nfe=    171
#  iter=    3 fnrm=     0.8327706298991680E-06 nfe=    291
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 9.7725E-04; Timestep = 5.8714E-07
#
# -----------------------------------------------------------------
# *** Number of time-step changes = 171 New time-step: 1.76E-06 ***
# -----------------------------------------------------------------
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2767510091316546E-01 nfe=      1
#  iter=    1 fnrm=     0.1913534883770443E-01 nfe=    105
#  iter=    2 fnrm=     0.2323017810367286E-02 nfe=    218
#  iter=    3 fnrm=     0.3445869240384173E-03 nfe=    347
#  iter=    4 fnrm=     0.2688505061962206E-06 nfe=    481
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2468950627540139E-01 nfe=      1
#  iter=    1 fnrm=     0.2107644892020739E-01 nfe=    114
#  iter=    2 fnrm=     0.1122495024198629E-02 nfe=    238
#  iter=    3 fnrm=     0.1712051290339305E-04 nfe=    373
#  iter=    4 fnrm=     0.7069638633058293E-08 nfe=    508
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 9.7960E-04; Timestep = 1.7614E-06
#
#  Inner iteration #2
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2210105264612459E-01 nfe=      1
#  iter=    1 fnrm=     0.1014544025993664E-01 nfe=    112
#  iter=    2 fnrm=     0.2992387162038403E-03 nfe=    234
#  iter=    3 fnrm=     0.2068868407664262E-04 nfe=    369
#  iter=    4 fnrm=     0.1112177260804966E-06 nfe=    504
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 9.8136E-04; Timestep = 1.7614E-06
#
#  Inner iteration #3
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1979856592483270E-01 nfe=      1
#  iter=    1 fnrm=     0.5718865778356788E-02 nfe=    130
#  iter=    2 fnrm=     0.2830682149798516E-04 nfe=    260
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 9.8312E-04; Timestep = 1.7614E-06
#
#  Inner iteration #4
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1789639950694413E-01 nfe=      1
#  iter=    1 fnrm=     0.3379350963953554E-02 nfe=    130
#  iter=    2 fnrm=     0.1438974551920558E-04 nfe=    265
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 9.8488E-04; Timestep = 1.7614E-06
#
#  Inner iteration #5
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1635671599688520E-01 nfe=      1
#  iter=    1 fnrm=     0.2049231906410286E-02 nfe=    129
#  iter=    2 fnrm=     0.1530971796453436E-04 nfe=    264
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 9.8664E-04; Timestep = 1.7614E-06
#
# -----------------------------------------------------------------
# *** Number of time-step changes = 172 New time-step: 5.99E-06 ***
# -----------------------------------------------------------------
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1539055302108650E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.6165225359885563E-02 nfe=     73
#  iter=    2 fnrm=     0.4302920369244378E-03 nfe=    161
#  iter=    3 fnrm=     0.2206203514385947E-04 nfe=    296
#  iter=    4 fnrm=     0.1618196526211387E-08 nfe=    431
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1222718309147925E-01 nfe=      1
#  iter=    1 fnrm=     0.2399519017074615E-02 nfe=     80
#  iter=    2 fnrm=     0.2577706203665891E-03 nfe=    178
#  iter=    3 fnrm=     0.3520164032520755E-05 nfe=    313
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 9.9439E-04; Timestep = 5.9888E-06
#
#  Inner iteration #2
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1087712695751257E-01 nfe=      1
#  iter=    1 fnrm=     0.3334918099892308E-02 nfe=     84
#  iter=    2 fnrm=     0.2006738360338975E-03 nfe=    180
#  iter=    3 fnrm=     0.2154568236978752E-04 nfe=    315
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v12_p398_last_ii2.hdf5
#  Total time = 1.0004E-03; Timestep = 5.9888E-06
#
#  Inner iteration #3
#
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridue_v12_vertical.hdf5

# %%
c.solver.convergenceanalysis('reconverged_v9_integrated_puff2_last_ii2.hdf5');

# %% [markdown]
# # Inner plate

# %%
# %matplotlib widget
fig, axs = plt.subplot_mosaic(
    [['TopLeft', 'TopRight'],
     ['Bottom', 'Bottom']],
    layout='constrained',  # Automatically adjust layout
    width_ratios=[1, 1],   # Equal width for the top plots
)
fig.suptitle('Inner heat fluxes per area')
fig.supxlabel('Distance along inner plate (m)')
fig.supylabel('Heat flux (MW/m**2)')
# axs['TopRight'].set_xlabel("Distance along inner plate (m)")
#axs['TopRight'].set_ylabel("feex (W)")
axs['TopRight'].set_title("Electrons")
axs['TopRight'].plot(com.yylb[1:-1],-bbb.feex[0,1:-1]/com.sx[0,1:-1]*1e-6)

# axs['TopLeft'].set_xlabel("Distance along inner plate (m)")
# axs['TopLeft'].set_ylabel("Heat flux (MW/m**2)")
axs['TopLeft'].set_title("Ions/Atoms")
axs['TopLeft'].plot(com.yylb[1:-1],-bbb.feix[0,1:-1]/com.sx[0,1:-1]*1e-6) #polodal east field area

bbb.fqp=0
bbb.plateflux(); #internally calculated fluxes (postprocessing)
# axs['Bottom'].set_xlabel("Distance along inner plate (m)")
# axs['Bottom'].set_ylabel("Heat flux [MW/m**2]")
axs['Bottom'].set_title("Particle+radiation heat flux")
axs['Bottom'].plot(com.yylb,1.e-6*(bbb.sdtlb+bbb.sdrlb))
plt.show()

# %% [markdown]
# # Midplane

# %%
plt.xlabel("Distance from separatrix (m)")
plt.ylabel("ions/m^3")
plt.title("Ion density")
plt.plot(com.yylb[1:-1],bbb.ni[33,1:-1,0])
plt.show()
plt.xlabel("Distance from separatrix (m)")
plt.ylabel("eV")
plt.title("Ion temp")
plt.plot(com.yylb[1:-1],bbb.ti[33,1:-1]/bbb.ev)
plt.show()
plt.xlabel("Distance from separatrix (m)")
plt.ylabel("eV")
plt.title("Elc temp")
plt.plot(com.yylb[1:-1],bbb.te[33,1:-1]/bbb.ev)
plt.show()

#inner limit of dist. from separatrix should correspond with the rho coord of temp and n BC so rho * minor rad. (0.72m)
#rho=0.92

'''#for heat flux wall mapping fix with Filippo's method
plt.xlabel("Distance from separatrix (m)")
plt.ylabel("feix (W/m^2)")
plt.title("Ion temp * Bpol/Btot")
plt.plot(com.yylb[1:-1],bbb.ti[com.ixpt2[0],1:-1].T/bbb.ev*((com.bpol[com.ixpt2[0],1:-1,0]/com.b[com.ixpt2[0],1:-1,0])))
plt.show()
plt.xlabel("Distance from separatrix (m)")
plt.ylabel("feex (W/m^2)")
plt.title("Elc temp * Bpol/Btot")
plt.plot(com.yylb[1:-1],bbb.te[com.ixpt2[0],1:-1].T/bbb.ev*((com.bpol[com.ixpt2[0],1:-1,0]/com.b[com.ixpt2[0],1:-1,0])))
plt.show()'''
'''
#For length scale need real distance from separatrix at midplane

plt.xlabel("Distance from separatrix (m)")
plt.ylabel("ions/m^3")
plt.title("Ion density ixpt2")
plt.plot(com.yylb[1:-1],bbb.ni[com.ixpt2[0],1:-1])
plt.show()
'''
'''plt.xlabel("R (m)")
plt.ylabel("Ti (eV)")
plt.title("Ti at midplane (ixmp)")
plt.plot(rad,bbb.ti[bbb.ixmp,1:-1]/bbb.ev)
plt.show()'''
'''
rad = [arr[0] for arr in com.rm[bbb.ixmp, 1:-1]] #average index 2 and 4 for arr

plt.xlabel("R (m)")
plt.ylabel("Te (eV)")
plt.title("Te at midplane (ixmp)")
plt.plot(rad,bbb.te[bbb.ixmp,1:-1]/bbb.ev)
plt.show()
plt.xlabel("R (m)")
plt.ylabel("feex (W/m^2)")
plt.title("feex outer bound above x point (ixpt2)")
plt.plot(rad,bbb.feex[com.ixpt2[0],1:-1])
plt.show()

import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

def exponential_func(x, n, k):
    return np.exp(n - x / k)

x_data = rad
y_data = bbb.feex[com.ixpt2[0], 1:-1]

x_data_outward = x_data[17:30]
y_data_outward = y_data[17:30]

try:
    popt, pcov = curve_fit(exponential_func, x_data_outward, y_data_outward, p0=[np.log(y_data_outward[0]), 1], maxfev=10000)
    
    plt.xlabel("R (m)")
    plt.ylabel("feex (W/m^2)")
    plt.title("feex outer bound above x point (ixpt2)")
    plt.plot(x_data, y_data, label="Data")
    x_fit = np.linspace(min(x_data_outward), max(x_data_outward), 100)
    y_fit = exponential_func(x_fit, *popt)
    plt.plot(x_fit, y_fit, 'r--', label="Exponential Fit")
    plt.legend()
    plt.show()

except RuntimeError as e:
    print("Curve fitting did not converge:", e)

n_opt, k_opt = popt
print(f"Optimized n: {n_opt}")
print(f"Optimized k: {k_opt*1000}") 

bbb.afracs'''
# Out:
# '\nrad = [arr[0] for arr in com.rm[bbb.ixmp, 1:-1]] #average index 2 and 4 for arr\n\nplt.xlabel("R (m)")\nplt.ylabel("Te (eV)")\nplt.title("Te at midplane (ixmp)")\nplt.plot(rad,bbb.te[bbb.ixmp,1:-1]/bbb.ev)\nplt.show()\nplt.xlabel("R (m)")\nplt.ylabel("feex (W/m^2)")\nplt.title("feex outer bound above x point (ixpt2)")\nplt.plot(rad,bbb.feex[com.ixpt2[0],1:-1])\nplt.show()\n\nimport numpy as np\nfrom scipy.optimize import curve_fit\nimport matplotlib.pyplot as plt\n\ndef exponential_func(x, n, k):\n    return np.exp(n - x / k)\n\nx_data = rad\ny_data = bbb.feex[com.ixpt2[0], 1:-1]\n\nx_data_outward = x_data[17:30]\ny_data_outward = y_data[17:30]\n\ntry:\n    popt, pcov = curve_fit(exponential_func, x_data_outward, y_data_outward, p0=[np.log(y_data_outward[0]), 1], maxfev=10000)\n    \n    plt.xlabel("R (m)")\n    plt.ylabel("feex (W/m^2)")\n    plt.title("feex outer bound above x point (ixpt2)")\n    plt.plot(x_data, y_data, label="Data")\n    x_fit = np.linspace(min(x_data_outward), max(x_data_outward), 100)\n    y_fit = exponential_func(x_fit, *popt)\n    plt.plot(x_fit, y_fit, \'r--\', label="Exponential Fit")\n    plt.legend()\n    plt.show()\n\nexcept RuntimeError as e:\n    print("Curve fitting did not converge:", e)\n\nn_opt, k_opt = popt\nprint(f"Optimized n: {n_opt}")\nprint(f"Optimized k: {k_opt*1000}") \n\nbbb.afracs'

# %% [markdown]
# # Outer plate

# %%
# total convective and conductive heat flux
# 2nd char: e for energy n for particle
plt.figure()
fig, axs = plt.subplot_mosaic(
    [['TopLeft', 'TopRight'],
     ['Bottom', 'Bottom']],
    layout='constrained',  # Automatically adjust layout
    width_ratios=[1, 1],   # Equal width for the top plots
)
fig.suptitle('Outer heat fluxes per area')
fig.supxlabel('Distance along outer plate (m)')
fig.supylabel('Heat flux (MW/m**2)')
# axs['TopRight'].set_xlabel("Distance along inner plate (m)")
#axs['TopRight'].set_ylabel("feex (W)")
axs['TopRight'].set_title("Electrons")
axs['TopRight'].plot(com.yyrb[1:-1],bbb.feex[com.nx,1:-1]/com.sx[0,1:-1]*1e-6)

# axs['TopLeft'].set_xlabel("Distance along inner plate (m)")
# axs['TopLeft'].set_ylabel("Heat flux (MW/m**2)")
axs['TopLeft'].set_title("Ions/Atoms")
axs['TopLeft'].plot(com.yyrb[1:-1],bbb.feix[com.nx,1:-1]/com.sx[0,1:-1]*1e-6) #polodal east field area

bbb.fqp=0
bbb.plateflux(); #internally calculated fluxes (postprocessing)
# axs['Bottom'].set_xlabel("Distance along inner plate (m)")
# axs['Bottom'].set_ylabel("Heat flux [MW/m**2]")
axs['Bottom'].set_title("Particle+radiation heat flux")
axs['Bottom'].plot(com.yylb,1.e-6*(bbb.sdtrb+bbb.sdrrb))
plt.show()
max(1.e-6*(bbb.sdtrb+bbb.sdrrb))
# Out:
# array([21.88591257])

# %% [markdown]
# # 2D Plots

# %%
plt.figure()

c.plot.grid(linewidth=0.1, #grid plot
   vessel=True, 
   plates=True, 
   platecolor=['gold','teal'], 
   lcfs=True, 
   xlim=(1.8, 2.8), 
   ylim=(0.1,0.85),
   lcfscolor='r', 
   linecolor='b',
   title='Mesh grid'
  );

c.plot.mesh(
    bbb.ne, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85),
    figsize=(7,5), 
    zrange=(1e10,1e22), 
    cmap='gist_heat',
    title='Electron density'
);


c.plot.mesh(
    bbb.feex, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    # zrange=(-8e5,8e5),
    cmap='seismic',
    title='Electron heat (W)'
);
c.plot.mesh(
    bbb.te/bbb.ev, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    # zrange=(-5e5,5e5),
    cmap='seismic',
    title='Electron temperature (eV)'
);

c.plot.mesh(
    bbb.ne, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85),
    figsize=(7,5), 
    zrange=(1e10,1e22), 
    cmap='gist_heat',
    title='Ion density'
);
c.plot.mesh(
    bbb.feix, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85),
    figsize=(7,5), 
    # zrange=(-8e5,8e5),
    cmap='seismic',
    title='Ion heat (W)'
);
c.plot.mesh(
    bbb.te/bbb.ev, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    # zrange=(-5e5,5e5),
    cmap='seismic',
    title='Ion temperature (eV)'
);
plt.show()

# %%
c.dashboard() # a GUI with all the most common variable
# Out:
# /opt/anaconda3/envs/uedge_class/lib/python3.12/site-packages/uetools/UeDashboard/Dashboard.py:1068: SyntaxWarning: invalid escape sequence '\m'
#   'Total radiated power [W/m$\mathrm{{}^{-3}}$]',
# /opt/anaconda3/envs/uedge_class/lib/python3.12/site-packages/uetools/UeDashboard/Dashboard.py:1075: SyntaxWarning: invalid escape sequence '\m'
#   'Hydrogenic radiated power [W/m$\mathrm{{}^{-3}}$]',
# /opt/anaconda3/envs/uedge_class/lib/python3.12/site-packages/uetools/UeDashboard/Dashboard.py:1082: SyntaxWarning: invalid escape sequence '\m'
#   'Impurity radiated power [W/m$\mathrm{{}^{-3}}$]',
# /opt/anaconda3/envs/uedge_class/lib/python3.12/site-packages/uetools/UeDashboard/Dashboard.py:1817: SyntaxWarning: invalid escape sequence '\m'
#   for substr in ["$", "\mathrm", "{","}"]:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 c.dashboard()
#
# File /opt/anaconda3/envs/uedge_class/lib/python3.12/site-packages/uetools/UeCase/Case.py:757, in Case.dashboard(self)
#     754 import sys
#     756 app = QApplication([])
# --> 757 win = StandaloneDashboard(self)
#     758 win.show()
#     759 app.exec_()
#
# File /opt/anaconda3/envs/uedge_class/lib/python3.12/site-packages/uetools/UeDashboard/Dashboard.py:1610, in StandaloneDashboard.__init__(self, case, parent)
#    1607 self.resize(1250, 850)
#    1609 self.statusbar = self.statusBar()
# -> 1610 self.centralWidget =  CaseDashboard(self.case)
#    1611 self.centralWidget.setMinimumWidth(1250)
#    1612 self.centralWidget.setMinimumHeight(850)
#
# File /opt/anaconda3/envs/uedge_class/lib/python3.12/site-packages/uetools/UeDashboard/Dashboard.py:458, in CaseDashboard.__init__(self, case, parent)
#     455 self.file = case.info['filename']
#     457 self.centralWidget = QWidget(self)
# --> 458 self.caseplot = HeatmapInteractiveFigure(case)
#     459 # Cannibalize Case functions
#     460 self.inplace = case.info['inplace']
#
# File /opt/anaconda3/envs/uedge_class/lib/python3.12/site-packages/uetools/UeDashboard/Dashboard.py:1164, in HeatmapInteractiveFigure.__init__(self, case, parent)
#    1162 self.case = case
#    1163 self.case.plot.te2D(ax=self.canvas.axes)
# -> 1164 self.case.about.set_speciesarrays()
#    1165 self.verts = self.case.plot.Qvertices
#    1167 self._createSlider()
#
# File /opt/anaconda3/envs/uedge_class/lib/python3.12/site-packages/uetools/UeUtils/AboutSetup.py:117, in AboutSetup.set_speciesarrays(self)
#     112 for i in range(nisp):
#     113     charge = "{}".format(
#     114         ("+" + str(int(zi[i]))) * (zi[i] > 0) + "0" * (zi[i] == 0)
#     115     )
#     116     sign = "".join(
# --> 117         (x for x in elements[znuclin[i]][minu[i]] if not x.isdigit())
#     118     )
#     119     ionarray.append("{}{}".format(sign, charge))  # .center(5))
#     120 for i in range(nhsp - 1):
#
# KeyError: 2.5

# %%
from scipy.integrate import simpson
bbb.fqp=0
bbb.plateflux();

psep = simpson( (bbb.feiy+bbb.feey)[com.ixpt1[0]+1:com.ixpt2[0],com.iysptrx]) / 1e6
pcore = simpson( (bbb.feiy+bbb.feey)[com.ixpt1[0]+1:com.ixpt2[0],0]) / 1e6

print(f' Power from core boundary (surface closest to magnetic axis) = {pcore:.3f} MW  \n \
Power at Separatrix = {psep:.3f} MW  \n \
Power radiated in core region = {(pcore-psep):.3f} MW ')
particlecore = simpson( (bbb.fniy)[com.ixpt1[0]+1:com.ixpt2[0],0])
particlecore
# Out:
#  Power from core boundary (surface closest to magnetic axis) = 8.048 MW
#  Power at Separatrix = 5.351 MW
#  Power radiated in core region = 2.697 MW
# array([1.67344395e+19, 6.45162508e+19, 1.19388060e+20, 2.50793527e+20,
#        2.35361796e+20, 2.66883516e+20, 2.78829270e+20, 2.70702551e+20,
#        2.51593717e+20, 2.32160000e+20, 2.17022173e+20, 2.07206275e+20,
#        2.00394799e+20, 1.25116048e+15, 5.59366425e+15, 9.01866024e+20,
#        8.54684948e+20, 7.68498401e+20, 6.39604430e+20, 5.04006980e+20,
#        3.69309741e+20, 2.02367788e+20, 1.22948008e+20])

# %%
c.search.var("fniy")
c.search.var("sdrrb")
# Out:
# Package:    bbb
# Group:      Comflo
# Attributes: Comflo
# Dimension:  (0:nx+1,0:ny+1,1:nisp)
#             (66, 46, 2)
# Type:       double
# Address:    4877910016
# Pyaddress:  4496925360
# Unit:       1/s
# Comment:
# ion radial current, north face
# Package:    bbb
# Group:      Postproc
# Attributes: Postproc
# Dimension:  (0:ny+1,1:nxpt)
#             (46, 1)
# Type:       double
# Address:    4502853040
# Pyaddress:  4496917680
# Unit:       W/m**2
# Comment:
# tot rad flux to right div

# %%
print(grd.rplate1,grd.rplate2,grd.zplate1,grd.zplate1)
# Out:
# [2.177 2.307] [2.177 2.307] [0.42138276 0.09438276] [0.42138276 0.09438276]
