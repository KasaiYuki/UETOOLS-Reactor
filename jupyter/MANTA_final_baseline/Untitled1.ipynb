# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from uedge import *
from uedge.hdf5 import *
#import plotmesh as pm
from uetools import Case
from uedge.gridue import write_gridue
from Forthon import gchange
# Out:
# UEDGE configuration file /Users/paullab/.uetoolsrc read.

# %%
c = Case('reconverged_v9_diag_p20_imp2_last_ii2.hdf5')
# bbb.isphiofft=1 #1 is default
# bbb.gamsec = 1 # striation fix
# Out:
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../jupyter/MANTA_final_baseline/reconverged_v9_diag_p20_imp2_last_ii2.hdf5
#   User-specified diffusivities read from HDF5 file ".../jupyter/MANTA_final_baseline/reconverged_v9_diag_p20_imp2_last_ii2.hdf5"
# UETOOLS-style save successfully restored from .../jupyter/MANTA_final_baseline/reconverged_v9_diag_p20_imp2_last_ii2.hdf5
# *** For isimpon=2, set afracs, not afrac ***
#
# *** UEDGE arrays populated: WARNING, case NOT converged ***
# fnrm without preconditioning: 1.30e+05

# %%
c.converge(savefname='reconverged_v9_diag_p20_gamsec', dtreal=1e-10)
# Out:
# Requested save-path ../solutions not found, writing to cwd!
# *----------------------------------------------------------*
#  Need to take initial step with Jacobian; trying to do here
# *----------------------------------------------------------*
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1961077479855051     nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.2394543038162676E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ---------------------------------------------------------------
# *** Number of time-step changes = 1 New time-step: 1.00E-10 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1961071569766773     nfe=      1
#  iter=    1 fnrm=     0.1385885547605287E-05 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1961065623670814     nfe=      1
#  iter=    1 fnrm=     0.2756228160577768E-05 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #2
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1961059627749260     nfe=      1
#  iter=    1 fnrm=     0.4135120060203757E-05 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 2.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #3
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1961053571759760     nfe=      1
#  iter=    1 fnrm=     0.5517023167711652E-05 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 3.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #4
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1961047447854332     nfe=      1
#  iter=    1 fnrm=     0.2534235263062363E-09 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 4.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #5
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1961041248084329     nfe=      1
#  iter=    1 fnrm=     0.2895050229231311E-09 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 5.0000E-10; Timestep = 1.0000E-10
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 2 New time-step: 3.40E-10 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1961034969513304     nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1840806269070008E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1961012348562699     nfe=      1
#  iter=    1 fnrm=     0.4545432784795082E-05 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 9.4000E-10; Timestep = 3.4000E-10
#
#  Inner iteration #2
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1960988596576681     nfe=      1
#  iter=    1 fnrm=     0.2389319465735196E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.2800E-09; Timestep = 3.4000E-10
#
#  Inner iteration #3
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1960963625811649     nfe=      1
#  iter=    1 fnrm=     0.2462578752507743E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.6200E-09; Timestep = 3.4000E-10
#
#  Inner iteration #4
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1960937359763606     nfe=      1
#  iter=    1 fnrm=     0.2486198936813711E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.9600E-09; Timestep = 3.4000E-10
#
#  Inner iteration #5
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1960909725751007     nfe=      1
#  iter=    1 fnrm=     0.2464984187871039E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 2.3000E-09; Timestep = 3.4000E-10
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 3 New time-step: 1.16E-09 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1960880654762133     nfe=      1
#  iter=    1 fnrm=     0.6106463819162737E-06 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1960761061887965     nfe=      1
#  iter=    1 fnrm=     0.5959982958928393E-06 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 3.7960E-09; Timestep = 1.1560E-09
#
#  Inner iteration #2
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1960620496189054     nfe=      1
#  iter=    1 fnrm=     0.5381200989800217E-06 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 4.9520E-09; Timestep = 1.1560E-09
#
#  Inner iteration #3
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1960456759151950     nfe=      1
#  iter=    1 fnrm=     0.6578438551393247E-06 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 6.1080E-09; Timestep = 1.1560E-09
#
#  Inner iteration #4
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1960267786655120     nfe=      1
#  iter=    1 fnrm=     0.2401616252289890E-05 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 7.2640E-09; Timestep = 1.1560E-09
#
#  Inner iteration #5
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1960051505612339     nfe=      1
#  iter=    1 fnrm=     0.5788049798981448E-05 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 8.4200E-09; Timestep = 1.1560E-09
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 4 New time-step: 3.93E-09 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1959807511002104     nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.4808889663968160E-06 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1958558401255429     nfe=      1
#  iter=    1 fnrm=     0.3543111832901560E-06 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.3506E-08; Timestep = 3.9304E-09
#
#  Inner iteration #2
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1956843224957106     nfe=      1
#  iter=    1 fnrm=     0.3715102615754688E-06 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.7437E-08; Timestep = 3.9304E-09
#
#  Inner iteration #3
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1954598813367366     nfe=      1
#  iter=    1 fnrm=     0.3901413663820512E-06 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 2.1367E-08; Timestep = 3.9304E-09
#
#  Inner iteration #4
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.1584E-06; Timestep = 1.5448E-07
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 8 New time-step: 5.25E-07 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.2664788927940800E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1325184718535934E-05 nfe=     10
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2180324181925595E-02 nfe=      1
#  iter=    1 fnrm=     0.9294005287832089E-06 nfe=     13
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.8381E-06; Timestep = 5.2523E-07
#
#  Inner iteration #2
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1812152286838360E-02 nfe=      1
#  iter=    1 fnrm=     0.9351890796656198E-06 nfe=     15
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 2.3633E-06; Timestep = 5.2523E-07
#
#  Inner iteration #3
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1704153601023304E-02 nfe=      1
#  iter=    1 fnrm=     0.9193760661883549E-06 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 2.8885E-06; Timestep = 5.2523E-07
#
#  Inner iteration #4
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1661317758873595E-02 nfe=      1
#  iter=    1 fnrm=     0.8882317166059679E-06 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 3.4138E-06; Timestep = 5.2523E-07
#
#  Inner iteration #5
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1623810774551998E-02 nfe=      1
#  iter=    1 fnrm=     0.8549725665400130E-06 nfe=     18
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 3.9390E-06; Timestep = 5.2523E-07
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 9 New time-step: 1.79E-06 ***
# ---------------------------------------------------------------
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1585570255990132E-02 nfe=      1
#  iter=    1 fnrm=     0.8691700226754013E-05 nfe=     26
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1467076619628492E-02 nfe=      1
#  iter=    1 fnrm=     0.7678063913137417E-05 nfe=     26
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 6.2500E-06; Timestep = 1.7858E-06
#
#  Inner iteration #2
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1361312533962383E-02 nfe=      1
#  iter=    1 fnrm=     0.6774720675453079E-05 nfe=     26
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 8.0358E-06; Timestep = 1.7858E-06
#
#  Inner iteration #3
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1266510562779117E-02 nfe=      1
#  iter=    1 fnrm=     0.5985648540694635E-05 nfe=     26
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 9.8216E-06; Timestep = 1.7858E-06
#
#  Inner iteration #4
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1181218439692670E-02 nfe=      1
#  iter=    1 fnrm=     0.5299356420006960E-05 nfe=     27
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ...
# ----------------------------------------------------------------
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.2510291186791085E-03 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.8029260696115261E-05 nfe=    110
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1754197654058232E-03 nfe=      1
#  iter=    1 fnrm=     0.6783245120118420E-05 nfe=    111
#  iter=    2 fnrm=     0.2044990887702761E-06 nfe=    224
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.4048E-02; Timestep = 1.5171E-03
#
#  Inner iteration #2
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1220793294508515E-03 nfe=      1
#  iter=    1 fnrm=     0.3766728004191864E-05 nfe=    111
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.5565E-02; Timestep = 1.5171E-03
#
#  Inner iteration #3
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.8507927171541665E-04 nfe=      1
#  iter=    1 fnrm=     0.2680250295647520E-05 nfe=    113
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.7082E-02; Timestep = 1.5171E-03
#
#  Inner iteration #4
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.5913513682721836E-04 nfe=      1
#  iter=    1 fnrm=     0.1844743668474909E-05 nfe=    113
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.8599E-02; Timestep = 1.5171E-03
#
#  Inner iteration #5
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.4107600248432753E-04 nfe=      1
#  iter=    1 fnrm=     0.1238590299997847E-05 nfe=    113
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 2.0116E-02; Timestep = 1.5171E-03
#
# ----------------------------------------------------------------
# *** Number of time-step changes = 31 New time-step: 5.16E-03 ***
# ----------------------------------------------------------------
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2851108792432649E-04 nfe=      1
#  iter=    1 fnrm=     0.1735041895061986E-05 nfe=    117
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1149320928841329E-04 nfe=      1
#  iter=    1 fnrm=     0.6699351008607122E-06 nfe=    124
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 2.6792E-02; Timestep = 5.1581E-03
#
#  Inner iteration #2
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.4578412600533592E-05 nfe=      1
#  iter=    1 fnrm=     0.2809808116168869E-06 nfe=    126
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 3.1950E-02; Timestep = 5.1581E-03
#
#  Inner iteration #3
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1827337068454105E-05 nfe=      1
#  iter=    1 fnrm=     0.1151877160932130E-06 nfe=    127
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 3.7108E-02; Timestep = 5.1581E-03
#
#  Inner iteration #4
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.7294905413828110E-06 nfe=      1
#  iter=    1 fnrm=     0.6321716410720860E-07 nfe=    131
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 4.2266E-02; Timestep = 5.1581E-03
#
#  Inner iteration #5
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2969334910161386E-06 nfe=      1
#  iter=    1 fnrm=     0.4941767011739329E-07 nfe=    133
#  iter=    2 fnrm=     0.6518863325579914E-09 nfe=    263
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 4.7424E-02; Timestep = 5.1581E-03
#
# ----------------------------------------------------------------
# *** Number of time-step changes = 32 New time-step: 1.75E-02 ***
# ----------------------------------------------------------------
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1195115520896273E-06 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.5955903472539257E-08 nfe=    129
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Inner iteration #1
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2575659967713650E-07 nfe=      1
#  iter=    1 fnrm=     0.4114009676752006E-08 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 7.0120E-02; Timestep = 1.7538E-02
#
#  Inner iteration #2
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.9799399458136769E-08 nfe=      1
#  iter=    1 fnrm=     0.2712935016197964E-08 nfe=    133
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 8.7658E-02; Timestep = 1.7538E-02
#
#  Inner iteration #3
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.5092172843810546E-08 nfe=      1
#  iter=    1 fnrm=     0.1378137868483049E-08 nfe=    134
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.0520E-01; Timestep = 1.7538E-02
#
#  Inner iteration #4
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.2619666052630451E-08 nfe=      1
#  iter=    1 fnrm=     0.7007724690675226E-09 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#  Total time = 1.2273E-01; Timestep = 1.7538E-02
#
#  Inner iteration #5
#
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridmorph/progress53p837.hdf5
#      run-ID:      TokaMaker:
#  iter=    0 fnrm=     0.1363787884177016E-08 nfe=      1
#  iter=    1 fnrm=     0.3242275694208810E-09 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./reconverged_v9_diag_p20_gamsec_last_ii2.hdf5
#
# ******************************
# ** SUCCESS: fnrm < bbb.ftol **
# ******************************
# Total runtime: 0:07:09

# %%
c.solver.convergenceanalysis('reconverged_v9_diag_p20_imp2_last_ii2.hdf5');

# %%
bbb.isphiofft
# Out:
# 1

# %%
# %matplotlib widget
fig, axs = plt.subplot_mosaic(
    [['TopLeft', 'TopRight'],
     ['Bottom', 'Bottom']],
    layout='constrained',  # Automatically adjust layout
    width_ratios=[1, 1],   # Equal width for the top plots
)
fig.suptitle('Inner heat fluxes per area')
fig.supxlabel('Distance along inner plate (m)')
fig.supylabel('Heat flux (MW/m**2)')
# axs['TopRight'].set_xlabel("Distance along inner plate (m)")
#axs['TopRight'].set_ylabel("feex (W)")
axs['TopRight'].set_title("Electrons")
axs['TopRight'].plot(com.yylb[1:-1],-bbb.feex[0,1:-1]/com.sx[0,1:-1]*1e-6)

# axs['TopLeft'].set_xlabel("Distance along inner plate (m)")
# axs['TopLeft'].set_ylabel("Heat flux (MW/m**2)")
axs['TopLeft'].set_title("Ions/Atoms")
axs['TopLeft'].plot(com.yylb[1:-1],-bbb.feix[0,1:-1]/com.sx[0,1:-1]*1e-6) #polodal east field area

bbb.fqp=0
bbb.plateflux(); #internally calculated fluxes (postprocessing)
# axs['Bottom'].set_xlabel("Distance along inner plate (m)")
# axs['Bottom'].set_ylabel("Heat flux [MW/m**2]")
axs['Bottom'].set_title("Particle+radiation heat flux")
axs['Bottom'].plot(com.yylb,1.e-6*(bbb.sdtlb+bbb.sdrlb))
plt.show()

# %%
# total convective and conductive heat flux
# 2nd char: e for energy n for particle
plt.figure()
fig, axs = plt.subplot_mosaic(
    [['TopLeft', 'TopRight'],
     ['Bottom', 'Bottom']],
    layout='constrained',  # Automatically adjust layout
    width_ratios=[1, 1],   # Equal width for the top plots
)
fig.suptitle('Outer heat fluxes per area')
fig.supxlabel('Distance along outer plate (m)')
fig.supylabel('Heat flux (MW/m**2)')
# axs['TopRight'].set_xlabel("Distance along inner plate (m)")
#axs['TopRight'].set_ylabel("feex (W)")
axs['TopRight'].set_title("Electrons")
axs['TopRight'].plot(com.yyrb[1:-1],bbb.feex[com.nx,1:-1]/com.sx[0,1:-1]*1e-6)

# axs['TopLeft'].set_xlabel("Distance along inner plate (m)")
# axs['TopLeft'].set_ylabel("Heat flux (MW/m**2)")
axs['TopLeft'].set_title("Ions/Atoms")
axs['TopLeft'].plot(com.yyrb[1:-1],bbb.feix[com.nx,1:-1]/com.sx[0,1:-1]*1e-6) #polodal east field area

bbb.fqp=0
bbb.plateflux(); #internally calculated fluxes (postprocessing)
# axs['Bottom'].set_xlabel("Distance along inner plate (m)")
# axs['Bottom'].set_ylabel("Heat flux [MW/m**2]")
axs['Bottom'].set_title("Particle+radiation heat flux")
axs['Bottom'].plot(com.yylb,1.e-6*(bbb.sdtrb+bbb.sdrrb))
plt.show()
max(1.e-6*(bbb.sdtrb+bbb.sdrrb))
# Out:
# array([56.99836183])

# %%
plt.figure()

c.plot.grid(linewidth=0.1, #grid plot
   vessel=True, 
   plates=True, 
   platecolor=['gold','teal'], 
   lcfs=True, 
   xlim=(1.8, 2.8), 
   ylim=(0.1,0.85),
   lcfscolor='r', 
   linecolor='b',
   title='Mesh grid'
  );
c.plot.mesh(
    bbb.feex, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    zrange=(-10e5,10e5),
    cmap='seismic',
    title='Electron heat flux (W)'
);



c.plot.mesh(
    bbb.feix, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85),
    figsize=(7,5), 
    zrange=(-8e5,8e5),
    cmap='seismic',
    title='Ion heat flux (W)'
);

plt.show()
