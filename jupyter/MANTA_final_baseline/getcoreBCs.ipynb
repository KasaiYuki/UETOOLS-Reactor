# %%
import numpy as np
data = np.load('ni.npz')  # Replace 'ni.npz' with the actual file path
print(data)
data = np.load('ti.npz')  # Replace 'ni.npz' with the actual file path
print(data)
data = np.load('te.npz')  # Replace 'ni.npz' with the actual file path
print(data)
data = np.load('psi_grid.npz')  # Replace 'ni.npz' with the actual file path
print(data)
# Out:
# [3.01990211e+20 3.01981216e+20 3.01954232e+20 3.01909264e+20
#  3.01846321e+20 3.01765413e+20 3.01666555e+20 3.01549764e+20
#  3.01415062e+20 3.01262472e+20 3.01092022e+20 3.00903742e+20
#  3.00697665e+20 3.00473829e+20 3.00232274e+20 2.99973041e+20
#  2.99696178e+20 2.99401733e+20 2.99089760e+20 2.98760313e+20
#  2.98413451e+20 2.98049235e+20 2.97667730e+20 2.97269004e+20
#  2.96853127e+20 2.96420172e+20 2.95970216e+20 2.95503339e+20
#  2.95019622e+20 2.94519151e+20 2.94002014e+20 2.93444068e+20
#  2.92821367e+20 2.92134327e+20 2.91383408e+20 2.90569111e+20
#  2.89648756e+20 2.88580304e+20 2.87365417e+20 2.86005979e+20
#  2.84504092e+20 2.82877109e+20 2.81142213e+20 2.79301509e+20
#  2.77357217e+20 2.75311675e+20 2.73261887e+20 2.71302056e+20
#  2.69430462e+20 2.67645469e+20 2.65945522e+20 2.64296830e+20
#  2.62666455e+20 2.61054182e+20 2.59459802e+20 2.57883107e+20
#  2.56372874e+20 2.54976759e+20 2.53692991e+20 2.52519946e+20
# ...
