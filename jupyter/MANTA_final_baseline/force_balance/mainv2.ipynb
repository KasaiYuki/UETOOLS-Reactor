# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from uedge import *
from uedge.hdf5 import *
#import plotmesh as pm
from uetools import Case
from uedge.gridue import write_gridue
from Forthon import gchange
# Out:
# UEDGE configuration file /Users/eliotfelske/.uetoolsrc read.

# %% [markdown]
# # Create Case from YAML

# %%
#c = Case('reconverged_v12_p3.93_n2.38_imp1e4_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5')
#c = Case('baseline_v12_p3.93_n2.38_imp1e4_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5')
c = Case('input_v12_force_balance.yaml')
print("dif_use, kye_use, kyi_use around SOL:", bbb.dif_use[28, :, 0][1], bbb.kye_use[28, :][1], bbb.kyi_use[28, :][1])
#if bbb.dif_use[30, :, 0][1] == c_dif and bbb.kye_use[30, :][1] == c_kye and bbb.kyi_use[30, :][1] == c_kyi:
   # pass
#else:
    #print(f'Diffusivities or chi values not matching!', file=sys.stderr)
# fnorm for final=1.65e+00
# Out:
# *** Warning:  nzspt<1 for isimpon>3
# *** Warning:  nzspt<1 for isimpon>3
# No diffusivity-file supplied: reading from save-file ".../MANTA_final_baseline/force_balance/baseline_v12_p3.93_n2.38_imp1e4_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5"
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/force_balance/baseline_v12_p3.93_n2.38_imp1e4_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/force_balance/baseline_v12_p3.93_n2.38_imp1e4_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5
# *** Warning:  nzspt<1 for isimpon>3
#
# *** UEDGE arrays populated: WARNING, case NOT converged ***
# fnrm without preconditioning: 4.96e+07
#
# dif_use, kye_use, kyi_use around SOL: 0.059 0.059 0.0221

# %%
api.apidir
# Out:
# array([b'/Users/eliotfelske/UETOOLS-Reactor/uedge-rates/api                                                                      '],
#       dtype='|S120')

# %%
c.populate()
print("dif_use, kye_use, kyi_use around SOL:", bbb.dif_use[30, :, 0][1], bbb.kye_use[30, :][1], bbb.kyi_use[30, :][1])
# Out:
# *** For isimpon=2, set afracs, not afrac ***
#
# *** UEDGE arrays populated: WARNING, case NOT converged ***
# fnrm without preconditioning: 5.67e+07
#
# dif_use, kye_use, kyi_use around SOL: 0.059 0.059 0.0221

# %%
'''c_dif = 0.05
c_kye = 0.05
c_kyi = 0.02

prof_d = [0.06, 0.059, 0.058, 0.057, 0.056, 0.055, 0.054, 0.053, 0.052, 0.051, 
 0.05, 0.049, 0.048, 0.047, 0.046, 0.045, 0.044, 0.043, 0.042, 0.041, 
 0.04, 0.039, 0.038, 0.037, 0.036, 0.035, 0.034, 0.033, 0.032, 0.031, 
 0.03, 0.029, 0.028, 0.027, 0.026, 0.025, 0.024, 0.023, 0.022, 0.021, 
 0.02, 0.019, 0.018, 0.017, 0.016, 0.015]
prof_e = [0.06, 0.059, 0.058, 0.057, 0.056, 0.055, 0.054, 0.053, 0.052, 0.051, 
 0.05, 0.049, 0.048, 0.047, 0.046, 0.045, 0.044, 0.043, 0.042, 0.041, 
 0.04, 0.039, 0.038, 0.037, 0.036, 0.035, 0.034, 0.033, 0.032, 0.031, 
 0.03, 0.029, 0.028, 0.027, 0.026, 0.025, 0.024, 0.023, 0.022, 0.021, 
 0.02, 0.019, 0.018, 0.017, 0.016, 0.015]
prof_i = [0.0226, 0.0221, 0.0216, 0.0211, 0.0206, 0.0201, 0.0196, 0.0191, 0.0186, 0.0181, 
 0.0176, 0.0171, 0.0166, 0.0161, 0.0156, 0.0151, 0.0146, 0.0141, 0.0136, 0.0131, 
 0.0126, 0.0121, 0.0116, 0.0111, 0.0106, 0.0101, 0.0096, 0.0091, 0.0086, 0.0081, 
 0.0076, 0.0071, 0.0066, 0.0061, 0.0056, 0.0051, 0.0046, 0.0041, 0.0036, 0.0031, 
 0.0026, 0.0021, 0.0016, 0.0011, 0.0006, 0.0001]

#divertor region temporary for plotting, reset to 0.5 at the end of cell
bbb.dif_use[1:17, :, 0] = c_dif
bbb.dif_use[41:65, :, 0] = c_dif
bbb.kye_use[1:17, :] = c_kye
bbb.kye_use[41:65, :] = c_kye
bbb.kyi_use[1:17, :] = c_kyi
bbb.kyi_use[41:65, :] = c_kyi

bbb.dif_use[30,:,0] = prof_d
bbb.dif_use[29,:,0] = prof_d
bbb.dif_use[28,:,0] = prof_d
bbb.dif_use[27,:,0] = prof_d
bbb.dif_use[26,:,0] = prof_d
bbb.dif_use[25,:,0] = prof_d
bbb.dif_use[24,:,0] = prof_d
bbb.dif_use[23,:,0] = prof_d
bbb.dif_use[22,:,0] = prof_d
bbb.dif_use[21,:,0] = prof_d
bbb.dif_use[20,:,0] = prof_d
bbb.dif_use[19,:,0] = prof_d
bbb.dif_use[18,:,0] = prof_d
bbb.dif_use[17,:,0] = prof_d
bbb.dif_use[31,:,0] = prof_d
bbb.dif_use[32,:,0] = prof_d
bbb.dif_use[33,:,0] = prof_d
bbb.dif_use[34,:,0] = prof_d
bbb.dif_use[35,:,0] = prof_d
bbb.dif_use[36,:,0] = prof_d
bbb.dif_use[37,:,0] = prof_d
bbb.dif_use[38,:,0] = prof_d
bbb.dif_use[39,:,0] = prof_d
bbb.dif_use[40,:,0] = prof_d

bbb.kye_use[30,:] = prof_e
bbb.kye_use[29,:] = prof_e
bbb.kye_use[28,:] = prof_e
bbb.kye_use[27,:] = prof_e
bbb.kye_use[26,:] = prof_e
bbb.kye_use[25,:] = prof_e
bbb.kye_use[24,:] = prof_e
bbb.kye_use[23,:] = prof_e
bbb.kye_use[22,:] = prof_e
bbb.kye_use[21,:] = prof_e
bbb.kye_use[20,:] = prof_e
bbb.kye_use[19,:] = prof_e
bbb.kye_use[18,:] = prof_e
bbb.kye_use[17,:] = prof_e
bbb.kye_use[31,:] = prof_e
bbb.kye_use[32,:] = prof_e
bbb.kye_use[33,:] = prof_e
bbb.kye_use[34,:] = prof_e
bbb.kye_use[35,:] = prof_e
bbb.kye_use[36,:] = prof_e
bbb.kye_use[37,:] = prof_e
bbb.kye_use[38,:] = prof_e
bbb.kye_use[39,:] = prof_e
bbb.kye_use[40,:] = prof_e

bbb.kyi_use[30,:] = prof_i
bbb.kyi_use[29,:] = prof_i
bbb.kyi_use[28,:] = prof_i
bbb.kyi_use[27,:] = prof_i
bbb.kyi_use[26,:] = prof_i
bbb.kyi_use[25,:] = prof_i
bbb.kyi_use[24,:] = prof_i
bbb.kyi_use[23,:] = prof_i
bbb.kyi_use[22,:] = prof_i
bbb.kyi_use[21,:] = prof_i
bbb.kyi_use[20,:] = prof_i
bbb.kyi_use[19,:] = prof_i
bbb.kyi_use[18,:] = prof_i
bbb.kyi_use[17,:] = prof_i
bbb.kyi_use[31,:] = prof_i
bbb.kyi_use[32,:] = prof_i
bbb.kyi_use[33,:] = prof_i
bbb.kyi_use[34,:] = prof_i
bbb.kyi_use[35,:] = prof_i
bbb.kyi_use[36,:] = prof_i
bbb.kyi_use[37,:] = prof_i
bbb.kyi_use[38,:] = prof_i
bbb.kyi_use[39,:] = prof_i
bbb.kyi_use[40,:] = prof_i
#bbb.kye_use[com.ixpt1[0]+1:com.ixpt2[0],com.iysptrx-10:com.iysptrx] = 15 what does this do?
'''
plt.figure()
c.plot.mesh(bbb.dif_use[:,:,0])
plt.title('dif_use')

c.plot.mesh(bbb.kye_use[:,:])
plt.title('kye_use')

c.plot.mesh(bbb.kyi_use[:,:])
plt.title('kyi_use')

plt.show()
'''
bbb.dif_use[1:17, :, 0] = c_dif
bbb.dif_use[41:65, :, 0] = c_dif
bbb.kye_use[1:17, :] = c_kye
bbb.kye_use[41:65, :] = c_kye
bbb.kyi_use[1:17, :] = c_kyi
bbb.kyi_use[41:65, :] = c_kyi

#indexing first index from 1 starts at the inner plate moving upward with index number, starting at
#Core boundary indicies: HFS: 17-30, LFS: 31-40
#kye biases heat outer plate, dif is more inner plate and has more of an effecto on midplane temps

#for ix in range(com.ixpt1[0]+1,com.ixpt2[0]: bbb.dif_use[ix,:,0]= [0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5]
#len bbb.dif_use[#,:,0] = 46

#for ix in range(com.ixpt1[0] + 1, com.ixpt2[0]):
    #print(bbb.dif_use[ix,:,0])
#kye,i decrease makes wall heat go down and decreases lambda, dif decrease increases wall heat again
'''
# Out:
# '\nbbb.dif_use[1:17, :, 0] = c_dif\nbbb.dif_use[41:65, :, 0] = c_dif\nbbb.kye_use[1:17, :] = c_kye\nbbb.kye_use[41:65, :] = c_kye\nbbb.kyi_use[1:17, :] = c_kyi\nbbb.kyi_use[41:65, :] = c_kyi\n\n#indexing first index from 1 starts at the inner plate moving upward with index number, starting at\n#Core boundary indicies: HFS: 17-30, LFS: 31-40\n#kye biases heat outer plate, dif is more inner plate and has more of an effecto on midplane temps\n\n#for ix in range(com.ixpt1[0]+1,com.ixpt2[0]: bbb.dif_use[ix,:,0]= [0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5,0.5]\n#len bbb.dif_use[#,:,0] = 46\n\n#for ix in range(com.ixpt1[0] + 1, com.ixpt2[0]):\n    #print(bbb.dif_use[ix,:,0])\n#kye,i decrease makes wall heat go down and decreases lambda, dif decrease increases wall heat again\n'

# %%
from plot_sinksource import plot_sinksource
plot_sinksource(c)

# %% [markdown]
# # Converge

# %%
bbb.ncore
# Out:
# array([2.38e+20, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19,
#        7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19,
#        7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19,
#        7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19,
#        7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19, 7.00e+19,
#        7.00e+19])

# %%
#bbb.afracs = 1.e-4
bbb.afracs
# Out:
# array([[0.04, 0.04, 0.04, ..., 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, ..., 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, ..., 0.04, 0.04, 0.04],
#        ...,
#        [0.04, 0.04, 0.04, ..., 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, ..., 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, ..., 0.04, 0.04, 0.04]])

# %%
#bbb.pcoree = 1.96e6
#bbb.pcorei = 1.96e6
bbb.pcoree,bbb.pcorei
# Out:
# (3930000.0, 3930000.0)

# %%
#bbb.isimpon = 6
bbb.isimpon
# Out:
# 6

# %%
c.populate()
# Out:
# *** Warning:  nzspt<1 for isimpon>3
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 5.17e-01

# %%
import subprocess
bbb.isbcwdt=0
proc = subprocess.Popen(['caffeinate', "-d", "-u", "-i", "-s"])

try:
    c.converge(savefname='first_force_balance', dtreal=1e-10)
    os.system("printf '\7'") #macos plays sound after converging
finally:
    # Terminate caffeinate
    proc.terminate()
# Out:
# Requested save-path ../solutions not found, writing to cwd!
# *----------------------------------------------------------*
#  Need to take initial step with Jacobian; trying to do here
# *----------------------------------------------------------*
# *** Warning:  nzspt<1 for isimpon>3
#  Reading grid data from /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/force_balance/gridue_v12_vertical.hdf5
#  Grid data read successfully:
#      file name:   /Users/eliotfelske/UETOOLS-Reactor/jupyter/MANTA_final_baseline/force_balance/gridue_v12_vertical.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
# *-------------------------------------------------------------------*
#  Error: converge an initial time-step first; then re-execute command
# *-------------------------------------------------------------------*
#  iter=    0 fnrm=     0.5743094914355966     nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1379116143572044E-01 nfe=      4
#  iter=    2 fnrm=     0.1599954140007045E-02 nfe=     17
#  iter=    3 fnrm=     0.6949288231996642E-03 nfe=     30
#  iter=    4 fnrm=     0.1261841794511943E-02 nfe=     43
#  iter=    5 fnrm=     0.1230324023704950E-02 nfe=     56
#   Updating Jacobian, npe =                      3
#  iter=    6 fnrm=     0.1158669920579110E-02 nfe=     61
#  iter=    7 fnrm=     0.1227071986529453E-02 nfe=     71
#  iter=    8 fnrm=     0.1259589194710672E-02 nfe=     80
#  iter=    9 fnrm=     0.1243200729176392E-02 nfe=     90
#  iter=   10 fnrm=     0.1274919809891091E-02 nfe=    101
#   Updating Jacobian, npe =                      4
#  iter=   11 fnrm=     0.1246625815942235E-02 nfe=    106
#  iter=   12 fnrm=     0.1196314328320192E-02 nfe=    117
#  iter=   13 fnrm=     0.1246457511363362E-02 nfe=    127
#  iter=   14 fnrm=     0.1208744257391836E-02 nfe=    138
#  iter=   15 fnrm=     0.1257359750122908E-02 nfe=    148
#   Updating Jacobian, npe =                      5
#  iter=   16 fnrm=     0.1232475549267908E-02 nfe=    153
#  iter=   17 fnrm=     0.1347883337072455E-02 nfe=    164
#  iter=   18 fnrm=     0.1568503219113536E-02 nfe=    174
#  iter=   19 fnrm=     0.4356744869532711E-02 nfe=    185
#  iter=   20 fnrm=     0.1950411338394692E-01 nfe=    196
#   Updating Jacobian, npe =                      6
#  iter=   21 fnrm=     0.7398901843511642E-01 nfe=    200
#  iter=   22 fnrm=     0.3657268363978408     nfe=    207
#  iter=   23 fnrm=      1.341306588269031     nfe=    213
#  iter=   24 fnrm=      6.278302088567698     nfe=    220
#  iter=   25 fnrm=      21.56401809379328     nfe=    227
#   Updating Jacobian, npe =                      7
#  iter=   26 fnrm=      31.46765847238256     nfe=    231
#  iter=   27 fnrm=      28.48507609700778     nfe=    240
#  iter=   28 fnrm=      27.18164082453117     nfe=    247
#  iter=   29 fnrm=      39.58840640242914     nfe=    255
#  iter=   30 fnrm=      14.04921426242965     nfe=    263
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1

# %%
import subprocess
proc = subprocess.Popen(['caffeinate', "-d", "-u", "-i", "-s"])

try:
    c.continuation_solve('afracs', 1e-2, savedir='impu_up', dtreal=1e-10, ftol=1e-2)
    os.system("printf '\7'") #macos plays sound after converging
finally:
    # Terminate caffeinate
    proc.terminate()
# Out:
# *----------------------------------------------------------*
#  Need to take initial step with Jacobian; trying to do here
# *----------------------------------------------------------*
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             0.000%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    1000
#
# *** For isimpon=2, set afracs, not afrac ***
#  Reading grid data from /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/reconverged_v12_p1.0_n2.38_imp2e3_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#  Grid data read successfully:
#      file name:   /Users/paullab/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/reconverged_v12_p1.0_n2.38_imp2e3_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5.hdf5
#      run-ID:      TokaMaker:
#   Updating Jacobian, npe =                      1
# ===== MAIN LOOP 1/7 ===== iter=    0 fnrm=     0.3119233849731334E-03 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1326935185897124E-04 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             0.000%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    1000
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.1955062863750491E-04 nfe=      1
#  iter=    1 fnrm=     0.1284355053604638E-05 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to impu_up/progress0p100.hdf5
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             0.100%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    999
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.3114627405181665E-03 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             0.200%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    998
#
#  iter=    1 fnrm=     0.2303082987494772E-04 nfe=    136
#  iter=    2 fnrm=     0.3650173490361933E-05 nfe=    271
#  iter=    3 fnrm=     0.1593736650705364E-05 nfe=    406
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.3134846877981168E-03 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    1 fnrm=     0.2992689755849992E-04 nfe=    136
#  iter=    2 fnrm=     0.3710548663778971E-05 nfe=    271
#  iter=    3 fnrm=     0.1006948295155099E-05 nfe=    406
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 4/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             0.300%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    997
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.3130638337278467E-03 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 5/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             0.400%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    996
#
#  iter=    1 fnrm=     0.2636770798598970E-04 nfe=    136
#  iter=    2 fnrm=     0.1422752848851743E-04 nfe=    271
#  iter=    3 fnrm=     0.6020859400363538E-06 nfe=    406
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.3125541322275566E-03 nfe=      1
#  iter=    1 fnrm=     0.4282107640474806E-04 nfe=    136
#  iter=    2 fnrm=     0.2296985133161952E-04 nfe=    271
#  iter=    3 fnrm=     0.1138767697200744E-04 nfe=    406
#  iter=    4 fnrm=     0.2669035429566752E-05 nfe=    541
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 6/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             0.500%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    995
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.3120520011648609E-03 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    1 fnrm=     0.4381933796026417E-04 nfe=    136
#  iter=    2 fnrm=     0.4381108434527025E-05 nfe=    271
#  iter=    3 fnrm=     0.2570822671271284E-05 nfe=    406
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 7/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             0.600%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    994
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.3115209512102050E-03 nfe=      1
#
# ===== INNER LOOP COMPLETED: ADVANCING DELTA =====
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             0.700%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    451
#
#  iter=    1 fnrm=     0.2120714530037978E-04 nfe=    136
#  iter=    2 fnrm=     0.5001545109578386E-05 nfe=    271
#  iter=    3 fnrm=     0.1343298081542016E-05 nfe=    406
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#   Updating Jacobian, npe =                      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    0 fnrm=     0.6867455086687244E-03 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.4764384556033650E-04 nfe=    136
#  iter=    2 fnrm=     0.1581327805552868E-05 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             0.920%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    450
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.6875701468240570E-03 nfe=      1
#  iter=    1 fnrm=     0.4335693294297272E-03 nfe=    136
#  iter=    2 fnrm=     0.2058793732773280E-05 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to impu_up/progress1p140.hdf5
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             1.140%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    449
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.6851050173340193E-03 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    1 fnrm=     0.4533933116035578E-04 nfe=    136
#  iter=    2 fnrm=     0.2215333602287999E-05 nfe=    271
#  iter=    3 fnrm=     0.4401638252614406E-06 nfe=    406
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 4/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             1.360%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    448
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.6825577009615938E-03 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    1 fnrm=     0.8491567362767957E-04 nfe=    136
#  iter=    2 fnrm=     0.1295533836661751E-05 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 5/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             1.580%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    447
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.6799973961900774E-03 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    1 fnrm=     0.1302998702064398E-03 nfe=    136
#  iter=    2 fnrm=     0.5663995436970039E-05 nfe=    271
#  iter=    3 fnrm=     0.8109386632259488E-06 nfe=    406
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 6/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             1.800%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    446
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.6774269235088038E-03 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 7/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             2.020%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    445
#
#  iter=    1 fnrm=     0.6097901735155328E-04 nfe=    136
#  iter=    2 fnrm=     0.8840057690634031E-06 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.6748613316842115E-03 nfe=      1
#
# ===== INNER LOOP COMPLETED: ADVANCING DELTA ===== iter=    1 fnrm=     0.5096673469124373E-04 nfe=    136
#  iter=    2 fnrm=     0.4153842045449773E-05 nfe=    271
#  iter=    3 fnrm=     0.1010952163666860E-05 nfe=    406
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             2.240%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    201
#
# *** For isimpon=2, set afracs, not afrac ***
#   Updating Jacobian, npe =                      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    0 fnrm=     0.1488426792610246E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.5012586540345481E-03 nfe=    136
#  iter=    2 fnrm=     0.3677835733188122E-05 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             2.724%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    200
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.1483463065457881E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             3.208%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    199
#
#  iter=    1 fnrm=     0.2533619278755217E-03 nfe=    136
#  iter=    2 fnrm=     0.5446160369761045E-05 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.1471270383959581E-02 nfe=      1
#  iter=    1 fnrm=     0.6310865035989234E-03 nfe=    136
#  iter=    2 fnrm=     0.2450437513837382E-05 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to impu_up/progress3p692.hdf5
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 4/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             3.692%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    198
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.1458644506930507E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 5/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             4.176%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    197
#
#  iter=    1 fnrm=     0.3194078868814050E-03 nfe=    136
#  iter=    2 fnrm=     0.1723793851125674E-04 nfe=    271
#  iter=    3 fnrm=     0.3954973697108408E-05 nfe=    406
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    0 fnrm=     0.1445997184173509E-02 nfe=      1
# ===== MAIN LOOP 6/7 ===== iter=    1 fnrm=     0.7706571121596939E-03 nfe=    136
#  iter=    2 fnrm=     0.5754193872589222E-05 nfe=    271
#  iter=    3 fnrm=     0.3480075184210572E-05 nfe=    406
#  iter=    4 fnrm=     0.1882306101642367E-05 nfe=    541
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             4.660%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    196
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.1433333139023617E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    1 fnrm=     0.4105825536315059E-03 nfe=    136
#  iter=    2 fnrm=     0.1857555231770869E-05 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 7/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             5.144%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    195
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.1420556930738122E-02 nfe=      1
#  iter=    1 fnrm=     0.3025836745272442E-03 nfe=    136
#  iter=    2 fnrm=     0.7207883088635454E-05 nfe=    271
#  iter=    3 fnrm=     0.3135273957305048E-05 nfe=    406
#  iter=    4 fnrm=     0.1074517347863267E-05 nfe=    541
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#
# ===== INNER LOOP COMPLETED: ADVANCING DELTA ===== Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             5.628%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    88
#
# *** For isimpon=2, set afracs, not afrac ***
#   Updating Jacobian, npe =                      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    0 fnrm=     0.3202260852317845E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1767314917077817E-02 nfe=    136
#  iter=    2 fnrm=     0.5218397479351665E-04 nfe=    271
#  iter=    3 fnrm=     0.9163711325745409E-05 nfe=    406
#  iter=    4 fnrm=     0.2481553553787588E-05 nfe=    541
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             6.693%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    87
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.3157067063172523E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    1 fnrm=     0.1973022353463516E-02 nfe=    136
#  iter=    2 fnrm=     0.2673640222711793E-03 nfe=    271
#  iter=    3 fnrm=     0.3507190280819573E-04 nfe=    406
#  iter=    4 fnrm=     0.2059776080165075E-04 nfe=    541
#  iter=    5 fnrm=     0.1810127339258623E-05 nfe=    676
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             7.758%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    86
#
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.3093874520392182E-02 nfe=      1
#  iter=    1 fnrm=     0.1501061305614966E-02 nfe=    136
#  iter=    2 fnrm=     0.5919251953494782E-04 nfe=    271
#  iter=    3 fnrm=     0.1246311209313834E-04 nfe=    406
#  iter=    4 fnrm=     0.1842242521690500E-05 nfe=    541
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 4/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             8.822%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    85
#
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.3029603810997519E-02 nfe=      1
#  iter=    1 fnrm=     0.1548213801938064E-02 nfe=    136
#  iter=    2 fnrm=     0.4943045629082723E-05 nfe=    271
#  iter=    3 fnrm=     0.1258752730830982E-04 nfe=    406
#  iter=    4 fnrm=     0.4496847003160039E-05 nfe=    541
#  iter=    5 fnrm=     0.4145317597333722E-05 nfe=    676
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to impu_up/progress9p887.hdf5
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 5/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             9.887%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    84
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.2965008366571699E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    1 fnrm=     0.1493175004287111E-02 nfe=    136
#  iter=    2 fnrm=     0.1831172822539688E-04 nfe=    271
#  iter=    3 fnrm=     0.2422610624620672E-05 nfe=    406
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 6/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             10.952%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    83
#
# *** For isimpon=2, set afracs, not afrac ***
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    0 fnrm=     0.2899975291624229E-02 nfe=      1
#
# ===== MAIN LOOP 7/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             12.017%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    82
#
#  iter=    1 fnrm=     0.1332428552656860E-02 nfe=    136
#  iter=    2 fnrm=     0.5150358232771341E-04 nfe=    271
#  iter=    3 fnrm=     0.1316227184160079E-04 nfe=    406
#  iter=    4 fnrm=     0.2017727129498547E-05 nfe=    541
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.2834488305832000E-02 nfe=      1
#
# ===== INNER LOOP COMPLETED: ADVANCING DELTA =====
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             13.082%
#     -Advancing by                         2.343%
#     -Steps to target at current delta:    37
#
#  iter=    1 fnrm=     0.1640361948769655E-02 nfe=    136
#  iter=    2 fnrm=     0.2283108972345080E-04 nfe=    271
#  iter=    3 fnrm=     0.2935658105896279E-05 nfe=    406
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#   Updating Jacobian, npe =                      1
#
# ===== FAIL 1/3 =====
# ===== DECREASE DELTA AND TRY AGAIN =====
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             13.082%
#     -Advancing by                         1.171%
#     -Steps to target at current delta:    74
#
#  iter=    0 fnrm=     0.6605397310302266E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1077736134471862E-01 nfe=    136
#  iter=    2 fnrm=     0.5036798698680903E-03 nfe=    271
#  iter=    3 fnrm=     0.2190553854404430E-03 nfe=    406
#  iter=    4 fnrm=     0.8297135282623060E-04 nfe=    541
#  iter=    5 fnrm=     0.6040550313947635E-04 nfe=    676
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#   Updating Jacobian, npe =                      1
#
# ===== FAIL 2/3 =====
# ===== DECREASE DELTA AND TRY AGAIN =====
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             13.082%
#     -Advancing by                         0.586%
#     -Steps to target at current delta:    148
#
#  iter=    0 fnrm=     0.3330524140738571E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.3527754675501418E-02 nfe=    136
#  iter=    2 fnrm=     0.2807935582775096E-03 nfe=    271
#  iter=    3 fnrm=     0.3102005533491421E-03 nfe=    406
#  iter=    4 fnrm=     0.8699044084069481E-04 nfe=    541
#  iter=    5 fnrm=     0.2442703623461642E-03 nfe=    676
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#   Updating Jacobian, npe =                      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    0 fnrm=     0.1691251335935321E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1502974702319159E-02 nfe=    136
#  iter=    2 fnrm=     0.8763405176798367E-04 nfe=    271
#  iter=    3 fnrm=     0.6088145461349211E-04 nfe=    406
#  iter=    4 fnrm=     0.2191309214326927E-04 nfe=    541
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             13.667%
#     -Advancing by                         0.586%
#     -Steps to target at current delta:    147
#
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.1648835039511330E-02 nfe=      1
# ===== RECOVERY LOOP ENTERED =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             13.667%
#
#  iter=    1 fnrm=     0.2216057476314538E-02 nfe=    136
#  iter=    2 fnrm=     0.1450307292012815E-02 nfe=    271
#  iter=    3 fnrm=     0.5078394916571559E-03 nfe=    406
#  iter=    4 fnrm=     0.1630590259650939E-03 nfe=    541
#  iter=    5 fnrm=     0.1214294646123562E-03 nfe=    676
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
#
# ===== STATIC ITERATION FOR DTREAL=2.00e-04 AT 13.7% =====
# *** For isimpon=2, set afracs, not afrac ***
#   Updating Jacobian, npe =                      1
#
# ===== STATIC ITERATION FOR DTREAL=1.00e-03 AT 13.7% =====
#  iter=    0 fnrm=     0.1205525947867147E-03 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1228976181549559E-04 nfe=    136
#  iter=    2 fnrm=     0.9150815879328580E-06 nfe=    271
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.1089036602969919E-03 nfe=      1
#  iter=    1 fnrm=     0.6256021169053382E-05 nfe=    136
#  iter=    2 fnrm=     0.1267619405811218E-05 nfe=    271
#  iter=    3 fnrm=     0.3754287994505652E-06 nfe=    406
#  iter=    4 fnrm=     0.1313311723090405E-06 nfe=    541
#  iter=    5 fnrm=     0.7488247145140393E-07 nfe=    676
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== STATIC ITERATION FOR DTREAL=5.00e-03 AT 13.7% =====
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.7113517996328566E-04 nfe=      1
#  iter=    1 fnrm=     0.8899588320976743E-05 nfe=    136
#  iter=    2 fnrm=     0.3707882930429534E-05 nfe=    271
#  iter=    3 fnrm=     0.1452203394200326E-05 nfe=    406
#  iter=    4 fnrm=     0.2610965234100292E-05 nfe=    541
#  iter=    5 fnrm=     0.7058167748256530E-06 nfe=    676
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
#
# ===== STATIC FNRM REDUCTION FAILED =====
#
# ===== ENTER TIME-DEPENDENT SOLVE =====
#     -Variable(s) being solved:
#                                         - afracs
#     -Progress                             13.667%
#
# *** For isimpon=2, set afracs, not afrac ***
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.5589913518708702E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.8529015836163482E-05 nfe=     81
#  iter=    2 fnrm=     0.5819255378218151E-07 nfe=    216
#  iter=    3 fnrm=     0.3485722316351656E-08 nfe=    351
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#
#  Initial successful time-step exists
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 1 New time-step: 1.00E-10 ***
# ---------------------------------------------------------------
# Solving for delta=15.667%
#  Interpolants created; mype =                   -1
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4897625281848400E-02 nfe=      1
#  iter=    1 fnrm=     0.1279209658988354E-05 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4897621343513472E-02 nfe=      1
#  iter=    1 fnrm=     0.1279399371744943E-05 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 1.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #2
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4897617405277954E-02 nfe=      1
#  iter=    1 fnrm=     0.1279679893633291E-05 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 2.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #3
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4897613467140102E-02 nfe=      1
#  iter=    1 fnrm=     0.1279830563281891E-05 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 3.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #4
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4897609529098521E-02 nfe=      1
#  iter=    1 fnrm=     0.1280103614126545E-05 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 4.0000E-10; Timestep = 1.0000E-10
#
#  Inner iteration #5
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4897605591156219E-02 nfe=      1
#  iter=    1 fnrm=     0.1280399977092989E-05 nfe=    136
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 5.0000E-10; Timestep = 1.0000E-10
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 2 New time-step: 3.40E-10 ***
# ---------------------------------------------------------------
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.4900569542805495E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.7032323727480766E-07 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4900556080718024E-02 nfe=      1
#  iter=    1 fnrm=     0.7027196030850031E-07 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 9.4000E-10; Timestep = 3.4000E-10
#
#  Inner iteration #2
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4900542620316303E-02 nfe=      1
#  iter=    1 fnrm=     0.7020728569813095E-07 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 1.2800E-09; Timestep = 3.4000E-10
#
#  Inner iteration #3
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4900529161134233E-02 nfe=      1
#  iter=    1 fnrm=     0.7016660738643794E-07 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 1.6200E-09; Timestep = 3.4000E-10
#
#  Inner iteration #4
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4900515703170750E-02 nfe=      1
#  iter=    1 fnrm=     0.7010734030650854E-07 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 1.9600E-09; Timestep = 3.4000E-10
#
#  Inner iteration #5
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4900502246421974E-02 nfe=      1
#  iter=    1 fnrm=     0.7005916166713957E-07 nfe=      3
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 2.3000E-09; Timestep = 3.4000E-10
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 3 New time-step: 1.16E-09 ***
# ---------------------------------------------------------------
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4900488790891061E-02 nfe=      1
#  iter=    1 fnrm=     0.8476198113811623E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4900443051324988E-02 nfe=      1
#  iter=    1 fnrm=     0.6832358743701693E-07 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 3.7960E-09; Timestep = 1.1560E-09
#
#  Inner iteration #2
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4900397324623939E-02 nfe=      1
#  iter=    1 fnrm=     0.2449940085778174E-09 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 4.9520E-09; Timestep = 1.1560E-09
#
#  Inner iteration #3
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4900351614922221E-02 nfe=      1
#  iter=    1 fnrm=     0.2832617177334420E-07 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 6.1080E-09; Timestep = 1.1560E-09
#
#  Inner iteration #4
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4900305916948376E-02 nfe=      1
#  iter=    1 fnrm=     0.4012794471000518E-09 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 7.2640E-09; Timestep = 1.1560E-09
#
#  Inner iteration #5
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4900260234553340E-02 nfe=      1
#  iter=    1 fnrm=     0.2833092001320022E-07 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 8.4200E-09; Timestep = 1.1560E-09
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 4 New time-step: 3.93E-09 ***
# ---------------------------------------------------------------
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.4900217145999299E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1456943687017760E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4900061995041118E-02 nfe=      1
#  iter=    1 fnrm=     0.1460550808108563E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 1.3506E-08; Timestep = 3.9304E-09
#
#  Inner iteration #2
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4899907004386551E-02 nfe=      1
#  iter=    1 fnrm=     0.1465899909687274E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 1.7437E-08; Timestep = 3.9304E-09
#
#  Inner iteration #3
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4899752174339640E-02 nfe=      1
#  iter=    1 fnrm=     0.1472640211910614E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 2.1367E-08; Timestep = 3.9304E-09
#
#  Inner iteration #4
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4899597504479218E-02 nfe=      1
#  iter=    1 fnrm=     0.1489667889823245E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 2.5298E-08; Timestep = 3.9304E-09
#
#  Inner iteration #5
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4899442994415183E-02 nfe=      1
#  iter=    1 fnrm=     0.1578875109992419E-08 nfe=      4
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 2.9228E-08; Timestep = 3.9304E-09
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 5 New time-step: 1.34E-08 ***
# ---------------------------------------------------------------
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4899288643764431E-02 nfe=      1
#  iter=    1 fnrm=     0.2651569223815772E-07 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4898765267693959E-02 nfe=      1
#  iter=    1 fnrm=     0.1689789811683685E-07 nfe=      6
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 4.6522E-08; Timestep = 1.3363E-08
#
#  Inner iteration #2
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4898243709521688E-02 nfe=      1
#  iter=    1 fnrm=     0.7108811548088624E-07 nfe=      5
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 5.9885E-08; Timestep = 1.3363E-08
#
#  Inner iteration #3
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4897723952283958E-02 nfe=      1
#  iter=    1 fnrm=     0.2328977885250163E-07 nfe=      6
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 7.3248E-08; Timestep = 1.3363E-08
#
#  Inner iteration #4
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4897205989213453E-02 nfe=      1
#  iter=    1 fnrm=     0.1786257187917973E-07 nfe=      6
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress15p667_dtrun_last_ii2.hdf5
#  Total time = 8.6612E-08; Timestep = 1.3363E-08
#
#  Inner iteration #5
#
# Solving for delta=15.667%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.4896689805894472E-02 nfe=      1
# ...
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1130E-01; Timestep = 1.3988E-05
#
#  Inner iteration #2
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5522326284606797E-01 nfe=      1
#  iter=    1 fnrm=     0.3029837380153096E-02 nfe=    111
#  iter=    2 fnrm=     0.2504428255790488E-03 nfe=    242
#  iter=    3 fnrm=     0.1037484208762498E-03 nfe=    377
#  iter=    4 fnrm=     0.8354879262480536E-04 nfe=    513
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1132E-01; Timestep = 1.3988E-05
#
#  Inner iteration #3
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5547148252005085E-01 nfe=      1
#  iter=    1 fnrm=     0.1427117629331703E-02 nfe=    102
#  iter=    2 fnrm=     0.1015643639520808E-02 nfe=    237
#  iter=    3 fnrm=     0.4694950409080891E-03 nfe=    372
#  iter=    4 fnrm=     0.6037060033793904E-04 nfe=    507
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1133E-01; Timestep = 1.3988E-05
#
#  Inner iteration #4
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5574914438539583E-01 nfe=      1
#  iter=    1 fnrm=     0.6891043725199464E-03 nfe=     98
#  iter=    2 fnrm=     0.1412338582253274E-03 nfe=    233
#  iter=    3 fnrm=     0.4299709998055070E-04 nfe=    368
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1135E-01; Timestep = 1.3988E-05
#
#  Inner iteration #5
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5594772415464887E-01 nfe=      1
#  Total time = 1.1135E-01; Timestep = 1.3988E-05  iter=    1 fnrm=     0.2192133513786443E-02 nfe=    105
#  iter=    2 fnrm=     0.2245638094770674E-02 nfe=    245
#  iter=    3 fnrm=     0.2263997802999284E-02 nfe=    381
#  iter=    4 fnrm=     0.2440571444712021E-02 nfe=    519
#  iter=    5 fnrm=     0.8354837142516415E-03 nfe=    654
#  iter=    6 fnrm=     0.5454051804586233E-03 nfe=    789
#  iter=    7 fnrm=     0.5761312111629679E-03 nfe=    926
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
#
#
# ** Fortran index of trouble making equation is:
# 17712
# ** Number of equations solved per cell:
#     numvar = 6
#
# ** Troublemaker equation is:
# Ion energy equation: iv_t=6
#
# ** Troublemaker cell (ix,iy) is:
# [47 44]
#
# ** Timestep for troublemaker equation:
# 1.3988e-05
#
# ** yl for troublemaker equation:
# 3.3186e-02
#
# ** yldot*sfscal for troublemaker equation:
# 1.6718e-04
#
# *** Converg. fails for bbb.dtreal; reduce time-step by 3, try again ***
# -----------------------------------------------------------------------
# -----------------------------------------------------------------
# *** Number of time-step changes = 148 New time-step: 4.66E-06 ***
# -----------------------------------------------------------------
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5594772415464887E-01 nfe=      1
#  iter=    1 fnrm=     0.5692337120296611E-04 nfe=    114
#  iter=    2 fnrm=     0.2298952691394118E-05 nfe=    249
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5601387871980055E-01 nfe=      1
#  iter=    1 fnrm=     0.4568656223221500E-04 nfe=    113
#  iter=    2 fnrm=     0.1485209653713126E-05 nfe=    248
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1136E-01; Timestep = 4.6626E-06
#
#  Inner iteration #2
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5606500286931967E-01 nfe=      1
#  iter=    1 fnrm=     0.5319894017309823E-04 nfe=    120
#  iter=    2 fnrm=     0.2195856630498324E-05 nfe=    255
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1137E-01; Timestep = 4.6626E-06
#
#  Inner iteration #3
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5610008519351151E-01 nfe=      1
#  iter=    1 fnrm=     0.7292909710666150E-04 nfe=    121
#  iter=    2 fnrm=     0.7516629609101890E-05 nfe=    256
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1137E-01; Timestep = 4.6626E-06
#
#  Inner iteration #4
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5611343308375600E-01 nfe=      1
#  Total time = 1.1137E-01; Timestep = 4.6626E-06  iter=    1 fnrm=     0.5164656922423853E-03 nfe=    134
#  iter=    2 fnrm=     0.4844235104290176E-03 nfe=    272
#  iter=    3 fnrm=     0.5148137778740019E-03 nfe=    409
#  iter=    4 fnrm=     0.4414695572292418E-03 nfe=    545
#  iter=    5 fnrm=     0.4805702374069133E-03 nfe=    684
#  iter=    6 fnrm=     0.4077159696494376E-03 nfe=    820
#  iter=    7 fnrm=     0.4390362223632701E-03 nfe=    961
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
#
#
# ** Fortran index of trouble making equation is:
# 17948
# ** Number of equations solved per cell:
#     numvar = 6
#
# ** Troublemaker equation is:
# Ion density equation of species 2: iv_t=2
#
# ** Troublemaker cell (ix,iy) is:
# [21 45]
#
# ** Timestep for troublemaker equation:
# 4.6626e-06
#
# ** yl for troublemaker equation:
# 1.6432e-04
#
# ** yldot*sfscal for troublemaker equation:
# 2.7031e-04
#
# *** Converg. fails for bbb.dtreal; reduce time-step by 3, try again ***
# -----------------------------------------------------------------------
# -----------------------------------------------------------------
# *** Number of time-step changes = 149 New time-step: 1.55E-06 ***
# -----------------------------------------------------------------
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.5668393549256693E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1832758204855345E-04 nfe=     56
#  iter=    2 fnrm=     0.4695907145679237E-06 nfe=    163
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5669023621165644E-01 nfe=      1
#  iter=    1 fnrm=     0.4413168239654827E-04 nfe=     56
#  iter=    2 fnrm=     0.1145930562621947E-04 nfe=    163
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1138E-01; Timestep = 1.5542E-06
#
#  Inner iteration #2
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5669960350787501E-01 nfe=      1
#  iter=    1 fnrm=     0.7592522023071127E-03 nfe=     57
#  iter=    2 fnrm=     0.5999459037841472E-04 nfe=    153
#  iter=    3 fnrm=     0.4253188014110234E-06 nfe=    260
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1138E-01; Timestep = 1.5542E-06
#
#  Inner iteration #3
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5672616615044569E-01 nfe=      1
#  iter=    1 fnrm=     0.7675835319529705E-03 nfe=     58
#  iter=    2 fnrm=     0.2789706505204713E-04 nfe=    156
#  iter=    3 fnrm=     0.5352495706961348E-07 nfe=    264
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1138E-01; Timestep = 1.5542E-06
#
#  Inner iteration #4
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5677669082461925E-01 nfe=      1
#  iter=    1 fnrm=     0.5856451924476392E-03 nfe=     56
#  iter=    2 fnrm=     0.5782273309046038E-05 nfe=    159
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1138E-01; Timestep = 1.5542E-06
#
#  Inner iteration #5
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5684629991137102E-01 nfe=      1
#  iter=    1 fnrm=     0.4421410289066916E-03 nfe=     51
#  iter=    2 fnrm=     0.2044223679370102E-05 nfe=    156
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1139E-01; Timestep = 1.5542E-06
#
# -----------------------------------------------------------------
# *** Number of time-step changes = 150 New time-step: 4.66E-06 ***
# -----------------------------------------------------------------
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5692753648761616E-01 nfe=      1
#  iter=    1 fnrm=     0.1909164125105865E-02 nfe=     72
#  iter=    2 fnrm=     0.2303433608282753E-03 nfe=    199
#  iter=    3 fnrm=     0.9328492020501078E-05 nfe=    332
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5710556646731052E-01 nfe=      1
#  iter=    1 fnrm=     0.1644887770714713E-02 nfe=     74
#  iter=    2 fnrm=     0.1531137448913291E-03 nfe=    184
#  iter=    3 fnrm=     0.2631593349110085E-05 nfe=    318
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1139E-01; Timestep = 4.6626E-06
#
#  Inner iteration #2
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5718885287859454E-01 nfe=      1
#  iter=    1 fnrm=     0.2056209726192788E-02 nfe=     74
#  iter=    2 fnrm=     0.2713646425618823E-03 nfe=    196
#  iter=    3 fnrm=     0.4080777494534634E-05 nfe=    315
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1140E-01; Timestep = 4.6626E-06
#
#  Inner iteration #3
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5697779146419561E-01 nfe=      1
#  iter=    1 fnrm=     0.5547823430811537E-03 nfe=     77
#  iter=    2 fnrm=     0.7753127872150283E-04 nfe=    209
#  iter=    3 fnrm=     0.5391947551601895E-05 nfe=    344
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1140E-01; Timestep = 4.6626E-06
#
#  Inner iteration #4
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5664128113246730E-01 nfe=      1
#  iter=    1 fnrm=     0.1349358017918975E-02 nfe=     78
#  iter=    2 fnrm=     0.5943257908738878E-03 nfe=    205
#  iter=    3 fnrm=     0.1839068738203980E-04 nfe=    327
#  iter=    4 fnrm=     0.2730496456466616E-07 nfe=    462
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1141E-01; Timestep = 4.6626E-06
#
#  Inner iteration #5
#
# Solving for delta=27.222%
# *** For isimpon=2, set afracs, not afrac ***
#  iter=    0 fnrm=     0.5653994910225664E-01 nfe=      1
#  iter=    1 fnrm=     0.5008707856149156E-03 nfe=     76
#  iter=    2 fnrm=     0.3835261854931892E-05 nfe=    206
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./impu_up/progress27p222_dtrun_last_ii2.hdf5
#  Total time = 1.1141E-01; Timestep = 4.6626E-06
#
# =====================================
# ===== CONTINUATION SOLVE FAILED =====
# =====================================
# Progress upon abortion: 25.222%

# %%
c.solver.convergenceanalysis('reconverged_v12_p3.93_n2.38_imp1e4_dp0.06_kep0.06_kip0.0226_last_ii2.hdf5');

# %% [markdown]
# # Inner plate

# %%
# %matplotlib widget
bbb.fqp=0
bbb.plateflux(); #internally calculated fluxes (postprocessing)

fig, axs = plt.subplot_mosaic(
    [['TopLeft', 'TopRight'],
     ['Bottom', 'Bottom']],
    layout='constrained',  # Automatically adjust layout
    width_ratios=[1, 1],   # Equal width for the top plots
)
fig.suptitle('Inner heat fluxes')
fig.supxlabel('Distance along inner plate (m)')
fig.supylabel('Heat flux (MW/m**2)')
# axs['TopRight'].set_xlabel("Distance along inner plate (m)")
#axs['TopRight'].set_ylabel("feex (W)")
axs['TopRight'].set_title("Electrons")
axs['TopRight'].plot(com.yylb[1:-1],bbb.sdelb[1:-1,0]*1e-6)

# axs['TopLeft'].set_xlabel("Distance along inner plate (m)")
# axs['TopLeft'].set_ylabel("Heat flux (MW/m**2)")
axs['TopLeft'].set_title("Ions/Atoms")
axs['TopLeft'].plot(com.yylb[1:-1],bbb.sdilb[1:-1]*1e-6) #polodal east field area

# axs['Bottom'].set_xlabel("Distance along inner plate (m)")
# axs['Bottom'].set_ylabel("Heat flux [MW/m**2]")
axs['Bottom'].set_title("Particle+radiation heat flux")
axs['Bottom'].plot(com.yylb,1.e-6*(bbb.sdtlb+bbb.sdrlb))
plt.show()

# %% [markdown]
# # Length Scale Calculations

# %%
#lambda_q from Eich = 1.06mm (we are probably a bit wider, so I am targeting 1.1mm, lambda_t = 3
from scipy.optimize import curve_fit
from scipy.interpolate import UnivariateSpline
# NEED: ION HEAT, ELECTRON HEAT, ION DENSITY
poloidal_index = 28 # CHANGE TO 28 for in board, 32 out board
# exponential fit

#ELECTRONS HEAT 
eheat = -np.array(bbb.feex[poloidal_index,1:-1]) #add a minus sign for inboard
dist = np.array([val[0] for val in com.yylb[1:-1]])
mask = dist >= 0
eheat = eheat[mask]
dist = dist[mask]
# Params[0]=a, params[1]=b
# b=-1/lambda_q
params, pcov = curve_fit(lambda t,a,b: a*np.exp(b*t),  dist,  eheat,  p0=(0.5, 1/4))

y_fit = params[0]*np.exp(params[1]*dist)

plt.plot(dist, eheat, label="Data")

plt.title("e Heat (W)")
plt.plot(dist, y_fit, 'r-', label="Fit")
plt.gca().set_xlim(left=0)
# plt.axhline(y=0.0, color='r', linestyle='-')
plt.legend()
# plt.yscale('log')
plt.show()
print(f"Lambda_q estimate: {-1/params[1]*1000} mm")

# calc 99% heat flux
# electron TEMP REGION
from scipy.integrate import simpson
totalheat = simpson(eheat, x=dist)
from scipy.integrate import cumulative_trapezoid
cumulative_integral = cumulative_trapezoid(eheat, dist, initial=0)
target_scale = 0.999
target_value = target_scale * cumulative_integral[-1]

index = np.searchsorted(cumulative_integral, target_value)

decaylen = dist[index]
poloidal_index = 28
etemp= np.array(bbb.te[poloidal_index,1:-1]/bbb.ev)
etemp = etemp[mask]

# Interpolating to get exact temp at wall
interp_func = UnivariateSpline(dist[10:17], etemp[10:17])
x = np.arange(0.015, 0.025, 0.001)

y = interp_func(x)

wallIndex = np.where(abs(x - 0.02) < 0.0000001)[0][0]


# print(np.shape(dist),np.shape(eheat), np.shape(etemp))
print(f"{target_scale*100}% of heat flux at x = {(decaylen*100):.3f}cm, e temp = {etemp[index]:.3f} eV")
print(f"*** at x = 2cm (Index = {wallIndex}), interpolated Elc temp = {y[wallIndex]:.3f} eV ***")
print(f"at x = {(dist[13]*100):.3f}cm, Elc temp = {etemp[13]:.3f} eV")
print(f"at x = {(dist[16]*100):.3f}cm, Elc temp = {etemp[16]:.3f} eV")
print(f"at x = {(dist[21]*100):.3f}cm, Elc temp = {etemp[21]:.3f} eV")
plt.plot(x, y)
plt.plot(dist, etemp)
plt.title('Interpolation region check')
plt.xlim([0.015,0.025])
plt.ylim([7.5,17])
plt.show()
# tparams, tpcov = curve_fit(lambda t,a,b: a*np.exp(b*t),  dist,  etemp,  p0=(0.5, -1))
plt.plot(dist, etemp)
plt.title("e Temp (eV)")
plt.show()
targeteV = 5
eev = np.searchsorted(etemp[::-1], targeteV, side = "right")*-1

print(f"{targeteV}ev at x = {dist[eev]*100}cm")
# Out:
# Lambda_q estimate: 1.2949619384236644 mm
# 99.9% of heat flux at x = 3.752cm, e temp = 5.007 eV
# *** at x = 2cm (Index = 5), interpolated Elc temp = 11.524 eV ***
# at x = 2.092cm, Elc temp = 10.848 eV
# at x = 2.978cm, Elc temp = 6.757 eV
# at x = 5.326cm, Elc temp = 3.267 eV
# 5ev at x = 4.210907209462682cm

# %%
#lambda_q from Eich = 1.06mm (we are probably a bit wider, so I am targeting 1.1mm, lambda_t = 3
from scipy.optimize import curve_fit
from scipy.interpolate import UnivariateSpline
# NEED: ION HEAT, ELECTRON HEAT, ION DENSITY
poloidal_index = 28 # CHANGE TO 28 for in board, 32 out board
# exponential fit

# IONS HEAT
ionheat = -np.array(bbb.feix[poloidal_index,1:-1]) #add a minus sign for inboard
dist = np.array([val[0] for val in com.yylb[1:-1]])
mask = dist >= 0
ionheat = ionheat[mask]
dist = dist[mask]
# Params[0]=a, params[1]=b
# b=-1/lambda_q
params, pcov = curve_fit(lambda t,a,b: a*np.exp(b*t),  dist,  ionheat,  p0=(0.5, -1))
#print(pcov)
#print(params)
y_fit = params[0]*np.exp(params[1]*dist)
# print(y_fit)
# Plot the results
plt.plot(dist, ionheat, label="Data")
plt.title("Ion Heat (W)")
plt.plot(dist, y_fit, 'r-', label="Fit")
plt.gca().set_xlim(left=0)
# plt.axhline(y=0.0, color='r', linestyle='-')
plt.legend()
plt.show()
print(f"Lambda_q estimate: {-1/params[1]*1000} mm")

# ION TEMP REGION
from scipy.integrate import simpson
totalheat = simpson(ionheat, x=dist)
from scipy.integrate import cumulative_trapezoid
cumulative_integral = cumulative_trapezoid(ionheat, dist, initial=0)
target_scale = 0.999
target_value = target_scale * totalheat
iontemp= np.array(bbb.ti[poloidal_index,1:-1]/bbb.ev)
iontemp = iontemp[mask]


# Interpolation check
interp_func = UnivariateSpline(dist[10:17], iontemp[10:17])
x = np.arange(0.015, 0.025, 0.001)
# print(x)
y = interp_func(x)

wallIndex = np.where(abs(x - 0.02) < 0.0000001)[0][0]


index = np.searchsorted(cumulative_integral, target_value)
# print("HI",dist[13])
decaylen = dist[index]
poloidal_index = 29
iontemp= np.array(bbb.ti[poloidal_index,1:-1]/bbb.ev)
iontemp = iontemp[mask]
print(f"{target_scale*100}% of heat flux at x = {(decaylen*100):.3f}cm, Ion temp = {iontemp[index]:.3f} eV")
print(f"*** at x = 2cm (Index = {wallIndex}), interpolated Ion temp = {y[wallIndex]:.3f} eV ***")
print(f"at x = {(dist[13]*100):.3f}cm, Ion temp = {iontemp[13]:.3f} eV")
print(f"at x = {(dist[16]*100):.3f}cm, Ion temp = {iontemp[16]:.3f} eV")
print(f"at x = {(dist[21]*100):.3f}cm, Ion temp = {iontemp[21]:.3f} eV")
# tparams, tpcov = curve_fit(lambda t,a,b: a*np.exp(b*t),  dist,  iontemp,  p0=(0.5, -1))
plt.plot(x, y)
plt.plot(dist, etemp)
plt.title('Interpolation region check')
plt.xlim([0.015,0.025])
plt.ylim([7.5,17])
plt.show()
targeteV = 10
iev = np.searchsorted(iontemp[::-1], targeteV, side = "right")*-1

print(f"{targeteV}ev at x = {dist[iev]*100}cm")
plt.xlabel("Distance from separatrix (m)")
plt.ylabel("eV")
plt.title("Ion temp")
plt.plot(com.yylb[1:-1],bbb.ti[34,1:-1]/bbb.ev)
plt.axhline(y=5, color='r', linestyle='-')
plt.gca().set_xlim(left=0)
plt.yscale('log') 
plt.show()
# Out:
# Lambda_q estimate: 2.3386383037574534 mm
# 99.9% of heat flux at x = 2.978cm, Ion temp = 4.747 eV
# *** at x = 2cm (Index = 5), interpolated Ion temp = 6.902 eV ***
# at x = 2.092cm, Ion temp = 6.638 eV
# at x = 2.978cm, Ion temp = 4.747 eV
# at x = 5.326cm, Ion temp = 3.705 eV
# 10ev at x = 1.4385881170351815cm

# %% [markdown]
# # Midplane

# %%
# %matplotlib widget
plt.xlabel("Distance from separatrix (m)")
plt.ylabel("ions/m^3")
plt.title("Ion density")
plt.plot(com.yylb[1:-1],bbb.ni[28,1:-1,0])
plt.show()
plt.xlabel("Distance from separatrix (m)")
plt.ylabel("eV")
plt.title("Ion temp")
plt.plot(com.yylb[1:-1],bbb.ti[28,1:-1]/bbb.ev)
plt.show()
plt.xlabel("Distance from separatrix (m)")
plt.ylabel("eV")
plt.title("Elc temp")
plt.plot(com.yylb[1:-1],bbb.te[28,1:-1]/bbb.ev)
plt.plot(com.yylb[1:-1],bbb.te[31,1:-1]/bbb.ev)
plt.show()

plt.plot(com.yylb[1:-1], bbb.ne[30,1:-1])
plt.xlabel('Distance from Separatrix (m)')
plt.title('Elc density Inner Midplane')
plt.show()
plt.plot(com.yylb[1:-1], bbb.ne[31,1:-1])
plt.xlabel('Distance from Separatrix (m)')
plt.title('Elc density Outer Midplane')
#inner limit of dist. from separatrix should correspond with the rho coord of temp and n BC so rho * minor rad. (0.72m)
#rho=0.92
bbb.ni[28,1:-1,0].size
# Out:
# 44

# %%
rho = (com.yylb[1:-1] / 0.72) + 1
n_e = bbb.ne[31,1:-1].reshape(44)
rho = rho.reshape(44)
np.savetxt('midplane_ne.csv', np.vstack((rho,n_e)).T, delimiter=', ')
t_i = bbb.ti[31,1:-1].reshape(44)
t_e = bbb.te[31,1:-1].reshape(44)
n_i = bbb.ni[31,1:-1,0].reshape(44)
np.savetxt('midplane_ti.csv', np.vstack((rho,t_i)).T, delimiter=', ')
np.savetxt('midplane_te.csv', np.vstack((rho,t_e)).T, delimiter=', ')
np.savetxt('outmidplane_ni.csv', np.vstack((rho,n_i)).T, delimiter=', ')
plt.plot(rho, n_i)

# %% [markdown]
# # Outer plate

# %%
# total convective and conductive heat flux
# 2nd char: e for energy n for particle
bbb.fqp=0
bbb.plateflux(); #internally calculated fluxes (postprocessing)

plt.figure()
fig, axs = plt.subplot_mosaic(
    [['TopLeft', 'TopRight'],
     ['Bottom', 'Bottom']],
    layout='constrained',  # Automatically adjust layout
    width_ratios=[1, 1],   # Equal width for the top plots
)
fig.suptitle('Outer heat fluxes')
fig.supxlabel('Distance along outer plate (m)')
fig.supylabel('Heat flux (MW/m**2)')
# axs['TopRight'].set_xlabel("Distance along inner plate (m)")
#axs['TopRight'].set_ylabel("feex (W)")
axs['TopRight'].set_title("Electrons")
axs['TopRight'].plot(com.yyrb[1:-1],bbb.sderb[1:-1,0]*1e-6)

# axs['TopLeft'].set_xlabel("Distance along inner plate (m)")
# axs['TopLeft'].set_ylabel("Heat flux (MW/m**2)")
axs['TopLeft'].set_title("Ions/Atoms")
axs['TopLeft'].plot(com.yyrb[1:-1],bbb.sdirb[1:-1,0]*1e-6) #polodal east field area


# axs['Bottom'].set_xlabel("Distance along inner plate (m)")
# axs['Bottom'].set_ylabel("Heat flux [MW/m**2]")
axs['Bottom'].set_title("Particle+radiation heat flux")
axs['Bottom'].plot(com.yyrb,1.e-6*(bbb.sdtrb+bbb.sdrrb))
plt.show()
max(1.e-6*(bbb.sdtrb+bbb.sdrrb))
# Out:
# array([33.50015493])

# %%
np.sum( (bbb.sdtrb+bbb.sdrrb)) / 1e6
# Out:
# np.float64(25.673051490542424)

# %% [markdown]
# # 2D Plots

# %%
plt.figure()

c.plot.grid(linewidth=0.1, #grid plot
   vessel=True, 
   plates=True, 
   platecolor=['gold','teal'], 
   lcfs=True, 
   xlim=(1.8, 2.8), 
   ylim=(0.1,0.85),
   lcfscolor='r', 
   linecolor='b',
   title='Mesh grid'
  );

c.plot.mesh(
    bbb.ne, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85),
    figsize=(7,5), 
    zrange=(1e8,1e21), 
    cmap='gist_heat',
    title='Electron density'
);


c.plot.mesh(
    abs(bbb.feex), 
    log=True,
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    zrange=(1,1e6),
    cmap='inferno',
    title='Electron heat (W)'
);
c.plot.mesh(
    bbb.te/bbb.ev, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    # zrange=(-5e5,5e5),
    cmap='seismic',
    title='Electron temperature (eV)'
);

c.plot.mesh(
    bbb.ne, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85),
    figsize=(7,5), 
    zrange=(1e10,1e22), 
    cmap='gist_heat',
    title='Ion density'
);
c.plot.mesh(
    bbb.feix, 
    # xlim=(1.8, 2.8), 
    # ylim=(0.1,0.85),
    figsize=(7,5), 
    # zrange=(-8e5,8e5),
    cmap='seismic',
    title='Ion heat (W)'
);
c.plot.mesh(
    bbb.te/bbb.ev, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    # zrange=(-5e5,5e5),
    cmap='seismic',
    title='Ion temperature (eV)'
);
c.plot.mesh(
    bbb.na, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    # zrange=(-5e5,5e5),
    cmap='seismic',
    title='Impurity concentration (m^-3)'
);
c.plot.mesh(
    bbb.prad, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    # zrange=(-5e5,5e5),
    cmap='seismic',
    title='Power Radiation'
);
plt.show()

# %%
c.dashboard() # a GUI with all the most common variable
# Out:
# 2024-12-03 17:38:59.660 python[30589:1509532] +[IMKClient subclass]: chose IMKClient_Modern
# 2024-12-03 17:38:59.660 python[30589:1509532] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %% [markdown]
# # Zeff

# %%
nD = bbb.ni.transpose()
nT = nD[1] # deut density - atomic density
nD = nD[0] # deut density - ion density
nT = nT.transpose()
nD = nD.transpose()
zeff = (nT+nD+(bbb.na*10))/bbb.ne
c.plot.mesh(
    zeff, 
    log=True, 
    xlim=(1.8, 2.8), 
    ylim=(0.1,0.85), 
    figsize=(7,5), 
    zrange=(1,10),
    cmap='seismic',
    title='Impurity concentration (m^-3)'
);
bbb.minu[0]
# Out:
# 2.5

# %%
y = zeff[17:41,2]
plt.plot(y)
plt.show()
y
# Out:
# array([1.40000004, 1.40000005, 1.40000019, 1.40000039, 1.40000033,
#        1.40000017, 1.40000008, 1.40000004, 1.40000003, 1.40000002,
#        1.40000002, 1.40000002, 1.40000002, 1.40000002, 1.40000004,
#        1.40000004, 1.40000015, 1.40000073, 1.40000309, 1.40000327,
#        1.40000184, 1.40000061, 1.4000001 , 1.40000004])

# %% [markdown]
# # Power Calculations

# %%
c = Case('reconverged_v12_p3.93_n2.38_imp5e3_dp0.06_kep0.06_kip0.06_last_ii2.hdf5')
# Out:
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../jupyter/MANTA_final_baseline/reconverged_v12_p3.93_n2.38_imp5e3_dp0.06_kep0.06_kip0.06_last_ii2.hdf5
#   User-specified diffusivities read from HDF5 file ".../jupyter/MANTA_final_baseline/reconverged_v12_p3.93_n2.38_imp5e3_dp0.06_kep0.06_kip0.06_last_ii2.hdf5"
# UETOOLS-style save successfully restored from .../jupyter/MANTA_final_baseline/reconverged_v12_p3.93_n2.38_imp5e3_dp0.06_kep0.06_kip0.06_last_ii2.hdf5
# *** For isimpon=2, set afracs, not afrac ***
#
# *** UEDGE arrays populated: Warning, case may noy be fully converged ***
# fnrm without preconditioning: 94.4

# %%
from scipy.integrate import simpson
bbb.fqp=0
bbb.plateflux();

pcore = simpson( (bbb.feiy+bbb.feey)[com.ixpt1[0]+1:com.ixpt2[0]+1,0]) / 1e6
psep = simpson( (bbb.feiy+bbb.feey)[com.ixpt1[0]+1:com.ixpt2[0]+1,com.iysptrx]) / 1e6

print(f' Power from core boundary (surface closest to magnetic axis) = {pcore:.3f} MW  \n \
Power at Separatrix = {psep:.3f} MW  \n \
Power radiated in core region = {(pcore-psep):.3f} MW = {((abs(pcore-psep)/pcore)*100):3f}%')
particlecore = simpson( (bbb.fniy)[com.ixpt1[0]+1:com.ixpt2[0],0])

pleft = simpson( (bbb.feiy+bbb.feey)[com.ixpt1[0]+1:32,com.iysptrx]) / 1e6
pright = simpson( (bbb.feiy+bbb.feey)[32:com.ixpt2[0]+1,com.iysptrx]) / 1e6
print(f'From LCFS, {(pright/pleft):.3f} times more power going out into high field side than low field side\n Left:{pleft} MW | Right: {pright} MW')
# Out:
#  Power from core boundary (surface closest to magnetic axis) = 7.970 MW
#  Power at Separatrix = 5.410 MW
#  Power radiated in core region = 2.559 MW = 32.113384%
# From LCFS, 1.355 times more power going out into high field side than low field side
#  Left:2.120179577333994 MW | Right: 2.8718041746833274 MW

# %%
impFracs = [1e-4, 3e-3, 3e-2]
pRads = [33.11, 33.9, 42.5]

# %%
c.search.var("dif_use")
c.search.var("zaxpt")
# bbb.turb_chi()
bbb.up
# Out:
# Package:    bbb
# Group:      Conduc
# Attributes: Conduc input
# Dimension:  (0:nx+1,0:ny+1,1:nisp)
#             (66, 46, 2)
# Type:       double
# Address:    13021511680
# Pyaddress:  4817956624
# Unit:       m**2/s
# Comment:
# spatially depend. diff; if
# isbohmcalc=1, user input if all
# facbni+facbup+facbee+facbei =0,
# or kybohm if facbni, etc. > 0;
# if isbohmcalc=2, then
# D = difni*kybohm/(difni+kybohm)
# Package:    grd
# Group:      Analgrd
# Attributes: Analgrd gridgen
# Type:       double
# Address:    4818976272
# Unit:       m
# Comment:
# position of x-point; uniform grid to here
# array([[[-10855.51639259, -11431.43962379],
#         [-11971.11898326, -11372.56303412],
#         [-12063.32995936, -11460.16346141],
#         ...,
#         [-16742.86949573, -15905.72602096],
#         [-16736.78214279, -15899.94303563],
#         [-17113.88306861, -15894.80316941]],
#
#        [[ -9739.91380191, -11490.31621345],
#         [-11658.821658  , -11478.05857042],
#         [-11487.48532541, -11705.64496157],
#         ...,
#         [-16740.40383117, -15901.76312305],
#         [-16736.45900437, -15893.95033633],
#         [-17490.98399448, -15889.66330317]],
#
#        [[ -9775.39927487, -11943.00668698],
#         [-11473.56998083, -12050.62901481],
#         [-11237.46029189, -12474.12169535],
#         ...,
#         [-16733.06424669, -15895.77674864],
#         [-16735.26961347, -15887.54006081],
#         [-17451.30107602, -15883.59246353]],
#
#        ...,
#
#        [[  7885.9473896 ,   9847.58153258],
#         [  9934.65902927,   9784.36208432],
#         [  9136.08665206,   9007.2762516 ],
#         ...,
#         [ 11879.35905299,  11355.01421358],
#         [ 11918.64525057,  11336.19924488],
#         [ 12358.25720117,  11322.07147967]],
#
#        [[  9168.04253666,   9887.60616604],
#         [ 10450.13768373,   9927.63079954],
#         [  9533.61263481,   9056.93200307],
#         ...,
#         [ 11972.17008938,  11373.56158492],
#         [ 11954.03353185,  11356.33185525],
#         [ 12156.14536652,  11339.2016675 ]],
#
#        [[  9168.04253666,   9887.60616604],
#         [ 10450.13768373,   9927.63079953],
#         [  9533.61263481,   9056.93200306],
#         ...,
#         [ 11972.17008938,  11373.56158492],
#         [ 11954.03353185,  11356.33185525],
#         [ 12156.14536652,  11339.2016675 ]]])

# %%
len(bbb.te[28])
# Out:
# 46
