# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from uedge import *
from uedge.hdf5 import *
#import plotmesh as pm
from uetools import Case
from uedge.gridue import write_gridue
from Forthon import gchange
# Out:
# UEDGE configuration file /Users/paullab/.uetoolsrc read.

# %%
name = 'first_force_balance_last_ii2'
c = Case(name+'.hdf5')
c.solver.convergenceanalysis(name+'.hdf5');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 name = 'first_force_balance_last_ii2'
# ----> 2 c = Case(name+'.hdf5')
#       3 c.solver.convergenceanalysis(name+'.hdf5')
#
# NameError: name 'Case' is not defined

# %% [markdown]
# # Generate Grid

# %%
# %matplotlib widget
from gridgen_v15 import setGrid
setGrid()
# Out:
#
# ***  alfcy_inner has been re-defined  ***
#
#
#      alfcy_inner =   2.627351E+00
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 # %matplotlib widget
#       2 from gridgen_v15 import setGrid
# ----> 3 setGrid()
#
# File ~/ReactorDesign/UETOOLS-Reactor/jupyter/MANTA_final_baseline/gridgen_v15.py:78, in setGrid(steps, plot)
#      76 flx.flxrun() # Generate flux surface based on the above
#      77 if plot:
# ---> 78     f = c.grid.plot.flx()
#      79     f.get_axes()[0].plot(com.rseps, com.zseps, 'ro')
#      80     f.get_axes()[0].plot(com.rseps2, com.zseps2, 'go')
#
# File ~/miniforge3/envs/reactor/lib/python3.11/site-packages/uetools/UeGrid/Grid.py:291, in GridPlot.flx(self, ax, surfaces)
#     285 for i in rng:
#     286     # Plot SOL flux surfaces for each half-mesh
#     287     if ((i >= jmin[0] - 1) and (i < jsptrx[0])) or (
#     288         (i >= jsptrx[1]) and (i <= jmax[1])
#     289     ):
#     290         ax.plot(
# --> 291             xcurve[:, i][abs(xcurve[:, i]) > 0],
#     292             ycurve[:, i][abs(ycurve[:, i]) > 0],
#     293             "k-",
#     294             linewidth=0.3,
#     295         )
#     296     # Plot CORE/PFR flux surfaces for each half-mesh
#     297     elif ((i >= jsptrx[0]) and (i <= jmax[0])) or (
#     298         (i >= jmin[1] - 1) and (i <= jsptrx[1] + 1)
#     299     ):
#
# IndexError: index 91 is out of bounds for axis 1 with size 91

# %%
c = Case()
c.solver.convergenceanalysis('reconverged_v12_p3.93_n2.38_imp8.5e3_dp0.06_kep0.06_kip0.06_last_ii2.hdf5');

# %% [markdown]
# # Gridmorph

# %%
c = Case('input_v9_integrated_puff.yaml')
# Out:
# No diffusivity-file supplied: reading from save-file ".../jupyter/MANTA_final_baseline/reconverged_v9_integrated_puff2_last_ii2.hdf5"
#   User-specified diffusivities read from HDF5 file ".../jupyter/MANTA_final_baseline/reconverged_v9_integrated_puff2_last_ii2.hdf5"
# UETOOLS-style save successfully restored from .../jupyter/MANTA_final_baseline/reconverged_v9_integrated_puff2_last_ii2.hdf5
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 2.16e-04

# %%
import subprocess

proc = subprocess.Popen(['caffeinate'])

try:
    c.solver.gridmorph("gridue_v9_long.hdf5", 'gridmorph2', dt=1e20)  
finally:
    # Terminate caffeinate
    proc.terminate()
# Out:
# *----------------------------------------------------------*
#  Need to take initial step with Jacobian; trying to do here
# *----------------------------------------------------------*
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             0.000%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    1000
#
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.6118683944166938E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.9450456961193886E-04 nfe=     58
#  iter=    2 fnrm=     0.5831861877172650E-07 nfe=    123
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             0.000%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    1000
#
#  iter=    0 fnrm=     0.5831861863864253E-07 nfe=      1
#  iter=    1 fnrm=     0.2233586396594491E-11 nfe=     72
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to gridmorph2/progress0p100.hdf5
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             0.100%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    999
#
#  iter=    0 fnrm=     0.6131054889937156E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    1 fnrm=     0.8827074542043338E-04 nfe=     58
#  iter=    2 fnrm=     0.5773605090179901E-07 nfe=    122
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             0.200%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    998
#
#  iter=    0 fnrm=     0.6143518233673739E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    1 fnrm=     0.1421148560751615E-03 nfe=     58
#  iter=    2 fnrm=     0.5720880638502436E-07 nfe=    119
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 4/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             0.300%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    997
#
#  iter=    0 fnrm=     0.6156072812738308E-02 nfe=      1
#  iter=    1 fnrm=     0.6023066983132688E-04 nfe=     58
#  iter=    2 fnrm=     0.5652455289643351E-07 nfe=    124
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 5/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             0.400%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    996
#
#  iter=    0 fnrm=     0.6168705065158739E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    1 fnrm=     0.4494946368861796E-04 nfe=     58
#  iter=    2 fnrm=     0.5670018393587284E-07 nfe=    125
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 6/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             0.500%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    995
#
#  iter=    0 fnrm=     0.6181393497652693E-02 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    1 fnrm=     0.4607392923363403E-04 nfe=     58
#  iter=    2 fnrm=     0.5653119792470593E-07 nfe=    125
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 7/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             0.600%
#     -Advancing by                         0.100%
#     -Steps to target at current delta:    994
#
#  iter=    0 fnrm=     0.6194130736984794E-02 nfe=      1
#
# ===== INNER LOOP COMPLETED: ADVANCING DELTA =====
#  iter=    1 fnrm=     0.1463010005638402E-03 nfe=     58
#  iter=    2 fnrm=     0.6381816353480705E-07 nfe=    123
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             0.700%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    451
#
#   Updating Jacobian, npe =                      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    0 fnrm=     0.1343162818678192E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.4720619275507232E-03 nfe=     53
#  iter=    2 fnrm=     0.5546823133305477E-06 nfe=    118
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             0.920%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    450
#
#  iter=    0 fnrm=     0.1349218750087769E-01 nfe=      1
#  iter=    1 fnrm=     0.2502021488481679E-03 nfe=     56
#  iter=    2 fnrm=     0.4340797473663071E-06 nfe=    122
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to gridmorph2/progress1p140.hdf5
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             1.140%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    449
#
#  iter=    0 fnrm=     0.1355367150494610E-01 nfe=      1
#  iter=    1 fnrm=     0.2189936007960454E-03 nfe=     56
#  iter=    2 fnrm=     0.4375268898296019E-06 nfe=    122
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 4/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             1.360%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    448
#
#  iter=    0 fnrm=     0.1361591130832072E-01 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    1 fnrm=     0.3338655832119369E-03 nfe=     56
#  iter=    2 fnrm=     0.4410203600772852E-05 nfe=    119
#  iter=    3 fnrm=     0.4117971101445546E-08 nfe=    189
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 5/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             1.580%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    447
#
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    0 fnrm=     0.1370218730390584E-01 nfe=      1
#  iter=    1 fnrm=     0.3681851196699457E-03 nfe=     56
#  iter=    2 fnrm=     0.3201132391858522E-05 nfe=    122
#  iter=    3 fnrm=     0.2574369045817960E-08 nfe=    193
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 6/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             1.800%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    446
#
#  iter=    0 fnrm=     0.1391677723396215E-01 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    1 fnrm=     0.2087104715153625E-03 nfe=     57
#  iter=    2 fnrm=     0.2007764788970629E-05 nfe=    125
#  iter=    3 fnrm=     0.2190799702140994E-08 nfe=    197
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 7/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             2.020%
#     -Advancing by                         0.220%
#     -Steps to target at current delta:    445
#
#  iter=    0 fnrm=     0.1398029730836741E-01 nfe=      1
#
# ===== INNER LOOP COMPLETED: ADVANCING DELTA =====
#  iter=    1 fnrm=     0.5299238654183999E-03 nfe=     57
#  iter=    2 fnrm=     0.1127309038270287E-05 nfe=    123
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             2.240%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    201
#
#   Updating Jacobian, npe =                      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    0 fnrm=     0.2990932550929315E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1634100533619673E-02 nfe=     57
#  iter=    2 fnrm=     0.7040249303290518E-05 nfe=    118
#  iter=    3 fnrm=     0.3541730446043873E-08 nfe=    189
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             2.724%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    200
#
#  iter=    0 fnrm=     0.2979160013623113E-01 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    1 fnrm=     0.1107481489437711E-02 nfe=     56
#  iter=    2 fnrm=     0.2248147226425676E-05 nfe=    119
#  iter=    3 fnrm=     0.3527901537980994E-08 nfe=    192
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             3.208%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    199
#
#  iter=    0 fnrm=     0.3004563980144287E-01 nfe=      1
#  iter=    1 fnrm=     0.1031873491955615E-02 nfe=     56
#  iter=    2 fnrm=     0.2286512040076076E-05 nfe=    119
#  iter=    3 fnrm=     0.2884110574788258E-08 nfe=    193
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to gridmorph2/progress3p692.hdf5
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 4/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             3.692%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    198
#
#  iter=    0 fnrm=     0.3036206530311969E-01 nfe=      1
#  iter=    1 fnrm=     0.1030933243116640E-02 nfe=     56
#  iter=    2 fnrm=     0.2302082188495065E-05 nfe=    120
#  iter=    3 fnrm=     0.2825229973430738E-08 nfe=    195
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 5/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             4.176%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    197
#
#  iter=    0 fnrm=     0.3068586145616310E-01 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    1 fnrm=     0.1175080689722365E-02 nfe=     54
#  iter=    2 fnrm=     0.2578184874193940E-05 nfe=    118
#  iter=    3 fnrm=     0.3294824317487774E-08 nfe=    194
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 6/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             4.660%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    196
#
#  iter=    0 fnrm=     0.3101679519965997E-01 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    1 fnrm=     0.1454590888912632E-02 nfe=     55
#  iter=    2 fnrm=     0.1154901079389825E-04 nfe=    120
#  iter=    3 fnrm=     0.3084458196668555E-08 nfe=    195
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 7/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             5.144%
#     -Advancing by                         0.484%
#     -Steps to target at current delta:    195
#
#  iter=    0 fnrm=     0.3135445706822090E-01 nfe=      1
#
# ===== INNER LOOP COMPLETED: ADVANCING DELTA =====
#  iter=    1 fnrm=     0.1027977257593763E-02 nfe=     53
#  iter=    2 fnrm=     0.1832334830860240E-05 nfe=    119
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             5.628%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    88
#
#   Updating Jacobian, npe =                      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    0 fnrm=     0.6453110748517688E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.3964807016776101E-02 nfe=     56
#  iter=    2 fnrm=     0.2286828748834163E-03 nfe=    120
#  iter=    3 fnrm=     0.3625485328112761E-06 nfe=    189
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             6.693%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    87
#
#  iter=    0 fnrm=     0.6611890806668962E-01 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    1 fnrm=     0.4702643076294857E-02 nfe=     56
#  iter=    2 fnrm=     0.2043783369754941E-03 nfe=    119
#  iter=    3 fnrm=     0.2300266674855294E-06 nfe=    189
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             7.758%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    86
#
#  iter=    0 fnrm=     0.6744399359189596E-01 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    1 fnrm=     0.5835168509015549E-02 nfe=     53
#  iter=    2 fnrm=     0.1772523488688946E-03 nfe=    116
#  iter=    3 fnrm=     0.1603636551609956E-06 nfe=    190
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 4/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             8.822%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    85
#
#  iter=    0 fnrm=     0.6910333287057362E-01 nfe=      1
#  iter=    1 fnrm=     0.5081336663723867E-02 nfe=     57
#  iter=    2 fnrm=     0.1532611132487324E-03 nfe=    127
#  iter=    3 fnrm=     0.9459721046482410E-07 nfe=    202
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to gridmorph2/progress9p887.hdf5
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 5/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             9.887%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    84
#
#  iter=    0 fnrm=     0.7084107753330784E-01 nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    1 fnrm=     0.5160035462304138E-02 nfe=     63
#  iter=    2 fnrm=     0.1125650148493339E-03 nfe=    136
#  iter=    3 fnrm=     0.6052423043040142E-07 nfe=    218
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 6/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             10.952%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    83
#
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    0 fnrm=     0.7266025628709384E-01 nfe=      1
#  iter=    1 fnrm=     0.5865730023899508E-02 nfe=     66
#  iter=    2 fnrm=     0.9266801465881011E-04 nfe=    142
#  iter=    3 fnrm=     0.3455551406085055E-07 nfe=    234
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 7/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             12.017%
#     -Advancing by                         1.065%
#     -Steps to target at current delta:    82
#
#  iter=    0 fnrm=     0.7456921136307577E-01 nfe=      1
#
# ===== INNER LOOP COMPLETED: ADVANCING DELTA ===== iter=    1 fnrm=     0.5838037765105426E-02 nfe=     70
#  iter=    2 fnrm=     0.6266727894037631E-04 nfe=    151
#  iter=    3 fnrm=     0.1528293790831261E-07 nfe=    249
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             13.082%
#     -Advancing by                         2.343%
#     -Steps to target at current delta:    37
#
#   Updating Jacobian, npe =                      1
#
# ===== SUCCESS: ADVANCING VARIABLE ===== iter=    0 fnrm=     0.1416338775151677     nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.5035443152135833E-01 nfe=     64
#  iter=    2 fnrm=     0.2644375399995321E-02 nfe=    132
#  iter=    3 fnrm=     0.5355536731316032E-05 nfe=    205
#  iter=    4 fnrm=     0.1306259358146193E-08 nfe=    294
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             15.424%
#     -Advancing by                         2.343%
#     -Steps to target at current delta:    36
#
#  iter=    0 fnrm=     0.1493621464099954     nfe=      1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
#  iter=    1 fnrm=     0.4741884786810904E-01 nfe=     64
#  iter=    2 fnrm=     0.1753978092678513E-02 nfe=    131
#  iter=    3 fnrm=     0.2819776555127963E-05 nfe=    216
#  iter=    4 fnrm=     0.1002236938015506E-08 nfe=    314
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 3/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             17.767%
#     -Advancing by                         2.343%
#     -Steps to target at current delta:    35
#
#  iter=    0 fnrm=     0.1600320543754552     nfe=      1
#
# ===== FAIL 1/3 ===== iter=    1 fnrm=     0.1203901204391059     nfe=     69
#  iter=    2 fnrm=     0.7741269288547099E-01 nfe=    135
#  iter=    3 fnrm=     0.3127686744784100E-01 nfe=    207
#  iter=    4 fnrm=     0.3958565459127399E-02 nfe=    282
#  iter=    5 fnrm=     0.1456001583401991E-04 nfe=    370
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
#
# ===== DECREASE DELTA AND TRY AGAIN =====
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             17.767%
#     -Advancing by                         1.171%
#     -Steps to target at current delta:    70
#
#
# ===== SUCCESS: ADVANCING VARIABLE =====  Updating Jacobian, npe =                      1
#
#  iter=    0 fnrm=     0.7119117012014191E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.3914488550948777E-02 nfe=     63
#  iter=    2 fnrm=     0.1560647663169848E-04 nfe=    132
#  iter=    3 fnrm=     0.9042651977545822E-07 nfe=    219
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             18.938%
#     -Advancing by                         1.171%
#     -Steps to target at current delta:    69
#
#  iter=    0 fnrm=     0.7732144397609783E-01 nfe=      1
#
# ===== FAIL 2/3 =====
# ===== DECREASE DELTA AND TRY AGAIN =====
#  iter=    1 fnrm=     0.5833682799335946E-01 nfe=     67
#  iter=    2 fnrm=     0.3859811685550336E-01 nfe=    134
#  iter=    3 fnrm=     0.1825458448799466E-01 nfe=    204
#  iter=    4 fnrm=     0.3575107750087751E-02 nfe=    276
#  iter=    5 fnrm=     0.1815528692302129E-04 nfe=    351
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
# ===== MAIN LOOP 1/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             18.938%
#     -Advancing by                         0.586%
#     -Steps to target at current delta:    138
#
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.3564244021468983E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1429467452629666E-02 nfe=     66
#  iter=    2 fnrm=     0.1520423868651546E-05 nfe=    145
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
#
# ===== SUCCESS: ADVANCING VARIABLE =====
# ===== MAIN LOOP 2/7 =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             19.524%
#     -Advancing by                         0.586%
#     -Steps to target at current delta:    137
#
# ===== RECOVERY LOOP ENTERED ===== iter=    0 fnrm=     0.4390908476481245E-01 nfe=      1
#
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             19.524%
#
#  iter=    1 fnrm=     0.3330299655194701E-01 nfe=     71
#  iter=    2 fnrm=     0.2316494875265477E-01 nfe=    142
#  iter=    3 fnrm=     0.1354469476350144E-01 nfe=    215
#  iter=    4 fnrm=     0.3669638865889881E-02 nfe=    291
#  iter=    5 fnrm=     0.2135076859136113E-04 nfe=    371
#
#
#  nksol ---  iterm = 4.
#             the maximum allowable number of nonlinear
#             iterations has been reached.
#  Interpolants created; mype =                   -1
# Intermediate solution written to gridmorph2/progress19p524_staticiter.hdf5
# ===== CONVERGED AT STEADY STATE: RETURNING TO MAIN LOOP =====
# ===== ENTER TIME-DEPENDENT SOLVE =====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             19.524%
#
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.4354629387335269E-01 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.1224545513744737E-01 nfe=     49
#  iter=    2 fnrm=     0.1032712664980318E-03 nfe=     99
#  iter=    3 fnrm=     0.2682595114399389E-06 nfe=    169
#  iter=    4 fnrm=     0.3439806124551454E-11 nfe=    244
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#
#  Initial successful time-step exists
#
#  Interpolants created; mype =                   -1
# ---------------------------------------------------------------
# *** Number of time-step changes = 1 New time-step: 1.00E-05 ***
# ---------------------------------------------------------------
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.4522527314698933E-02 nfe=      1
#  iter=    1 fnrm=     0.2502199622066448E-03 nfe=     56
#  iter=    2 fnrm=     0.2368116853638124E-06 nfe=    122
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.4567972073100592E-02 nfe=      1
#  iter=    1 fnrm=     0.1661676264906607E-03 nfe=     56
#  iter=    2 fnrm=     0.1040658969522397E-06 nfe=    122
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 1.0000E-05; Timestep = 1.0000E-05
#
#  Inner iteration #2
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.5420964831129918E-02 nfe=      1
#  iter=    1 fnrm=     0.1387937797704209E-03 nfe=     53
#  iter=    2 fnrm=     0.6237702531475560E-07 nfe=    121
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 2.0000E-05; Timestep = 1.0000E-05
#
#  Inner iteration #3
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.6398041333058205E-02 nfe=      1
#  iter=    1 fnrm=     0.2077556588368764E-03 nfe=     52
#  iter=    2 fnrm=     0.1023793619739352E-06 nfe=    118
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 3.0000E-05; Timestep = 1.0000E-05
#
#  Inner iteration #4
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.7340337704734867E-02 nfe=      1
#  iter=    1 fnrm=     0.2739547859538088E-03 nfe=     52
#  iter=    2 fnrm=     0.1049272438300517E-06 nfe=    118
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 4.0000E-05; Timestep = 1.0000E-05
#
#  Inner iteration #5
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.8174397740295760E-02 nfe=      1
#  iter=    1 fnrm=     0.1175921561595670E-03 nfe=     51
#  iter=    2 fnrm=     0.1846382736532913E-07 nfe=    120
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 5.0000E-05; Timestep = 1.0000E-05
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 2 New time-step: 3.40E-05 ***
# ---------------------------------------------------------------
# Solving for delta=21.524%
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.8865300396439834E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.5071309911394088E-03 nfe=     59
#  iter=    2 fnrm=     0.6220624413605003E-06 nfe=    128
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.9803842129941173E-02 nfe=      1
#  iter=    1 fnrm=     0.7638662551507616E-03 nfe=     58
#  iter=    2 fnrm=     0.5040662824977221E-06 nfe=    125
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 9.4000E-05; Timestep = 3.4000E-05
#
#  Inner iteration #2
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.9965506263954123E-02 nfe=      1
#  iter=    1 fnrm=     0.3464381242929602E-03 nfe=     57
#  iter=    2 fnrm=     0.1139910541792014E-06 nfe=    127
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 1.2800E-04; Timestep = 3.4000E-05
#
#  Inner iteration #3
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.9723407614249434E-02 nfe=      1
#  iter=    1 fnrm=     0.1470285616441500E-03 nfe=     58
#  iter=    2 fnrm=     0.4902536152826964E-07 nfe=    129
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 1.6200E-04; Timestep = 3.4000E-05
#
#  Inner iteration #4
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.9347547474579344E-02 nfe=      1
#  iter=    1 fnrm=     0.3561433857812678E-03 nfe=     58
#  iter=    2 fnrm=     0.6527322412174073E-07 nfe=    128
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 1.9600E-04; Timestep = 3.4000E-05
#
#  Inner iteration #5
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.8970851106655763E-02 nfe=      1
#  iter=    1 fnrm=     0.7589130037253999E-04 nfe=     58
#  iter=    2 fnrm=     0.3300960150110280E-07 nfe=    131
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 2.3000E-04; Timestep = 3.4000E-05
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 3 New time-step: 1.16E-04 ***
# ---------------------------------------------------------------
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.8630509268592958E-02 nfe=      1
#  iter=    1 fnrm=     0.9397262707748689E-03 nfe=     72
#  iter=    2 fnrm=     0.5580203833617692E-06 nfe=    149
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.7538563930414230E-02 nfe=      1
#  iter=    1 fnrm=     0.4474976736488155E-03 nfe=     70
#  iter=    2 fnrm=     0.1984430388133885E-06 nfe=    145
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 3.7960E-04; Timestep = 1.1560E-04
#
#  Inner iteration #2
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.6623738083261397E-02 nfe=      1
#  iter=    1 fnrm=     0.6827680708503174E-03 nfe=     74
#  iter=    2 fnrm=     0.1060178955261027E-06 nfe=    151
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 4.9520E-04; Timestep = 1.1560E-04
#
#  Inner iteration #3
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.5803841095017832E-02 nfe=      1
#  iter=    1 fnrm=     0.1038830410656475E-03 nfe=     74
#  iter=    2 fnrm=     0.6673272223323418E-07 nfe=    156
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 6.1080E-04; Timestep = 1.1560E-04
#
#  Inner iteration #4
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.5092622672731875E-02 nfe=      1
#  iter=    1 fnrm=     0.1210750898254515E-03 nfe=     75
#  iter=    2 fnrm=     0.5652243922020179E-07 nfe=    157
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 7.2640E-04; Timestep = 1.1560E-04
#
#  Inner iteration #5
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.4492654874427991E-02 nfe=      1
#  iter=    1 fnrm=     0.7178794924416502E-04 nfe=     76
#  iter=    2 fnrm=     0.3163793717913235E-07 nfe=    159
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 8.4200E-04; Timestep = 1.1560E-04
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 4 New time-step: 3.93E-04 ***
# ---------------------------------------------------------------
# Solving for delta=21.524%
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.3920959372458935E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.3599123176566192E-03 nfe=     73
#  iter=    2 fnrm=     0.5964628761785873E-07 nfe=    143
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.2864325299046523E-02 nfe=      1
#  iter=    1 fnrm=     0.2928335235441023E-03 nfe=     73
#  iter=    2 fnrm=     0.4513394003774094E-07 nfe=    143
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 1.3506E-03; Timestep = 3.9304E-04
#
#  Inner iteration #2
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.2153086969261426E-02 nfe=      1
#  iter=    1 fnrm=     0.1730657737711133E-03 nfe=     74
#  iter=    2 fnrm=     0.2968085785228762E-07 nfe=    144
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 1.7437E-03; Timestep = 3.9304E-04
#
#  Inner iteration #3
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.1645344511857323E-02 nfe=      1
#  iter=    1 fnrm=     0.9336426634566241E-04 nfe=     74
#  iter=    2 fnrm=     0.1234996301813466E-07 nfe=    146
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 2.1367E-03; Timestep = 3.9304E-04
#
#  Inner iteration #4
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.1268233749314964E-02 nfe=      1
#  iter=    1 fnrm=     0.5013257500629240E-04 nfe=     74
#  iter=    2 fnrm=     0.2606179339266175E-08 nfe=    147
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 2.5298E-03; Timestep = 3.9304E-04
#
#  Inner iteration #5
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.9817288972441395E-03 nfe=      1
#  iter=    1 fnrm=     0.1874449876870513E-04 nfe=     74
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 2.9228E-03; Timestep = 3.9304E-04
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 5 New time-step: 1.34E-03 ***
# ---------------------------------------------------------------
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.7609773219044910E-03 nfe=      1
#  iter=    1 fnrm=     0.7729137377861683E-04 nfe=     80
#  iter=    2 fnrm=     0.5860580126298377E-08 nfe=    157
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.3825750044901785E-03 nfe=      1
#  iter=    1 fnrm=     0.3082062703799731E-04 nfe=     81
#  iter=    2 fnrm=     0.8637916433210839E-09 nfe=    159
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 4.6522E-03; Timestep = 1.3363E-03
#
#  Inner iteration #2
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.1915605619431806E-03 nfe=      1
#  iter=    1 fnrm=     0.2547440115490114E-05 nfe=     82
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 5.9885E-03; Timestep = 1.3363E-03
#
#  Inner iteration #3
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.9563322991236367E-04 nfe=      1
#  iter=    1 fnrm=     0.2177304604853162E-05 nfe=     83
#  iter=    2 fnrm=     0.4893006719282228E-10 nfe=    161
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 7.3248E-03; Timestep = 1.3363E-03
#
#  Inner iteration #4
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.4764900845193671E-04 nfe=      1
#  iter=    1 fnrm=     0.2054626174592165E-06 nfe=     84
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 8.6612E-03; Timestep = 1.3363E-03
#
#  Inner iteration #5
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.2370313446892822E-04 nfe=      1
#  iter=    1 fnrm=     0.6198899146832001E-07 nfe=     86
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 9.9975E-03; Timestep = 1.3363E-03
#
# ---------------------------------------------------------------
# *** Number of time-step changes = 6 New time-step: 4.54E-03 ***
# ---------------------------------------------------------------
# Solving for delta=21.524%
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1143962971679249E-04 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.8839341216048385E-07 nfe=     86
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.2576432244727680E-05 nfe=      1
#  iter=    1 fnrm=     0.1971038055914299E-07 nfe=     88
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#  Total time = 1.5877E-02; Timestep = 4.5435E-03
#
#  Inner iteration #2
#
# Solving for delta=21.524%
#  iter=    0 fnrm=     0.5799596518388166E-06 nfe=      1
#  iter=    1 fnrm=     0.4276375450451652E-08 nfe=     89
#
#
# ...
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 2.1367E-03; Timestep = 1.3101E-04
#
#  Inner iteration #5
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.1168930245288971E-02 nfe=      1
#  iter=    1 fnrm=     0.3374223312847559E-05 nfe=    106
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 2.2677E-03; Timestep = 1.3101E-04
#
# ----------------------------------------------------------------
# *** Number of time-step changes = 10 New time-step: 4.45E-04 ***
# ----------------------------------------------------------------
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.1060595223934168E-02 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.2686509860092802E-04 nfe=    107
#  iter=    2 fnrm=     0.1356386352764566E-07 nfe=    214
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.8255761820846996E-03 nfe=      1
#  iter=    1 fnrm=     0.3096052896163011E-04 nfe=    107
#  iter=    2 fnrm=     0.1202883706290609E-07 nfe=    213
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 2.8442E-03; Timestep = 4.4545E-04
#
#  Inner iteration #2
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.6428992052830095E-03 nfe=      1
#  iter=    1 fnrm=     0.2444693244949108E-04 nfe=    107
#  iter=    2 fnrm=     0.5703441144636967E-08 nfe=    213
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 3.2896E-03; Timestep = 4.4545E-04
#
#  Inner iteration #3
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.5010115468865212E-03 nfe=      1
#  iter=    1 fnrm=     0.8954108533178817E-04 nfe=    108
#  iter=    2 fnrm=     0.3626334863534371E-08 nfe=    207
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 3.7351E-03; Timestep = 4.4545E-04
#
#  Inner iteration #4
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.3908482104862674E-03 nfe=      1
#  iter=    1 fnrm=     0.4792255789578505E-05 nfe=    108
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 4.1805E-03; Timestep = 4.4545E-04
#
#  Inner iteration #5
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.3055082097434139E-03 nfe=      1
#  iter=    1 fnrm=     0.6797533595497244E-05 nfe=    109
#  iter=    2 fnrm=     0.1061413874432677E-08 nfe=    215
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 4.6260E-03; Timestep = 4.4545E-04
#
# ----------------------------------------------------------------
# *** Number of time-step changes = 11 New time-step: 1.51E-03 ***
# ----------------------------------------------------------------
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.2387605108319706E-03 nfe=      1
#  iter=    1 fnrm=     0.7432162656100414E-05 nfe=    111
#  iter=    2 fnrm=     0.9610808642922658E-08 nfe=    221
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.1233289596061464E-03 nfe=      1
#  iter=    1 fnrm=     0.2813400943897666E-05 nfe=    112
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 6.5859E-03; Timestep = 1.5145E-03
#
#  Inner iteration #2
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.6397496749477097E-04 nfe=      1
#  iter=    1 fnrm=     0.1247554397666601E-05 nfe=    114
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 8.1004E-03; Timestep = 1.5145E-03
#
#  Inner iteration #3
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.3315241280991322E-04 nfe=      1
#  iter=    1 fnrm=     0.5997432576686626E-06 nfe=    115
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 9.6150E-03; Timestep = 1.5145E-03
#
#  Inner iteration #4
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.1721708305806576E-04 nfe=      1
#  iter=    1 fnrm=     0.2983372504190771E-06 nfe=    116
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 1.1129E-02; Timestep = 1.5145E-03
#
#  Inner iteration #5
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.8949934229894217E-05 nfe=      1
#  iter=    1 fnrm=     0.1547035107303679E-06 nfe=    117
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 1.2644E-02; Timestep = 1.5145E-03
#
# ----------------------------------------------------------------
# *** Number of time-step changes = 12 New time-step: 5.15E-03 ***
# ----------------------------------------------------------------
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#   Updating Jacobian, npe =                      1
#  iter=    0 fnrm=     0.4573486958973327E-05 nfe=      1
#   Updating Jacobian, npe =                      2
#  iter=    1 fnrm=     0.5830104128710062E-07 nfe=    119
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Inner iteration #1
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.1106779980204286E-05 nfe=      1
#  iter=    1 fnrm=     0.1397981453608347E-07 nfe=    121
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 1.9308E-02; Timestep = 5.1493E-03
#
#  Inner iteration #2
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.2674558386705576E-06 nfe=      1
#  iter=    1 fnrm=     0.3404203360600893E-08 nfe=    123
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 2.4457E-02; Timestep = 5.1493E-03
#
#  Inner iteration #3
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.6464372302506992E-07 nfe=      1
#  iter=    1 fnrm=     0.8028230556333856E-09 nfe=    126
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 2.9607E-02; Timestep = 5.1493E-03
#
#  Inner iteration #4
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.1563750606836456E-07 nfe=      1
#  iter=    1 fnrm=     0.2023308805216520E-09 nfe=    128
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#  Total time = 3.4756E-02; Timestep = 5.1493E-03
#
#  Inner iteration #5
#
# Solving for delta=100.000%
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#  iter=    0 fnrm=     0.3779783376815371E-08 nfe=      1
#  iter=    1 fnrm=     0.4607850248208719E-10 nfe=    129
#
#
#  nksol ---  iterm = 1.
#             maxnorm(sf*f(u)) .le. ftol, where maxnorm() is
#             the maximum norm function.  u is probably an
#             approximate root of f.
#  Interpolants created; mype =                   -1
# Intermediate solution written to ./gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#
# ******************************
# ** SUCCESS: fnrm < bbb.ftol **
# ******************************
# Total runtime: 0:04:53
#
# ===== TARGET VALUE ACHIEVED: REDUCE FNORM ====
#     -Variable(s) being solved:
#                                         - gridmorph
#     -Progress                             100.000%
#
# Intermediate solution written to gridmorph2/progress100p000_staticiter.hdf5
# ===== CONVERGED AT STEADY STATE: RETURNING TO MAIN LOOP =====
# ++++++++++++++++++++++++++++++++++++++++
# +++++ CONTINUATION SOLVE SUCCEEDED +++++
# ++++++++++++++++++++++++++++++++++++++++
# Total runtime: 0:17:17
# Intermediate solution written to gridmorph2/SUCCESS.hdf5

# %%
# %%capture capt
import os

directory = os.getcwd()+'/gridmorph2'
files = os.listdir(directory)
files.sort(key=lambda x: os.stat(os.path.join(directory, x)).st_mtime)
lpoints = []
rpoints = []
for file in files:
    filename = os.fsdecode(file)
    c = Case('gridmorph2/' + filename)
    bbb.fqp=0
    bbb.plateflux(); #internally calculated fluxes (postprocessing)
    ldata = 1.e-6*(bbb.sdtlb+bbb.sdrlb)
    rdata = 1.e-6*(bbb.sdtrb+bbb.sdrrb)
    lpoints.append(max(ldata))
    rpoints.append(max(rdata))
    print(f'Left max: {max(ldata)}, right max: {max(rdata)}', file=sys.stderr)
# Out:
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress0p100.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress0p100.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress0p100.hdf5
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 4.72e-04
# Left max: [8.26610141], right max: [8.95941156]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress1p140.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress1p140.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress1p140.hdf5
#
# *** UEDGE arrays populated: Warning, case may noy be fully converged ***
# fnrm without preconditioning: 37.2
# Left max: [8.24692142], right max: [8.96731428]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress3p692.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress3p692.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress3p692.hdf5
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 7.63e+00
# Left max: [8.20110855], right max: [8.98229262]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress9p887.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress9p887.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress9p887.hdf5
#
# *** UEDGE arrays populated: Warning, case may noy be fully converged ***
# fnrm without preconditioning: 25.8
# Left max: [8.11456877], right max: [8.98148205]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress19p524_staticiter.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress19p524_staticiter.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress19p524_staticiter.hdf5
#
# *** UEDGE arrays populated: WARNING, case NOT converged ***
# fnrm without preconditioning: 4.19e+07
# Left max: [8.01802048], right max: [8.95570691]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress21p524_dtrun_last_ii2.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress21p524_dtrun_last_ii2.hdf5
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 1.11e-03
# Left max: [7.7285862], right max: [8.95495721]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress22p109.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress22p109.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress22p109.hdf5
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 1.11e-03
# Left max: [7.7285862], right max: [8.95495721]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress27p497.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress27p497.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress27p497.hdf5
#
# *** UEDGE arrays populated: Warning, case may noy be fully converged ***
# fnrm without preconditioning: 26.4
# Left max: [7.68118121], right max: [8.90759263]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress40p897.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress40p897.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress40p897.hdf5
#
# *** UEDGE arrays populated: Warning, case may noy be fully converged ***
# fnrm without preconditioning: 28.3
# Left max: [7.69528221], right max: [8.75487852]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress64p423.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress64p423.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress64p423.hdf5
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 2.00e+00
# Left max: [7.63373113], right max: [7.86236023]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress80p013.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress80p013.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress80p013.hdf5
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#
# *** UEDGE arrays populated: WARNING, case NOT converged ***
# fnrm without preconditioning: 2.10e+02
# Left max: [7.66188327], right max: [6.7945195]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress93p576.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress93p576.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress93p576.hdf5
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 1.36e+00
# Left max: [7.62145712], right max: [6.02492082]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress98p292_staticiter.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress98p292_staticiter.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress98p292_staticiter.hdf5
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#
# *** UEDGE arrays populated: WARNING, case NOT converged ***
# fnrm without preconditioning: 4.60e+07
# Left max: [7.55722427], right max: [5.68264015]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress100p000_dtrun_last_ii2.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress100p000_dtrun_last_ii2.hdf5
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 6.31e-02
# Left max: [7.25360842], right max: [5.66914867]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/progress100p000_staticiter.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/progress100p000_staticiter.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/progress100p000_staticiter.hdf5
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 6.31e-02
# Left max: [7.25360842], right max: [5.66914867]
# =================================================
# Restoring case from HDF5 file:
#   Rate dirs read from .uedgerc
#   Grid read from .../MANTA_final_baseline/gridmorph2/SUCCESS.hdf5
#   User-specified diffusivities read from HDF5 file ".../MANTA_final_baseline/gridmorph2/SUCCESS.hdf5"
# UETOOLS-style save successfully restored from .../MANTA_final_baseline/gridmorph2/SUCCESS.hdf5
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   17
#   fy search failure at ix,iy =                    16                   18
#
# *** UEDGE arrays populated: Case appears converged ***
# fnrm without preconditioning: 6.31e-02
# Left max: [7.25360842], right max: [5.66914867]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 [item[0][0] for item in lpoints]
#
# Cell In[13], line 1, in <listcomp>(.0)
# ----> 1 [item[0][0] for item in lpoints]
#
# IndexError: invalid index to scalar variable.

# %%
plt.figure()
plt.plot(np.arange(0,16), [item[0] for item in lpoints])
plt.figure()
plt.plot(np.arange(0,16), [item[0] for item in rpoints])
